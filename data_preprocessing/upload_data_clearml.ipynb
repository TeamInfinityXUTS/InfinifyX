# %%
# !pip install clearml
# Out:
# Collecting clearml
#   Downloading clearml-2.1.7-py2.py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: attrs>=18.0 in /opt/conda/lib/python3.12/site-packages (from clearml) (23.2.0)
# Collecting furl>=2.0.0 (from clearml)
#   Downloading furl-2.1.4-py2.py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: jsonschema>=2.6.0 in /opt/conda/lib/python3.12/site-packages (from clearml) (4.23.0)
# Collecting pathlib2>=2.3.0 (from clearml)
#   Downloading pathlib2-2.3.7.post1-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: psutil>=3.4.2 in /opt/conda/lib/python3.12/site-packages (from clearml) (5.9.8)
# Requirement already satisfied: pyparsing>=2.0.3 in /opt/conda/lib/python3.12/site-packages (from clearml) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/conda/lib/python3.12/site-packages (from clearml) (2.9.0.post0)
# Requirement already satisfied: pyjwt<3.0.0,>=2.4.0 in /opt/conda/lib/python3.12/site-packages (from clearml) (2.11.0)
# Requirement already satisfied: PyYAML>=3.12 in /opt/conda/lib/python3.12/site-packages (from clearml) (6.0.3)
# Requirement already satisfied: six>=1.16.0 in /opt/conda/lib/python3.12/site-packages (from clearml) (1.17.0)
# Requirement already satisfied: urllib3>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from clearml) (1.26.20)
# Requirement already satisfied: Pillow>=10.3.0 in /opt/conda/lib/python3.12/site-packages (from clearml) (11.3.0)
# Requirement already satisfied: referencing<0.40 in /opt/conda/lib/python3.12/site-packages (from clearml) (0.37.0)
# Requirement already satisfied: requests>=2.32.0 in /opt/conda/lib/python3.12/site-packages (from clearml) (2.32.5)
# Requirement already satisfied: numpy>=1.26.4 in /opt/conda/lib/python3.12/site-packages (from clearml) (1.26.4)
# Requirement already satisfied: rpds-py>=0.7.0 in /opt/conda/lib/python3.12/site-packages (from referencing<0.40->clearml) (0.27.1)
# Requirement already satisfied: typing-extensions>=4.4.0 in /opt/conda/lib/python3.12/site-packages (from referencing<0.40->clearml) (4.15.0)
# Collecting orderedmultidict>=1.0.1 (from furl>=2.0.0->clearml)
#   Downloading orderedmultidict-1.0.2-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=2.6.0->clearml) (2025.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests>=2.32.0->clearml) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests>=2.32.0->clearml) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests>=2.32.0->clearml) (2026.2.25)
# Downloading clearml-2.1.7-py2.py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 59.9 MB/s  0:00:00
# Downloading furl-2.1.4-py2.py3-none-any.whl (27 kB)
# Downloading orderedmultidict-1.0.2-py2.py3-none-any.whl (11 kB)
# Downloading pathlib2-2.3.7.post1-py2.py3-none-any.whl (18 kB)
# Installing collected packages: pathlib2, orderedmultidict, furl, clearml
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [clearml]m3/4 [clearml]
# Successfully installed clearml-2.1.7 furl-2.1.4 orderedmultidict-1.0.2 pathlib2-2.3.7.post1

# %%
import os

# %env CLEARML_WEB_HOST=https://app.clear.ml/
# %env CLEARML_API_HOST=https://api.clear.ml
# %env CLEARML_FILES_HOST=https://files.clear.ml
# %env CLEARML_API_ACCESS_KEY=R58U0GS1V7DPMV9POEA3L3E6WHH8EV
# %env CLEARML_API_SECRET_KEY=XQWoX03bgFcB4eJa6Ux8Kt7zmkaVmVdjg-3xBMa1kFdAdpywfbwfAKb8UzS-Rc2WWXU
# Out:
# env: CLEARML_WEB_HOST=https://app.clear.ml/
# env: CLEARML_API_HOST=https://api.clear.ml
# env: CLEARML_FILES_HOST=https://files.clear.ml
# env: CLEARML_API_ACCESS_KEY=R58U0GS1V7DPMV9POEA3L3E6WHH8EV
# env: CLEARML_API_SECRET_KEY=XQWoX03bgFcB4eJa6Ux8Kt7zmkaVmVdjg-3xBMa1kFdAdpywfbwfAKb8UzS-Rc2WWXU

# %%
from clearml import Dataset

# 1. 创建一个新的数据集对象
# dataset_project: ClearML 界面上的项目名称
# dataset_name: 数据集的名称
dataset = Dataset.create(
    dataset_project='InfinifyX', 
    dataset_name='bdd100k_augmented'
)

# 2. 指定你要上传的本地文件夹路径
# 按照你的描述，路径是 'InfinifyX/bdd100k_tiny'
dataset.add_files(path='bdd100k_augmented')

# 3. 开始上传到 ClearML 文件服务器
dataset.upload()

dataset.finalize()

print("Dataset Upload")
# Out:
# ClearML results page: https://app.clear.ml/projects/6d945a91487a4d44b4d0150a0f6a86bc/experiments/7733c9304cb04a72a8629c2bb6dfd413/output/log
# ClearML dataset page: https://app.clear.ml/datasets/simple/6d945a91487a4d44b4d0150a0f6a86bc/experiments/7733c9304cb04a72a8629c2bb6dfd413
# Generating SHA2 hash for 4800 files
# 100%|██████████| 4800/4800 [00:00<00:00, 7755.37it/s]
# Hash generation completed
# Uploading dataset changes (4800 files compressed to 133.59 MiB) to https://files.clear.ml
# █████████████████████████████ 100% | 133.59/133.59 MB [00:11<00:00, 11.30MB/s]:
# File compression and upload completed: total size 133.59 MiB, 1 chunk(s) stored (average size 133.59 MiB)
# Dataset Upload

# %%
# from clearml import Dataset
# import os

# # 1. 确认文件夹是否存在（防止路径报错）
# data_path = 'bdd100k' 
# if not os.path.exists(data_path):
#     print(f"❌ 找不到文件夹 '{data_path}'，")
# else:
#     print(f"✅ 找到文件夹 '{data_path}'，准备开始创建数据集...")

  
#     dataset = Dataset.create(
#         dataset_project='InfinifyX', 
#         dataset_name='bdd100k'
#     )

#     dataset.add_files(path=data_path)

#     print("正在上传中，完整数据集较大，请耐心等待...")
#     dataset.upload()
#     dataset.finalize()

#     print("🎉 完整版 bdd100k 数据集上传成功！")
# Out:
# ✅ 找到文件夹 'bdd100k'，准备开始创建数据集...
# ClearML results page: https://app.clear.ml/projects/6245f4e3df544431b522387d80173990/experiments/04c0bc4df28a4ee381ee684969f6be6c/output/log
# ClearML dataset page: https://app.clear.ml/datasets/simple/6245f4e3df544431b522387d80173990/experiments/04c0bc4df28a4ee381ee684969f6be6c
# Generating SHA2 hash for 249865 files
# 100%|██████████| 249865/249865 [01:21<00:00, 3077.46it/s]
# Hash generation completed
# ███████████████████████████████ 100% | 97.49/97.49 MB [00:08<00:00, 11.22MB/s]:
# 正在上传中，完整数据集较大，请耐心等待...
# Uploading dataset changes (6181 files compressed to 512.5 MiB) to https://files.clear.ml
# ██████▌                           21% | 20.00/96.9 MB [00:01<00:06, 12.54MB/s]:
# ████████▎                         26% | 25.00/96.9 MB [00:01<00:05, 12.46MB/s]:
# █████████▉                        31% | 30.00/96.9 MB [00:02<00:05, 12.42MB/s]:
# █████████████▏                    41% | 40.00/96.9 MB [00:03<00:04, 12.37MB/s]:
# ██████████████▊                   46% | 45.00/96.9 MB [00:03<00:04, 12.36MB/s]:
# █▌                                5% | 25.00/512.5 MB [00:01<00:38, 12.81MB/s]:
# ████████████████▌                 52% | 50.00/96.9 MB [00:04<00:04, 10.90MB/s]:
# ██████████████████▏               57% | 55.00/96.9 MB [00:04<00:03, 11.31MB/s]:
# █████████████████████▍            67% | 65.00/96.9 MB [00:05<00:02, 11.81MB/s]:
# ███████████████████████           72% | 70.00/96.9 MB [00:05<00:02, 11.96MB/s]:
# ████████████████████████▊         77% | 75.00/96.9 MB [00:06<00:01, 12.02MB/s]:
# ███▎                             11% | 55.00/512.5 MB [00:04<00:38, 11.74MB/s]:
# ██████████████████████████▍       83% | 80.00/96.9 MB [00:06<00:01, 10.79MB/s]:
# ████████████████████████████      88% | 85.00/96.9 MB [00:07<00:01, 11.20MB/s]:
# █████████████████████████████▋    93% | 90.00/96.9 MB [00:07<00:00, 11.46MB/s]:
# ████████████████████████████████ 100% | 96.90/96.9 MB [00:08<00:00, 11.34MB/s]:
# ████▊                            16% | 80.00/512.5 MB [00:06<00:38, 11.35MB/s]:
# ████████████████████████████████ 100% | 96.90/96.9 MB [00:08<00:00, 11.02MB/s]:
#
# █████▍                           18% | 90.00/512.5 MB [00:07<00:35, 11.80MB/s]:
# █████▋                           19% | 95.00/512.5 MB [00:07<00:34, 11.96MB/s]:
# █████▊                          20% | 100.00/512.5 MB [00:08<00:34, 12.09MB/s]:
# ██████▏                         20% | 105.00/512.5 MB [00:08<00:36, 11.05MB/s]:
# ██████▍                         21% | 110.00/512.5 MB [00:09<00:35, 11.39MB/s]:
# ██████▋                         22% | 115.00/512.5 MB [00:09<00:34, 11.63MB/s]:
# ███████                         23% | 120.00/512.5 MB [00:09<00:33, 11.82MB/s]:
# ███████▎                        24% | 125.00/512.5 MB [00:10<00:32, 11.92MB/s]:
# Uploading dataset changes (6183 files compressed to 512.53 MiB) to https://files.clear.ml
# ███████▌                        25% | 130.00/512.5 MB [00:14<01:53,  3.38MB/s]:
# ███████▉                        26% | 135.00/512.5 MB [00:14<01:27,  4.32MB/s]:
# ████████▏                       27% | 140.00/512.5 MB [00:15<01:09,  5.37MB/s]:
# ████████▍                       28% | 145.00/512.5 MB [00:15<00:56,  6.47MB/s]:
#                                            0% | 0.00/96.34 MB [00:00<?, ?MB/s]:
# ███▏                             10% | 10.00/96.34 MB [00:00<00:03, 24.57MB/s]:
# ████▊                            16% | 15.00/96.34 MB [00:00<00:04, 17.32MB/s]:
# █████████▋                      32% | 165.00/512.5 MB [00:17<00:35,  9.85MB/s]:
# ██████▍                          21% | 20.00/96.34 MB [00:01<00:06, 12.52MB/s]:
# ██████████▏                     34% | 175.00/512.5 MB [00:18<00:30, 11.00MB/s]:
#
# ████████                         26% | 25.00/96.34 MB [00:01<00:05, 12.45MB/s]:
#
# █████████▋                       31% | 30.00/96.34 MB [00:02<00:05, 12.41MB/s]:
# ███████████▎                     36% | 35.00/96.34 MB [00:02<00:04, 12.38MB/s]:
# ██████████▊                     36% | 185.00/512.5 MB [00:19<00:30, 10.85MB/s]:
#
# ████████████▊                    42% | 40.00/96.34 MB [00:03<00:04, 12.36MB/s]:
# ███████████                     37% | 190.00/512.5 MB [00:19<00:28, 11.26MB/s]:
#
# ██████████████▍                  47% | 45.00/96.34 MB [00:03<00:04, 12.34MB/s]:
# ███████████▍                    38% | 195.00/512.5 MB [00:19<00:27, 11.60MB/s]:
#
# █▍                               5% | 25.00/512.53 MB [00:01<00:37, 13.15MB/s]:
# ███████████▋                    39% | 200.00/512.5 MB [00:20<00:26, 11.82MB/s]:
#
# ████████████████                 52% | 50.00/96.34 MB [00:04<00:04, 10.91MB/s]:
#
# █████████████████▋               57% | 55.00/96.34 MB [00:04<00:03, 11.30MB/s]:
# ████████████                    40% | 205.00/512.5 MB [00:20<00:28, 10.79MB/s]:
#
# ███████████████████▎             62% | 60.00/96.34 MB [00:04<00:03, 11.59MB/s]:
# ████████████████████▉            67% | 65.00/96.34 MB [00:05<00:02, 11.76MB/s]:
# ████████████▌                   42% | 215.00/512.5 MB [00:21<00:25, 11.49MB/s]:
#
# ██████████████████████▌          73% | 70.00/96.34 MB [00:05<00:02, 11.87MB/s]:
# ████████████▉                   43% | 220.00/512.5 MB [00:22<00:24, 11.71MB/s]:
#
# ████████████████████████▏        78% | 75.00/96.34 MB [00:06<00:01, 11.94MB/s]:
# █████████████▏                  44% | 225.00/512.5 MB [00:22<00:24, 11.89MB/s]:
#
# ███▏                            11% | 55.00/512.53 MB [00:04<00:38, 11.86MB/s]:
# █████████████▍                  45% | 230.00/512.5 MB [00:22<00:23, 11.97MB/s]:
#
# █████████████████████████▋       83% | 80.00/96.34 MB [00:06<00:01, 10.84MB/s]:
#
# ███▊                            13% | 65.00/512.53 MB [00:05<00:37, 11.97MB/s]:
# ███████████████████████████▎     88% | 85.00/96.34 MB [00:07<00:01, 11.19MB/s]:
#
# ████                            14% | 70.00/512.53 MB [00:05<00:36, 12.02MB/s]:
# ████████████████████████████▉    93% | 90.00/96.34 MB [00:07<00:00, 11.41MB/s]:
# ██████████████▎                 48% | 245.00/512.5 MB [00:24<00:23, 11.62MB/s]:
#
# ███████████████████████████████ 100% | 96.34/96.34 MB [00:08<00:00, 11.08MB/s]:
# ██████████████▋                 49% | 250.00/512.5 MB [00:24<00:22, 11.77MB/s]:
#
# ████▋                           16% | 80.00/512.53 MB [00:06<00:38, 11.34MB/s]:
# ███████████████████████████████ 100% | 96.34/96.34 MB [00:08<00:00, 11.11MB/s]:
#
#
# ████▉                           17% | 85.00/512.53 MB [00:06<00:37, 11.49MB/s]:
# ███████████████▏                51% | 260.00/512.5 MB [00:25<00:21, 11.86MB/s]:
#
# █████▎                          18% | 90.00/512.53 MB [00:07<00:36, 11.73MB/s]:
#
# █████▌                          19% | 95.00/512.53 MB [00:07<00:34, 11.95MB/s]:
# ███████████████▌                52% | 265.00/512.5 MB [00:25<00:22, 11.17MB/s]:
#
# █████▋                         20% | 100.00/512.53 MB [00:08<00:34, 12.12MB/s]:
# ███████████████▊                53% | 270.00/512.5 MB [00:26<00:21, 11.46MB/s]:
# ████████████████                54% | 275.00/512.5 MB [00:26<00:20, 11.69MB/s]:
#
# █████▉                         20% | 105.00/512.53 MB [00:08<00:36, 11.29MB/s]:
# ████████████████▍               55% | 280.00/512.5 MB [00:27<00:19, 11.82MB/s]:
#
# ██████▏                        21% | 110.00/512.53 MB [00:09<00:35, 11.46MB/s]:
# ████████████████▋               56% | 285.00/512.5 MB [00:27<00:19, 11.86MB/s]:
#
# ██████▌                        22% | 115.00/512.53 MB [00:09<00:34, 11.58MB/s]:
# ████████████████▉               57% | 290.00/512.5 MB [00:28<00:18, 11.88MB/s]:
#
# ██████▊                        23% | 120.00/512.53 MB [00:09<00:33, 11.79MB/s]:
#
# ███████                        24% | 125.00/512.53 MB [00:10<00:33, 11.69MB/s]:
# █████████████████▎              58% | 295.00/512.5 MB [00:28<00:19, 11.19MB/s]:
#
# ███████▎                       25% | 130.00/512.53 MB [00:10<00:32, 11.80MB/s]:
# █████████████████▌              59% | 300.00/512.5 MB [00:28<00:19, 11.13MB/s]:
#
# ███████▋                       26% | 135.00/512.53 MB [00:11<00:33, 11.24MB/s]:
# █████████████████▊              60% | 305.00/512.5 MB [00:29<00:18, 11.35MB/s]:
#
# ███████▉                       27% | 140.00/512.53 MB [00:11<00:32, 11.48MB/s]:
# ██████████████████▏             60% | 310.00/512.5 MB [00:29<00:17, 11.52MB/s]:
#
# ████████▏                      28% | 145.00/512.53 MB [00:12<00:31, 11.62MB/s]:
# ██████████████████▍             61% | 315.00/512.5 MB [00:30<00:16, 11.65MB/s]:
#
# ████████▍                      29% | 150.00/512.53 MB [00:12<00:30, 11.72MB/s]:
# ██████████████████▋             62% | 320.00/512.5 MB [00:30<00:16, 11.70MB/s]:
#
# ████████▊                      30% | 155.00/512.53 MB [00:12<00:30, 11.77MB/s]:
# ███████████████████             63% | 325.00/512.5 MB [00:31<00:16, 11.58MB/s]:
#
# █████████                      31% | 160.00/512.53 MB [00:13<00:29, 11.86MB/s]:
# ███████████████████▎            64% | 330.00/512.5 MB [00:31<00:16, 11.38MB/s]:
#
# █████████▎                     32% | 165.00/512.53 MB [00:13<00:30, 11.41MB/s]:
# ███████████████████▌            65% | 335.00/512.5 MB [00:31<00:15, 11.51MB/s]:
#
# █████████▌                     33% | 170.00/512.53 MB [00:14<00:29, 11.58MB/s]:
# ███████████████████▉            66% | 340.00/512.5 MB [00:32<00:14, 11.62MB/s]:
#
# █████████▉                     34% | 175.00/512.53 MB [00:14<00:28, 11.71MB/s]:
# ████████████████████▏           67% | 345.00/512.5 MB [00:32<00:14, 11.73MB/s]:
#
# ██████████▏                    35% | 180.00/512.53 MB [00:15<00:28, 11.78MB/s]:
# ████████████████████▍           68% | 350.00/512.5 MB [00:33<00:13, 11.77MB/s]:
#
# ██████████▍                    36% | 185.00/512.53 MB [00:15<00:27, 11.82MB/s]:
# ████████████████████▊           69% | 355.00/512.5 MB [00:33<00:13, 11.66MB/s]:
#
# ██████████▊                    37% | 190.00/512.53 MB [00:15<00:27, 11.84MB/s]:
# █████████████████████           70% | 360.00/512.5 MB [00:34<00:13, 11.41MB/s]:
#
# ███████████                    38% | 195.00/512.53 MB [00:16<00:27, 11.46MB/s]:
# █████████████████████▎          71% | 365.00/512.5 MB [00:34<00:12, 11.53MB/s]:
#
# ███████████▎                   39% | 200.00/512.53 MB [00:16<00:26, 11.60MB/s]:
# █████████████████████▋          72% | 370.00/512.5 MB [00:34<00:12, 11.63MB/s]:
#
# ███████████▌                   40% | 205.00/512.53 MB [00:17<00:26, 11.69MB/s]:
# █████████████████████▉          73% | 375.00/512.5 MB [00:35<00:11, 11.73MB/s]:
# Uploading dataset changes (6263 files compressed to 512.54 MiB) to https://files.clear.ml
# ███████████▉                   41% | 210.00/512.53 MB [00:21<01:31,  3.32MB/s]:
# ██████████████████████▏         74% | 380.00/512.5 MB [00:39<00:39,  3.35MB/s]:
#
# ████████████▏                  42% | 215.00/512.53 MB [00:21<01:10,  4.24MB/s]:
# ██████████████████████▌         75% | 385.00/512.5 MB [00:39<00:29,  4.27MB/s]:
#
# ████████████▍                  43% | 220.00/512.53 MB [00:22<00:55,  5.27MB/s]:
# ██████████████████████▊         76% | 390.00/512.5 MB [00:40<00:23,  5.31MB/s]:
#
# ████████████▋                  44% | 225.00/512.53 MB [00:22<00:45,  6.36MB/s]:
# ███████████████████████         77% | 395.00/512.5 MB [00:40<00:19,  6.15MB/s]:
#
# █████████████                  45% | 230.00/512.53 MB [00:22<00:38,  7.42MB/s]:
#                                            0% | 0.00/95.77 MB [00:00<?, ?MB/s]:
#
# █████████████▎                 46% | 235.00/512.53 MB [00:23<00:34,  8.03MB/s]:
# ███▏                             10% | 10.00/95.77 MB [00:00<00:03, 24.50MB/s]:
#
# █████████████▌                 47% | 240.00/512.53 MB [00:23<00:30,  8.94MB/s]:
# ████▊                            16% | 15.00/95.77 MB [00:00<00:04, 17.25MB/s]:
#
# █████████████▊                 48% | 245.00/512.53 MB [00:24<00:27,  9.69MB/s]:
# ██████▍                          21% | 20.00/95.77 MB [00:01<00:06, 12.53MB/s]:
#
# ██████████████▏                49% | 250.00/512.53 MB [00:24<00:25, 10.31MB/s]:
# ████████                         26% | 25.00/95.77 MB [00:01<00:05, 12.45MB/s]:
#
#
#                                           0% | 0.00/512.54 MB [00:00<?, ?MB/s]:
#
# ██████████████▍                50% | 255.00/512.53 MB [00:25<00:24, 10.61MB/s]:
# █████████▋                       31% | 30.00/95.77 MB [00:02<00:05, 12.41MB/s]:
#
#
# ▌                                2% | 10.00/512.54 MB [00:00<00:21, 23.55MB/s]:
#
# ██████████████▋                51% | 260.00/512.53 MB [00:25<00:23, 10.95MB/s]:
# ███████████▎                     37% | 35.00/95.77 MB [00:02<00:04, 12.38MB/s]:
#
# ██████████████▉                52% | 265.00/512.53 MB [00:25<00:22, 10.92MB/s]:
#
#
# ▉                                3% | 15.00/512.54 MB [00:00<00:34, 14.39MB/s]:
# ████████████▉                    42% | 40.00/95.77 MB [00:03<00:04, 12.27MB/s]:
#
# ███████████████▎               53% | 270.00/512.53 MB [00:26<00:21, 11.26MB/s]:
#
#
# █▏                               4% | 20.00/512.54 MB [00:01<00:36, 13.38MB/s]:
# ██████████████▌                  47% | 45.00/95.77 MB [00:03<00:04, 12.18MB/s]:
#
# ███████████████▌               54% | 275.00/512.53 MB [00:26<00:20, 11.43MB/s]:
#
#
# █▍                               5% | 25.00/512.54 MB [00:01<00:38, 12.73MB/s]:
# ████████████████▏                52% | 50.00/95.77 MB [00:04<00:04, 10.97MB/s]:
#
# ███████████████▊               55% | 280.00/512.53 MB [00:27<00:20, 11.53MB/s]:
#
#
# █▊                               6% | 30.00/512.54 MB [00:02<00:38, 12.47MB/s]:
# █████████████████▊               57% | 55.00/95.77 MB [00:04<00:03, 11.32MB/s]:
#
# ████████████████▏              56% | 285.00/512.53 MB [00:27<00:19, 11.62MB/s]:
#
#
# ██                               7% | 35.00/512.54 MB [00:02<00:38, 12.29MB/s]:
# ███████████████████▍             63% | 60.00/95.77 MB [00:04<00:03, 11.55MB/s]:
#
# ████████████████▍              57% | 290.00/512.53 MB [00:28<00:19, 11.65MB/s]:
#
#
# ██▎                              8% | 40.00/512.54 MB [00:03<00:38, 12.21MB/s]:
# █████████████████████            68% | 65.00/95.77 MB [00:05<00:02, 11.66MB/s]:
#
# ████████████████▋              58% | 295.00/512.53 MB [00:28<00:18, 11.46MB/s]:
#
#
# ██▋                              9% | 45.00/512.54 MB [00:03<00:41, 11.37MB/s]:
# ██████████████████████▋          73% | 70.00/95.77 MB [00:05<00:02, 11.73MB/s]:
#
# ████████████████▉              59% | 300.00/512.53 MB [00:28<00:18, 11.65MB/s]:
#
#
# ██▉                             10% | 50.00/512.54 MB [00:04<00:40, 11.35MB/s]:
# ████████████████████████▎        78% | 75.00/95.77 MB [00:06<00:01, 11.59MB/s]:
#
# █████████████████▎             60% | 305.00/512.53 MB [00:29<00:17, 11.69MB/s]:
# ███████████████████████████▊    93% | 475.00/512.5 MB [00:47<00:03, 11.66MB/s]:
#
#
# █████████████████████████▉       84% | 80.00/95.77 MB [00:06<00:01, 11.02MB/s]:
#
# █████████████████▌             60% | 310.00/512.53 MB [00:29<00:17, 11.72MB/s]:
# ████████████████████████████    94% | 480.00/512.5 MB [00:48<00:02, 11.76MB/s]:
#
#
# ███████████████████████████▌     89% | 85.00/95.77 MB [00:07<00:00, 11.28MB/s]:
#
# █████████████████▊             61% | 315.00/512.53 MB [00:30<00:17, 11.60MB/s]:
#
#
# ███▊                            13% | 65.00/512.54 MB [00:05<00:38, 11.70MB/s]:
# █████████████████████████████▏   94% | 90.00/95.77 MB [00:07<00:00, 11.45MB/s]:
#
# ██████████████████             62% | 320.00/512.53 MB [00:30<00:16, 11.61MB/s]:
#
#
# ████                            14% | 70.00/512.54 MB [00:05<00:37, 11.85MB/s]:
# ██████████████████████████████▊  99% | 95.00/95.77 MB [00:07<00:00, 11.66MB/s]:
#
# ██████████████████▍            63% | 325.00/512.53 MB [00:31<00:16, 11.58MB/s]:
# ████████████████████████████▉   97% | 495.00/512.5 MB [00:49<00:01, 11.55MB/s]:
#
#
# ████▍                           15% | 75.00/512.54 MB [00:06<00:38, 11.32MB/s]:
#
# ██████████████████▋            64% | 330.00/512.53 MB [00:31<00:15, 11.74MB/s]:
# █████████████████████████████▎  98% | 500.00/512.5 MB [00:49<00:01, 11.54MB/s]:
#
#
# ███████████████████████████████ 100% | 95.77/95.77 MB [00:08<00:00, 10.98MB/s]:
#
#
# ██████████████████▉            65% | 335.00/512.53 MB [00:31<00:15, 11.78MB/s]:
# █████████████████████████████▌  99% | 505.00/512.5 MB [00:50<00:00, 11.71MB/s]:
#
#
# ████▉                           17% | 85.00/512.54 MB [00:07<00:37, 11.38MB/s]:
#
# ███████████████████▏           66% | 340.00/512.53 MB [00:32<00:14, 11.78MB/s]:
# █████████████████████████████▊ 100% | 510.00/512.5 MB [00:50<00:00, 11.76MB/s]:
#
#
# █████▎                          18% | 90.00/512.54 MB [00:07<00:36, 11.55MB/s]:
# ██████████████████████████████ 100% | 512.50/512.5 MB [00:50<00:00, 11.55MB/s]:
#
# ███████████████████▌           67% | 345.00/512.53 MB [00:32<00:14, 11.64MB/s]:
#
#
# █████▌                          19% | 95.00/512.54 MB [00:07<00:35, 11.67MB/s]:
#
# ███████████████████▊           68% | 350.00/512.53 MB [00:33<00:13, 11.62MB/s]:
#
#
# █████▋                         20% | 100.00/512.54 MB [00:08<00:34, 11.83MB/s]:
#
# ████████████████████           69% | 355.00/512.53 MB [00:33<00:13, 11.58MB/s]:
#
#
# █████▉                         20% | 105.00/512.54 MB [00:08<00:35, 11.34MB/s]:
#
# ████████████████████▎          70% | 360.00/512.53 MB [00:34<00:13, 11.70MB/s]:
#
#
# ██████▏                        21% | 110.00/512.54 MB [00:09<00:35, 11.32MB/s]:
#
# ████████████████████▋          71% | 365.00/512.53 MB [00:34<00:12, 11.83MB/s]:
#
#
# ██████▌                        22% | 115.00/512.54 MB [00:09<00:34, 11.40MB/s]:
#
# ████████████████████▉          72% | 370.00/512.53 MB [00:34<00:12, 11.81MB/s]:
#
#
# ██████▊                        23% | 120.00/512.54 MB [00:10<00:34, 11.53MB/s]:
#
# █████████████████████▏         73% | 375.00/512.53 MB [00:35<00:11, 11.61MB/s]:
#
#
# ███████                        24% | 125.00/512.54 MB [00:10<00:33, 11.46MB/s]:
#
# █████████████████████▌         74% | 380.00/512.53 MB [00:35<00:11, 11.66MB/s]:
#
#
# ███████▎                       25% | 130.00/512.54 MB [00:10<00:32, 11.67MB/s]:
#
# █████████████████████▊         75% | 385.00/512.53 MB [00:36<00:10, 11.61MB/s]:
#
#
# ███████▋                       26% | 135.00/512.54 MB [00:11<00:32, 11.46MB/s]:
#
# ██████████████████████         76% | 390.00/512.53 MB [00:36<00:10, 11.66MB/s]:
#
#
# ███████▉                       27% | 140.00/512.54 MB [00:11<00:32, 11.41MB/s]:
#
# ██████████████████████▎        77% | 395.00/512.53 MB [00:37<00:09, 11.86MB/s]:
#
#
# ████████▏                      28% | 145.00/512.54 MB [00:12<00:32, 11.17MB/s]:
#
# ██████████████████████████████ 100% | 512.50/512.5 MB [00:55<00:00,  9.21MB/s]:
#
#
#
# ████████▍                      29% | 150.00/512.54 MB [00:12<00:31, 11.42MB/s]:
#
# ██████████████████████▉        79% | 405.00/512.53 MB [00:37<00:09, 11.72MB/s]:
#
#
# ████████▊                      30% | 155.00/512.54 MB [00:13<00:30, 11.63MB/s]:
#
# ███████████████████████▏       80% | 410.00/512.53 MB [00:38<00:08, 11.73MB/s]:
#
#
# █████████                      31% | 160.00/512.54 MB [00:13<00:29, 11.79MB/s]:
#
# ███████████████████████▍       81% | 415.00/512.53 MB [00:38<00:08, 11.68MB/s]:
#
#
# █████████▎                     32% | 165.00/512.54 MB [00:13<00:30, 11.54MB/s]:
#
# ███████████████████████▊       82% | 420.00/512.53 MB [00:39<00:07, 11.69MB/s]:
#
#
# █████████▌                     33% | 170.00/512.54 MB [00:14<00:29, 11.47MB/s]:
#
# ████████████████████████       83% | 425.00/512.53 MB [00:39<00:07, 11.89MB/s]:
#
#
# █████████▉                     34% | 175.00/512.54 MB [00:14<00:30, 11.21MB/s]:
#
# ████████████████████████▎      84% | 430.00/512.53 MB [00:40<00:07, 11.52MB/s]:
#
#
# ██████████▏                    35% | 180.00/512.54 MB [00:15<00:29, 11.46MB/s]:
#
# ████████████████████████▌      85% | 435.00/512.53 MB [00:40<00:06, 11.69MB/s]:
#
#
# ██████████▍                    36% | 185.00/512.54 MB [00:15<00:28, 11.60MB/s]:
#
# ████████████████████████▉      86% | 440.00/512.53 MB [00:40<00:06, 11.75MB/s]:
#
#
# ██████████▊                    37% | 190.00/512.54 MB [00:16<00:27, 11.65MB/s]:
#
# █████████████████████████▏     87% | 445.00/512.53 MB [00:41<00:05, 11.56MB/s]:
#
#
# ███████████                    38% | 195.00/512.54 MB [00:16<00:27, 11.60MB/s]:
#
# █████████████████████████▍     88% | 450.00/512.53 MB [00:41<00:05, 11.65MB/s]:
#
#
# ███████████▎                   39% | 200.00/512.54 MB [00:17<00:27, 11.50MB/s]:
#
# █████████████████████████▋     89% | 455.00/512.53 MB [00:42<00:04, 11.77MB/s]:
#
#
# ███████████▌                   40% | 205.00/512.54 MB [00:17<00:27, 11.24MB/s]:
#
# ██████████████████████████     90% | 460.00/512.53 MB [00:42<00:04, 11.61MB/s]:
#
#
# ███████████▉                   41% | 210.00/512.54 MB [00:17<00:26, 11.42MB/s]:
#
# ██████████████████████████▎    91% | 465.00/512.53 MB [00:43<00:04, 11.75MB/s]:
#
#
# ████████████▏                  42% | 215.00/512.54 MB [00:18<00:25, 11.55MB/s]:
#
# ██████████████████████████▌    92% | 470.00/512.53 MB [00:43<00:03, 11.79MB/s]:
#
#
# ████████████▍                  43% | 220.00/512.54 MB [00:18<00:25, 11.69MB/s]:
#
# ██████████████████████████▉    93% | 475.00/512.53 MB [00:43<00:03, 11.61MB/s]:
#
#
# ████████████▋                  44% | 225.00/512.54 MB [00:19<00:24, 11.63MB/s]:
#
# ███████████████████████████▏   94% | 480.00/512.53 MB [00:44<00:02, 11.66MB/s]:
#
#
# █████████████                  45% | 230.00/512.54 MB [00:19<00:24, 11.52MB/s]:
#
# ███████████████████████████▍   95% | 485.00/512.53 MB [00:44<00:02, 11.73MB/s]:
#
#
# █████████████▎                 46% | 235.00/512.54 MB [00:20<00:24, 11.24MB/s]:
#
# ███████████████████████████▋   96% | 490.00/512.53 MB [00:45<00:01, 11.59MB/s]:
#
#
# █████████████▌                 47% | 240.00/512.54 MB [00:20<00:23, 11.43MB/s]:
#
# ████████████████████████████   97% | 495.00/512.53 MB [00:45<00:01, 11.73MB/s]:
#
#
# █████████████▊                 48% | 245.00/512.54 MB [00:20<00:23, 11.56MB/s]:
#
# ████████████████████████████▎  98% | 500.00/512.53 MB [00:46<00:01, 11.82MB/s]:
#
#
# ██████████████▏                49% | 250.00/512.54 MB [00:21<00:22, 11.60MB/s]:
#
# ████████████████████████████▌  99% | 505.00/512.53 MB [00:46<00:00, 11.64MB/s]:
#
#
# ██████████████▍                50% | 255.00/512.54 MB [00:21<00:22, 11.53MB/s]:
#
# ████████████████████████████▊ 100% | 510.00/512.53 MB [00:46<00:00, 11.69MB/s]:
#
# ████████████████████████████▉ 100% | 512.52/512.53 MB [00:47<00:00, 11.73MB/s]:
#
#
# ██████████████▋                51% | 260.00/512.54 MB [00:22<00:21, 11.60MB/s]:
#
#
# ██████████████▉                52% | 265.00/512.54 MB [00:22<00:21, 11.30MB/s]:
#
#
# ███████████████▎               53% | 270.00/512.54 MB [00:23<00:21, 11.47MB/s]:
#
#
# ███████████████▌               54% | 275.00/512.54 MB [00:23<00:20, 11.59MB/s]:
#
#
# ███████████████▊               55% | 280.00/512.54 MB [00:23<00:20, 11.62MB/s]:
#
#
# ████████████████▏              56% | 285.00/512.54 MB [00:24<00:19, 11.54MB/s]:
#
#
# ████████████████▍              57% | 290.00/512.54 MB [00:24<00:19, 11.61MB/s]:
#
#
# ████████████████▋              58% | 295.00/512.54 MB [00:25<00:19, 11.31MB/s]:
#
#
# ████████████████▉              59% | 300.00/512.54 MB [00:25<00:18, 11.48MB/s]:
#
#
# █████████████████▎             60% | 305.00/512.54 MB [00:26<00:17, 11.59MB/s]:
#
#
# █████████████████████████████ 100% | 512.53/512.53 MB [00:51<00:00,  9.88MB/s]:
#
#
#
# █████████████████▊             61% | 315.00/512.54 MB [00:27<00:17, 11.54MB/s]:
#
#
# ██████████████████             62% | 320.00/512.54 MB [00:27<00:16, 11.61MB/s]:
#
#
# ██████████████████▍            63% | 325.00/512.54 MB [00:27<00:16, 11.28MB/s]:
#
#
# ██████████████████▋            64% | 330.00/512.54 MB [00:28<00:15, 11.49MB/s]:
#
#
# ██████████████████▉            65% | 335.00/512.54 MB [00:28<00:15, 11.59MB/s]:
#
#
# ███████████████████▏           66% | 340.00/512.54 MB [00:29<00:14, 11.62MB/s]:
#
#
# ███████████████████▌           67% | 345.00/512.54 MB [00:29<00:14, 11.54MB/s]:
#
#
# ███████████████████▊           68% | 350.00/512.54 MB [00:30<00:13, 11.61MB/s]:
#
#
# ████████████████████           69% | 355.00/512.54 MB [00:30<00:13, 11.29MB/s]:
#
#
# ████████████████████▎          70% | 360.00/512.54 MB [00:30<00:13, 11.49MB/s]:
#
#
# ████████████████████▋          71% | 365.00/512.54 MB [00:31<00:12, 11.59MB/s]:
#
#
# ████████████████████▉          72% | 370.00/512.54 MB [00:31<00:12, 11.60MB/s]:
#
#
# █████████████████████▏         73% | 375.00/512.54 MB [00:32<00:11, 11.54MB/s]:
#
#
# █████████████████████▌         74% | 380.00/512.54 MB [00:32<00:11, 11.59MB/s]:
#
#
# █████████████████████▊         75% | 385.00/512.54 MB [00:33<00:11, 11.29MB/s]:
#
#
# ██████████████████████         76% | 390.00/512.54 MB [00:33<00:10, 11.49MB/s]:
#
#
# ██████████████████████▎        77% | 395.00/512.54 MB [00:33<00:10, 11.58MB/s]:
#
#
# ██████████████████████▋        78% | 400.00/512.54 MB [00:34<00:09, 11.60MB/s]:
#
#
# ██████████████████████▉        79% | 405.00/512.54 MB [00:34<00:09, 11.53MB/s]:
#
#
# ███████████████████████▏       80% | 410.00/512.54 MB [00:35<00:09, 11.39MB/s]:
#
#
# ███████████████████████▍       81% | 415.00/512.54 MB [00:35<00:08, 11.37MB/s]:
#
#
# ███████████████████████▊       82% | 420.00/512.54 MB [00:36<00:08, 11.54MB/s]:
#
#
# ████████████████████████       83% | 425.00/512.54 MB [00:36<00:07, 11.61MB/s]:
#
#
# ████████████████████████▎      84% | 430.00/512.54 MB [00:37<00:07, 11.63MB/s]:
#
#
# ████████████████████████▌      85% | 435.00/512.54 MB [00:37<00:06, 11.55MB/s]:
#
#
# ████████████████████████▉      86% | 440.00/512.54 MB [00:37<00:06, 11.38MB/s]:
#
#
# █████████████████████████▏     87% | 445.00/512.54 MB [00:38<00:05, 11.38MB/s]:
#
#
# █████████████████████████▍     88% | 450.00/512.54 MB [00:38<00:05, 11.54MB/s]:
#
#
# █████████████████████████▋     89% | 455.00/512.54 MB [00:39<00:04, 11.61MB/s]:
#
#
# ██████████████████████████     90% | 460.00/512.54 MB [00:39<00:04, 11.63MB/s]:
#
#
# ██████████████████████████▎    91% | 465.00/512.54 MB [00:40<00:04, 11.56MB/s]:
#
#
# ██████████████████████████▌    92% | 470.00/512.54 MB [00:40<00:03, 11.39MB/s]:
#
#
# ██████████████████████████▉    93% | 475.00/512.54 MB [00:40<00:03, 11.38MB/s]:
#
#
# ███████████████████████████▏   94% | 480.00/512.54 MB [00:41<00:02, 11.52MB/s]:
#
#
# ███████████████████████████▍   95% | 485.00/512.54 MB [00:41<00:02, 11.62MB/s]:
#
#
# ███████████████████████████▋   96% | 490.00/512.54 MB [00:42<00:01, 11.63MB/s]:
#
#
# ████████████████████████████   97% | 495.00/512.54 MB [00:42<00:01, 10.14MB/s]:
#
#
# ████████████████████████████▎  98% | 500.00/512.54 MB [00:43<00:01,  9.74MB/s]:
# Uploading dataset changes (6164 files compressed to 512.5 MiB) to https://files.clear.ml
# ████████████████████████████▌  99% | 505.00/512.54 MB [00:47<00:02,  3.33MB/s]:
#
#
# ████████████████████████████▊ 100% | 510.00/512.54 MB [00:47<00:00,  4.26MB/s]:
#
#
# ██████▌                          21% | 20.00/95.21 MB [00:01<00:06, 12.52MB/s]:
# ████████▏                        26% | 25.00/95.21 MB [00:01<00:05, 12.46MB/s]:
# █████████▊                       32% | 30.00/95.21 MB [00:02<00:05, 12.39MB/s]:
# █████████████                    42% | 40.00/95.21 MB [00:03<00:04, 12.36MB/s]:
# ██████████████▋                  47% | 45.00/95.21 MB [00:03<00:04, 12.35MB/s]:
# █████████████████████████████ 100% | 512.54/512.54 MB [00:52<00:00,  9.71MB/s]:
#
# ████████████████▎                53% | 50.00/95.21 MB [00:04<00:04, 10.88MB/s]:
# █████████████████▉               58% | 55.00/95.21 MB [00:04<00:03, 11.28MB/s]:
# █████████████████████▏           68% | 65.00/95.21 MB [00:05<00:02, 11.79MB/s]:
# ██████████████████████▊          74% | 70.00/95.21 MB [00:05<00:02, 11.95MB/s]:
# ███                              10% | 50.00/512.5 MB [00:03<00:39, 11.63MB/s]:
# ████████████████████████▍        79% | 75.00/95.21 MB [00:06<00:01, 10.75MB/s]:
# ██████████████████████████       84% | 80.00/95.21 MB [00:06<00:01, 11.13MB/s]:
# ███████████████████████████▋     89% | 85.00/95.21 MB [00:07<00:00, 11.43MB/s]:
# █████████████████████████████▎   95% | 90.00/95.21 MB [00:07<00:00, 11.57MB/s]:
# ██████████████████████████████▉ 100% | 95.00/95.21 MB [00:07<00:00, 11.73MB/s]:
# ███████████████████████████████ 100% | 95.21/95.21 MB [00:08<00:00, 11.19MB/s]:
#
# █████▏                           17% | 85.00/512.5 MB [00:06<00:36, 11.75MB/s]:
# █████▍                           18% | 90.00/512.5 MB [00:07<00:35, 11.93MB/s]:
# █████▋                           19% | 95.00/512.5 MB [00:07<00:34, 12.09MB/s]:
# █████▊                          20% | 100.00/512.5 MB [00:08<00:33, 12.18MB/s]:
# ██████▏                         20% | 105.00/512.5 MB [00:08<00:36, 11.15MB/s]:
# ██████▍                         21% | 110.00/512.5 MB [00:09<00:35, 11.47MB/s]:
# ██████▋                         22% | 115.00/512.5 MB [00:09<00:33, 11.75MB/s]:
# ███████                         23% | 120.00/512.5 MB [00:09<00:32, 11.94MB/s]:
# ███████▎                        24% | 125.00/512.5 MB [00:10<00:32, 12.09MB/s]:
# ███████▌                        25% | 130.00/512.5 MB [00:10<00:31, 12.04MB/s]:
# ███████▉                        26% | 135.00/512.5 MB [00:11<00:33, 11.13MB/s]:
# ████████▏                       27% | 140.00/512.5 MB [00:11<00:32, 11.46MB/s]:
# ████████▍                       28% | 145.00/512.5 MB [00:11<00:31, 11.71MB/s]:
# ████████▊                       29% | 150.00/512.5 MB [00:12<00:30, 11.90MB/s]:
# █████████                       30% | 155.00/512.5 MB [00:12<00:29, 12.02MB/s]:
# █████████▎                      31% | 160.00/512.5 MB [00:13<00:29, 12.11MB/s]:
# █████████▋                      32% | 165.00/512.5 MB [00:13<00:31, 11.18MB/s]:
# █████████▉                      33% | 170.00/512.5 MB [00:14<00:29, 11.49MB/s]:
# ██████████▏                     34% | 175.00/512.5 MB [00:14<00:28, 11.74MB/s]:
# ██████████▌                     35% | 180.00/512.5 MB [00:14<00:27, 11.91MB/s]:
# ██████████▊                     36% | 185.00/512.5 MB [00:15<00:27, 12.02MB/s]:
# ███████████                     37% | 190.00/512.5 MB [00:15<00:26, 12.12MB/s]:
# ███████████▍                    38% | 195.00/512.5 MB [00:16<00:28, 11.20MB/s]:
# ███████████▋                    39% | 200.00/512.5 MB [00:16<00:27, 11.50MB/s]:
# ████████████                    40% | 205.00/512.5 MB [00:17<00:26, 11.72MB/s]:
# ████████████▎                   41% | 210.00/512.5 MB [00:17<00:25, 11.88MB/s]:
# ████████████▌                   42% | 215.00/512.5 MB [00:17<00:24, 12.01MB/s]:
# ████████████▉                   43% | 220.00/512.5 MB [00:18<00:24, 12.05MB/s]:
# █████████████▏                  44% | 225.00/512.5 MB [00:18<00:25, 11.25MB/s]:
# █████████████▍                  45% | 230.00/512.5 MB [00:19<00:24, 11.53MB/s]:
# █████████████▊                  46% | 235.00/512.5 MB [00:19<00:23, 11.74MB/s]:
# ██████████████                  47% | 240.00/512.5 MB [00:20<00:22, 11.85MB/s]:
# ██████████████▎                 48% | 245.00/512.5 MB [00:20<00:22, 11.97MB/s]:
# ██████████████▋                 49% | 250.00/512.5 MB [00:20<00:21, 12.06MB/s]:
# ██████████████▉                 50% | 255.00/512.5 MB [00:21<00:22, 11.29MB/s]:
# ███████████████▏                51% | 260.00/512.5 MB [00:21<00:21, 11.55MB/s]:
# ███████████████▌                52% | 265.00/512.5 MB [00:22<00:21, 11.76MB/s]:
# ███████████████▊                53% | 270.00/512.5 MB [00:22<00:20, 11.86MB/s]:
# ████████████████                54% | 275.00/512.5 MB [00:23<00:19, 11.97MB/s]:
# ████████████████▍               55% | 280.00/512.5 MB [00:23<00:19, 12.06MB/s]:
# ████████████████▋               56% | 285.00/512.5 MB [00:23<00:20, 11.26MB/s]:
# ████████████████▉               57% | 290.00/512.5 MB [00:24<00:19, 11.53MB/s]:
# █████████████████▎              58% | 295.00/512.5 MB [00:24<00:18, 11.76MB/s]:
# █████████████████▌              59% | 300.00/512.5 MB [00:25<00:17, 11.88MB/s]:
# █████████████████▊              60% | 305.00/512.5 MB [00:25<00:17, 11.97MB/s]:
# ██████████████████▏             60% | 310.00/512.5 MB [00:26<00:16, 12.06MB/s]:
# ██████████████████▍             61% | 315.00/512.5 MB [00:26<00:17, 11.27MB/s]:
# ██████████████████▋             62% | 320.00/512.5 MB [00:26<00:16, 11.54MB/s]:
# ███████████████████             63% | 325.00/512.5 MB [00:27<00:15, 11.74MB/s]:
# ███████████████████▎            64% | 330.00/512.5 MB [00:27<00:15, 11.90MB/s]:
# ███████████████████▌            65% | 335.00/512.5 MB [00:28<00:14, 11.98MB/s]:
# ███████████████████▉            66% | 340.00/512.5 MB [00:28<00:15, 11.50MB/s]:
# ████████████████████▏           67% | 345.00/512.5 MB [00:29<00:14, 11.43MB/s]:
# ████████████████████▍           68% | 350.00/512.5 MB [00:29<00:13, 11.66MB/s]:
# ████████████████████▊           69% | 355.00/512.5 MB [00:29<00:13, 11.81MB/s]:
# █████████████████████           70% | 360.00/512.5 MB [00:30<00:12, 11.88MB/s]:
# █████████████████████▎          71% | 365.00/512.5 MB [00:30<00:12, 12.02MB/s]:
# █████████████████████▋          72% | 370.00/512.5 MB [00:31<00:12, 11.54MB/s]:
# █████████████████████▉          73% | 375.00/512.5 MB [00:31<00:11, 11.47MB/s]:
# ██████████████████████▏         74% | 380.00/512.5 MB [00:32<00:11, 11.69MB/s]:
# ██████████████████████▌         75% | 385.00/512.5 MB [00:32<00:10, 11.79MB/s]:
# ██████████████████████▊         76% | 390.00/512.5 MB [00:32<00:10, 11.90MB/s]:
# Uploading dataset changes (8317 files compressed to 512.67 MiB) to https://files.clear.ml
# ███████████████████████         77% | 395.00/512.5 MB [00:36<00:34,  3.39MB/s]:
# ███████████████████████▍        78% | 400.00/512.5 MB [00:37<00:26,  4.32MB/s]:
# ███████████████████████▋        79% | 405.00/512.5 MB [00:37<00:20,  5.37MB/s]:
# ████████████████████████        80% | 410.00/512.5 MB [00:38<00:15,  6.47MB/s]:
#                                            0% | 0.00/94.46 MB [00:00<?, ?MB/s]:
# ███▎                             11% | 10.00/94.46 MB [00:00<00:03, 24.42MB/s]:
# ████▉                            16% | 15.00/94.46 MB [00:00<00:04, 17.32MB/s]:
# █████████████████████████▏      84% | 430.00/512.5 MB [00:39<00:08,  9.75MB/s]:
#
#                                           0% | 0.00/512.67 MB [00:00<?, ?MB/s]:
# ██████▌                          21% | 20.00/94.46 MB [00:01<00:05, 12.55MB/s]:
#
# ▌                                2% | 10.00/512.67 MB [00:00<00:20, 24.92MB/s]:
# ████████▏                        26% | 25.00/94.46 MB [00:01<00:05, 12.48MB/s]:
#
# ▉                                3% | 15.00/512.67 MB [00:00<00:28, 17.55MB/s]:
# █████████▊                       32% | 30.00/94.46 MB [00:02<00:05, 12.42MB/s]:
#
# ███████████▍                     37% | 35.00/94.46 MB [00:02<00:04, 12.39MB/s]:
# ██████████████████████████▎     88% | 450.00/512.5 MB [00:41<00:05, 10.70MB/s]:
#
# █████████████▏                   42% | 40.00/94.46 MB [00:03<00:04, 12.32MB/s]:
# ██████████████████████████▋     89% | 455.00/512.5 MB [00:41<00:05, 11.12MB/s]:
#
# ██████████████▊                  48% | 45.00/94.46 MB [00:03<00:04, 12.23MB/s]:
# ██████████████████████████▉     90% | 460.00/512.5 MB [00:42<00:04, 11.44MB/s]:
#
# ██                               7% | 35.00/512.67 MB [00:02<00:38, 12.52MB/s]:
# ████████████████▍                53% | 50.00/94.46 MB [00:04<00:04, 10.92MB/s]:
#
# ██▎                              8% | 40.00/512.67 MB [00:02<00:37, 12.47MB/s]:
# ██████████████████               58% | 55.00/94.46 MB [00:04<00:03, 11.27MB/s]:
#
# ██▋                              9% | 45.00/512.67 MB [00:03<00:37, 12.40MB/s]:
# ███████████████████▋             64% | 60.00/94.46 MB [00:04<00:02, 11.52MB/s]:
#
# ██▉                             10% | 50.00/512.67 MB [00:03<00:41, 11.09MB/s]:
# █████████████████████▎           69% | 65.00/94.46 MB [00:05<00:02, 11.68MB/s]:
#
# ███▏                            11% | 55.00/512.67 MB [00:04<00:39, 11.47MB/s]:
# ██████████████████████▉          74% | 70.00/94.46 MB [00:05<00:02, 11.86MB/s]:
#
# ███▌                            12% | 60.00/512.67 MB [00:04<00:38, 11.76MB/s]:
# ████████████████████████▌        79% | 75.00/94.46 MB [00:06<00:01, 10.84MB/s]:
#
# ███▊                            13% | 65.00/512.67 MB [00:05<00:37, 11.95MB/s]:
# ██████████████████████████▎      85% | 80.00/94.46 MB [00:06<00:01, 11.20MB/s]:
#
# ████                            14% | 70.00/512.67 MB [00:05<00:36, 12.09MB/s]:
# ███████████████████████████▉     90% | 85.00/94.46 MB [00:07<00:00, 11.47MB/s]:
#
# ████▍                           15% | 75.00/512.67 MB [00:06<00:37, 11.78MB/s]:
# █████████████████████████████▌   95% | 90.00/94.46 MB [00:07<00:00, 11.67MB/s]:
#
# ████▋                           16% | 80.00/512.67 MB [00:06<00:39, 11.05MB/s]:
# ██████████████████████████████▉ 100% | 94.45/94.46 MB [00:07<00:00, 11.54MB/s]:
# █████████████████████████████▉ 100% | 512.49/512.5 MB [00:46<00:00, 11.63MB/s]:
#
# ████▉                           17% | 85.00/512.67 MB [00:06<00:37, 11.43MB/s]:
#
# █████▎                          18% | 90.00/512.67 MB [00:07<00:36, 11.73MB/s]:
#
# ███████████████████████████████ 100% | 94.46/94.46 MB [00:08<00:00, 10.57MB/s]:
#
#
# █████▋                         20% | 100.00/512.67 MB [00:08<00:34, 12.07MB/s]:
#
# █████▉                         20% | 105.00/512.67 MB [00:08<00:37, 10.91MB/s]:
#
# ██████▏                        21% | 110.00/512.67 MB [00:09<00:35, 11.31MB/s]:
#
# ██████▌                        22% | 115.00/512.67 MB [00:09<00:34, 11.63MB/s]:
#
# ██████▊                        23% | 120.00/512.67 MB [00:09<00:33, 11.85MB/s]:
#
# ███████                        24% | 125.00/512.67 MB [00:10<00:32, 12.02MB/s]:
#
# ███████▎                       25% | 130.00/512.67 MB [00:10<00:31, 12.14MB/s]:
#
# ███████▋                       26% | 135.00/512.67 MB [00:11<00:34, 10.95MB/s]:
# Uploading dataset changes (8324 files compressed to 512.65 MiB) to https://files.clear.ml
# ██████████████████████████████ 100% | 512.50/512.5 MB [00:52<00:00,  9.83MB/s]:
#
#
# ███████▉                       27% | 140.00/512.67 MB [00:14<01:46,  3.50MB/s]:
#
# ████████▏                      28% | 145.00/512.67 MB [00:15<01:23,  4.41MB/s]:
#
# ████████▍                      29% | 150.00/512.67 MB [00:15<01:09,  5.25MB/s]:
#
# ████████▊                      30% | 155.00/512.67 MB [00:16<00:56,  6.34MB/s]:
#
#                                             0% | 0.00/93.7 MB [00:00<?, ?MB/s]:
#
# ███▍                              11% | 10.00/93.7 MB [00:00<00:03, 24.05MB/s]:
#
# █████                             16% | 15.00/93.7 MB [00:00<00:04, 17.01MB/s]:
#
# █████████▉                     34% | 175.00/512.67 MB [00:18<00:33,  9.94MB/s]:
# ██████▊                           21% | 20.00/93.7 MB [00:01<00:05, 12.60MB/s]:
#
# ██████████▏                    35% | 180.00/512.67 MB [00:18<00:33,  9.87MB/s]:
# ████████▌                         27% | 25.00/93.7 MB [00:01<00:05, 12.27MB/s]:
#
# ██████████▍                    36% | 185.00/512.67 MB [00:18<00:31, 10.49MB/s]:
# ██████████▏                       32% | 30.00/93.7 MB [00:02<00:05, 12.26MB/s]:
#
# ██████████▋                    37% | 190.00/512.67 MB [00:19<00:29, 10.91MB/s]:
# ███████████▉                      37% | 35.00/93.7 MB [00:02<00:04, 12.28MB/s]:
#
# ███████████                    38% | 195.00/512.67 MB [00:19<00:28, 11.19MB/s]:
# █████████████▋                    43% | 40.00/93.7 MB [00:03<00:04, 12.29MB/s]:
#
# ███████████▎                   39% | 200.00/512.67 MB [00:20<00:27, 11.37MB/s]:
# ███████████████▎                  48% | 45.00/93.7 MB [00:03<00:03, 12.31MB/s]:
#
# ███████████▌                   40% | 205.00/512.67 MB [00:20<00:28, 10.90MB/s]:
# █████████████████                 53% | 50.00/93.7 MB [00:04<00:03, 10.95MB/s]:
#
# ███████████▉                   41% | 210.00/512.67 MB [00:21<00:26, 11.29MB/s]:
# ██████████████████▊               59% | 55.00/93.7 MB [00:04<00:03, 11.25MB/s]:
#
# ████████████▏                  42% | 215.00/512.67 MB [00:21<00:25, 11.58MB/s]:
# ████████████████████▍             64% | 60.00/93.7 MB [00:04<00:02, 11.55MB/s]:
#
# ████████████▍                  43% | 220.00/512.67 MB [00:21<00:25, 11.70MB/s]:
# ██████████████████████▏           69% | 65.00/93.7 MB [00:05<00:02, 11.77MB/s]:
#
# ████████████▋                  44% | 225.00/512.67 MB [00:22<00:24, 11.76MB/s]:
# ███████████████████████▉          75% | 70.00/93.7 MB [00:05<00:01, 11.93MB/s]:
#
# █████████████                  45% | 230.00/512.67 MB [00:22<00:24, 11.75MB/s]:
# █████████████████████████▌        80% | 75.00/93.7 MB [00:06<00:01, 12.05MB/s]:
#
# █████████████▎                 46% | 235.00/512.67 MB [00:23<00:24, 11.17MB/s]:
# ███████████████████████████▎      85% | 80.00/93.7 MB [00:06<00:01, 10.83MB/s]:
#
# █████████████▌                 47% | 240.00/512.67 MB [00:23<00:23, 11.50MB/s]:
# █████████████████████████████     91% | 85.00/93.7 MB [00:07<00:00, 11.18MB/s]:
#
# █████████████▊                 48% | 245.00/512.67 MB [00:24<00:22, 11.72MB/s]:
# ██████████████████████████████▋   96% | 90.00/93.7 MB [00:07<00:00, 11.50MB/s]:
#
# ██████████████▏                49% | 250.00/512.67 MB [00:24<00:22, 11.81MB/s]:
# ████████████████████████████████ 100% | 93.70/93.7 MB [00:07<00:00, 11.09MB/s]:
#
# ██████████████▍                50% | 255.00/512.67 MB [00:24<00:21, 11.84MB/s]:
# ████▉                           17% | 85.00/512.65 MB [00:07<00:37, 11.30MB/s]:
#
# ████████████████████████████████ 100% | 93.70/93.7 MB [00:08<00:00, 11.12MB/s]:
#
# █████▎                          18% | 90.00/512.65 MB [00:07<00:36, 11.57MB/s]:
#
# ██████████████▉                52% | 265.00/512.67 MB [00:25<00:22, 11.20MB/s]:
# █████▌                          19% | 95.00/512.65 MB [00:07<00:35, 11.73MB/s]:
#
# ███████████████▎               53% | 270.00/512.67 MB [00:26<00:21, 11.52MB/s]:
# █████▋                         20% | 100.00/512.65 MB [00:08<00:34, 11.83MB/s]:
#
# ███████████████▌               54% | 275.00/512.67 MB [00:26<00:20, 11.75MB/s]:
# █████▉                         20% | 105.00/512.65 MB [00:08<00:37, 10.91MB/s]:
#
# ███████████████▊               55% | 280.00/512.67 MB [00:27<00:19, 11.82MB/s]:
# ██████▏                        21% | 110.00/512.65 MB [00:09<00:35, 11.22MB/s]:
#
# ████████████████               56% | 285.00/512.67 MB [00:27<00:19, 11.85MB/s]:
# ██████▌                        22% | 115.00/512.65 MB [00:09<00:34, 11.49MB/s]:
#
# ████████████████▍              57% | 290.00/512.67 MB [00:27<00:18, 11.79MB/s]:
# ██████▊                        23% | 120.00/512.65 MB [00:10<00:33, 11.72MB/s]:
#
# ████████████████▋              58% | 295.00/512.67 MB [00:28<00:19, 11.21MB/s]:
# ███████                        24% | 125.00/512.65 MB [00:10<00:32, 11.84MB/s]:
#
# ████████████████▉              59% | 300.00/512.67 MB [00:28<00:18, 11.53MB/s]:
# ███████▎                       25% | 130.00/512.65 MB [00:10<00:32, 11.90MB/s]:
#
# █████████████████▎             59% | 305.00/512.67 MB [00:29<00:17, 11.69MB/s]:
# ███████▋                       26% | 135.00/512.65 MB [00:11<00:34, 10.95MB/s]:
#
# █████████████████▌             60% | 310.00/512.67 MB [00:29<00:17, 11.83MB/s]:
# ███████▉                       27% | 140.00/512.65 MB [00:11<00:33, 11.25MB/s]:
#
# █████████████████▊             61% | 315.00/512.67 MB [00:30<00:16, 11.81MB/s]:
# ████████▏                      28% | 145.00/512.65 MB [00:12<00:31, 11.50MB/s]:
#
# ██████████████████             62% | 320.00/512.67 MB [00:30<00:16, 11.58MB/s]:
# ████████▍                      29% | 150.00/512.65 MB [00:12<00:31, 11.68MB/s]:
#
# ██████████████████▍            63% | 325.00/512.67 MB [00:30<00:16, 11.26MB/s]:
# ████████▊                      30% | 155.00/512.65 MB [00:13<00:30, 11.70MB/s]:
#
# ██████████████████▋            64% | 330.00/512.67 MB [00:31<00:15, 11.43MB/s]:
# █████████                      31% | 160.00/512.65 MB [00:13<00:30, 11.74MB/s]:
#
# ██████████████████▉            65% | 335.00/512.67 MB [00:31<00:15, 11.57MB/s]:
# █████████▎                     32% | 165.00/512.65 MB [00:13<00:31, 11.04MB/s]:
#
# ███████████████████▏           66% | 340.00/512.67 MB [00:32<00:14, 11.69MB/s]:
# █████████▌                     33% | 170.00/512.65 MB [00:14<00:30, 11.31MB/s]:
#
# ███████████████████▌           67% | 345.00/512.67 MB [00:32<00:14, 11.86MB/s]:
# █████████▉                     34% | 175.00/512.65 MB [00:14<00:29, 11.52MB/s]:
#
# ███████████████████▊           68% | 350.00/512.67 MB [00:33<00:13, 11.72MB/s]:
# ██████████▏                    35% | 180.00/512.65 MB [00:15<00:28, 11.63MB/s]:
#
# ████████████████████           69% | 355.00/512.67 MB [00:33<00:13, 11.35MB/s]:
# ██████████▍                    36% | 185.00/512.65 MB [00:15<00:28, 11.69MB/s]:
#
# ████████████████████▎          70% | 360.00/512.67 MB [00:33<00:13, 11.49MB/s]:
# ██████████▋                    37% | 190.00/512.65 MB [00:16<00:27, 11.74MB/s]:
#
# ████████████████████▋          71% | 365.00/512.67 MB [00:34<00:12, 11.61MB/s]:
# ███████████                    38% | 195.00/512.65 MB [00:16<00:28, 11.09MB/s]:
#
# ████████████████████▉          72% | 370.00/512.67 MB [00:34<00:12, 11.70MB/s]:
# ███████████▎                   39% | 200.00/512.65 MB [00:17<00:27, 11.33MB/s]:
#
# █████████████████████▏         73% | 375.00/512.67 MB [00:35<00:11, 11.76MB/s]:
# ███████████▌                   40% | 205.00/512.65 MB [00:17<00:26, 11.47MB/s]:
#
# █████████████████████▍         74% | 380.00/512.67 MB [00:35<00:11, 11.79MB/s]:
# ███████████▉                   41% | 210.00/512.65 MB [00:17<00:26, 11.58MB/s]:
#
# █████████████████████▊         75% | 385.00/512.67 MB [00:36<00:11, 11.38MB/s]:
# ████████████▏                  42% | 215.00/512.65 MB [00:18<00:25, 11.66MB/s]:
#
# ██████████████████████         76% | 390.00/512.67 MB [00:36<00:10, 11.50MB/s]:
# ████████████▍                  43% | 220.00/512.65 MB [00:18<00:24, 11.72MB/s]:
#
# ██████████████████████▎        77% | 395.00/512.67 MB [00:36<00:10, 11.61MB/s]:
# ████████████▋                  44% | 225.00/512.65 MB [00:19<00:25, 11.17MB/s]:
#
# ██████████████████████▋        78% | 400.00/512.67 MB [00:37<00:09, 11.68MB/s]:
# Uploading dataset changes (8591 files compressed to 512.66 MiB) to https://files.clear.ml
# █████████████                  45% | 230.00/512.65 MB [00:23<01:22,  3.44MB/s]:
#
# ██████████████████████▉        79% | 405.00/512.67 MB [00:41<00:31,  3.42MB/s]:
# █████████████▎                 46% | 235.00/512.65 MB [00:23<01:03,  4.37MB/s]:
#
# ███████████████████████▏       80% | 410.00/512.67 MB [00:41<00:23,  4.36MB/s]:
# █████████████▌                 47% | 240.00/512.65 MB [00:23<00:52,  5.23MB/s]:
#
# ███████████████████████▍       81% | 415.00/512.67 MB [00:42<00:18,  5.39MB/s]:
# █████████████▊                 48% | 245.00/512.65 MB [00:24<00:42,  6.30MB/s]:
#
# ███████████████████████▊       82% | 420.00/512.67 MB [00:42<00:14,  6.46MB/s]:
# ██████████████▏                49% | 250.00/512.65 MB [00:24<00:36,  7.28MB/s]:
#
#                                            0% | 0.00/92.92 MB [00:00<?, ?MB/s]:
# ██████████████▍                50% | 255.00/512.65 MB [00:25<00:31,  8.23MB/s]:
#
# ███▎                             11% | 10.00/92.92 MB [00:00<00:03, 23.82MB/s]:
# ██████████████▋                51% | 260.00/512.65 MB [00:25<00:28,  8.99MB/s]:
#
# █████                            16% | 15.00/92.92 MB [00:00<00:04, 17.09MB/s]:
# ██████████████▉                52% | 265.00/512.65 MB [00:26<00:25,  9.64MB/s]:
#
# ████████████████████████▉      86% | 440.00/512.67 MB [00:44<00:07,  9.70MB/s]:
#
#
# ██████▋                          22% | 20.00/92.92 MB [00:01<00:05, 12.68MB/s]:
# ███████████████▎               53% | 270.00/512.65 MB [00:26<00:24,  9.97MB/s]:
#
# █████████████████████████▏     87% | 445.00/512.67 MB [00:44<00:06, 10.26MB/s]:
#
#
# ████████▎                        27% | 25.00/92.92 MB [00:01<00:05, 12.49MB/s]:
# ███████████████▌               54% | 275.00/512.65 MB [00:26<00:22, 10.46MB/s]:
#
# █████████████████████████▍     88% | 450.00/512.67 MB [00:45<00:05, 10.67MB/s]:
#
#
# ██████████                       32% | 30.00/92.92 MB [00:02<00:05, 12.40MB/s]:
# ███████████████▊               55% | 280.00/512.65 MB [00:27<00:21, 10.79MB/s]:
#
# ███████████▋                     38% | 35.00/92.92 MB [00:02<00:04, 12.36MB/s]:
#
#
# █▏                               4% | 20.00/512.66 MB [00:01<00:38, 12.63MB/s]:
# ████████████████               56% | 285.00/512.65 MB [00:27<00:20, 11.10MB/s]:
#
# █████████████▎                   43% | 40.00/92.92 MB [00:03<00:04, 12.23MB/s]:
#
#
# █▍                               5% | 25.00/512.66 MB [00:01<00:39, 12.36MB/s]:
# ████████████████▍              57% | 290.00/512.65 MB [00:28<00:19, 11.18MB/s]:
#
# ███████████████                  48% | 45.00/92.92 MB [00:03<00:03, 11.99MB/s]:
#
#
# █▊                               6% | 30.00/512.66 MB [00:02<00:39, 12.25MB/s]:
# ████████████████▋              58% | 295.00/512.65 MB [00:28<00:19, 11.27MB/s]:
#
# ██████████████████████████▌    92% | 470.00/512.67 MB [00:46<00:03, 11.21MB/s]:
#
#
# ...
# ███████████▉                     38% | 30.00/78.16 MB [00:02<00:03, 12.30MB/s]:
#
# ███████████▍                   40% | 180.00/455.02 MB [00:18<00:25, 10.83MB/s]:
#
#
# █▍                               5% | 20.00/406.86 MB [00:01<00:30, 12.86MB/s]:
# █████████████▉                   45% | 35.00/78.16 MB [00:02<00:03, 12.15MB/s]:
#
# ███████████▊                   41% | 185.00/455.02 MB [00:18<00:24, 11.07MB/s]:
#
#
# █▊                               6% | 25.00/406.86 MB [00:01<00:30, 12.34MB/s]:
# ███████████████▊                 51% | 40.00/78.16 MB [00:03<00:03, 11.80MB/s]:
#
# ████████████                   42% | 190.00/455.02 MB [00:18<00:23, 11.18MB/s]:
#
#
# ██▏                              7% | 30.00/406.86 MB [00:02<00:31, 11.95MB/s]:
# █████████████████▊               58% | 45.00/78.16 MB [00:03<00:03, 10.65MB/s]:
#
# ████████████▍                  43% | 195.00/455.02 MB [00:19<00:24, 10.61MB/s]:
#
#
# ██▌                              9% | 35.00/406.86 MB [00:02<00:33, 11.09MB/s]:
# ███████████████████▊             64% | 50.00/78.16 MB [00:04<00:02, 10.26MB/s]:
#
# ████████████▋                  44% | 200.00/455.02 MB [00:20<00:24, 10.32MB/s]:
#
#
# ██▉                             10% | 40.00/406.86 MB [00:03<00:35, 10.46MB/s]:
# █████████████████████▊           70% | 55.00/78.16 MB [00:04<00:02,  9.99MB/s]:
#
# █████████████                  45% | 205.00/455.02 MB [00:20<00:25,  9.99MB/s]:
#
#
# ███▎                            11% | 45.00/406.86 MB [00:03<00:36, 10.04MB/s]:
# ███████████████████████▊         77% | 60.00/78.16 MB [00:05<00:01,  9.84MB/s]:
#
# █████████████▍                 46% | 210.00/455.02 MB [00:21<00:24,  9.87MB/s]:
#
#
# ███▋                            12% | 50.00/406.86 MB [00:04<00:36,  9.81MB/s]:
# █████████████████████████▊       83% | 65.00/78.16 MB [00:05<00:01,  9.69MB/s]:
#
# █████████████▋                 47% | 215.00/455.02 MB [00:21<00:24,  9.78MB/s]:
#
#
# ████                            14% | 55.00/406.86 MB [00:04<00:36,  9.67MB/s]:
# ███████████████████████████▊     90% | 70.00/78.16 MB [00:06<00:00,  9.69MB/s]:
#
# ██████████████                 48% | 220.00/455.02 MB [00:22<00:24,  9.75MB/s]:
#
#
# ████▍                           15% | 60.00/406.86 MB [00:05<00:35,  9.66MB/s]:
# █████████████████████████████▋   96% | 75.00/78.16 MB [00:06<00:00,  9.67MB/s]:
#
# ██████████████▎                49% | 225.00/455.02 MB [00:22<00:23,  9.63MB/s]:
#
#
# ███████████████████████████████ 100% | 78.16/78.16 MB [00:07<00:00,  9.52MB/s]:
# █████████████████████████▍     88% | 400.00/456.99 MB [00:40<00:05,  9.65MB/s]:
#
# ██████████████▋                51% | 230.00/455.02 MB [00:23<00:22,  9.85MB/s]:
#
#
# █████▏                          17% | 70.00/406.86 MB [00:06<00:33, 10.12MB/s]:
# ███████████████████████████████ 100% | 78.16/78.16 MB [00:07<00:00, 10.05MB/s]:
#
#
# ██████████████▉                52% | 235.00/455.02 MB [00:23<00:21, 10.22MB/s]:
#
#
# █████▌                          18% | 75.00/406.86 MB [00:06<00:31, 10.52MB/s]:
# ██████████████████████████     90% | 410.00/456.99 MB [00:41<00:04, 10.61MB/s]:
#
# ███████████████▎               53% | 240.00/455.02 MB [00:23<00:20, 10.62MB/s]:
#
#
# █████▉                          20% | 80.00/406.86 MB [00:07<00:30, 10.82MB/s]:
# ██████████████████████████▎    91% | 415.00/456.99 MB [00:41<00:03, 10.98MB/s]:
#
# ███████████████▌               54% | 245.00/455.02 MB [00:24<00:19, 10.91MB/s]:
#
#
# ██████▎                         21% | 85.00/406.86 MB [00:07<00:29, 11.02MB/s]:
# ██████████████████████████▋    92% | 420.00/456.99 MB [00:41<00:03, 11.23MB/s]:
#
# ███████████████▉               55% | 250.00/455.02 MB [00:24<00:18, 11.16MB/s]:
#
#
# ██████▋                         22% | 90.00/406.86 MB [00:08<00:28, 11.25MB/s]:
# ██████████████████████████▉    93% | 425.00/456.99 MB [00:42<00:02, 11.33MB/s]:
#
# ████████████████▎              56% | 255.00/455.02 MB [00:25<00:17, 11.23MB/s]:
#
#
# ███████                         23% | 95.00/406.86 MB [00:08<00:27, 11.46MB/s]:
# ███████████████████████████▎   94% | 430.00/456.99 MB [00:42<00:02, 11.41MB/s]:
#
# ████████████████▌              57% | 260.00/455.02 MB [00:25<00:17, 11.29MB/s]:
#
#
# ███████▏                       25% | 100.00/406.86 MB [00:08<00:26, 11.53MB/s]:
# ███████████████████████████▌   95% | 435.00/456.99 MB [00:43<00:01, 11.49MB/s]:
#
# ████████████████▉              58% | 265.00/455.02 MB [00:26<00:16, 11.26MB/s]:
#
#
# ███████▍                       26% | 105.00/406.86 MB [00:09<00:26, 11.57MB/s]:
# ███████████████████████████▉   96% | 440.00/456.99 MB [00:43<00:01, 11.58MB/s]:
#
# █████████████████▏             59% | 270.00/455.02 MB [00:26<00:16, 11.29MB/s]:
#
#
# ███████▊                       27% | 110.00/406.86 MB [00:09<00:25, 11.55MB/s]:
# ████████████████████████████▏  97% | 445.00/456.99 MB [00:44<00:01, 11.60MB/s]:
#
# █████████████████▌             60% | 275.00/455.02 MB [00:27<00:15, 11.27MB/s]:
#
#
# ████████▏                      28% | 115.00/406.86 MB [00:10<00:25, 11.55MB/s]:
# ████████████████████████████▌  98% | 450.00/456.99 MB [00:44<00:00, 11.49MB/s]:
#
# █████████████████▊             62% | 280.00/455.02 MB [00:27<00:15, 11.40MB/s]:
#
#
# ████████▌                      29% | 120.00/406.86 MB [00:10<00:24, 11.62MB/s]:
# ████████████████████████████▊ 100% | 455.00/456.99 MB [00:44<00:00, 11.18MB/s]:
# Uploading dataset changes (42010 files compressed to 151.51 MiB) to https://files.clear.ml
# ████████████████████████████▉ 100% | 456.98/456.99 MB [00:47<00:00,  3.79MB/s]:
#
# ██████████████████▏            63% | 285.00/455.02 MB [00:30<00:39,  4.32MB/s]:
#
#
# ████████▉                      31% | 125.00/406.86 MB [00:13<01:05,  4.29MB/s]:
#
# ██████████████████▍            64% | 290.00/455.02 MB [00:30<00:31,  5.25MB/s]:
#
#
# █████████▎                     32% | 130.00/406.86 MB [00:14<00:52,  5.31MB/s]:
#
# ██████████████████▊            65% | 295.00/455.02 MB [00:31<00:25,  6.29MB/s]:
#
#
# █████████▌                     33% | 135.00/406.86 MB [00:14<00:42,  6.35MB/s]:
#
# ███████████████████            66% | 300.00/455.02 MB [00:31<00:21,  7.25MB/s]:
#
#
# █████████▉                     34% | 140.00/406.86 MB [00:14<00:36,  7.36MB/s]:
#
# ███████████████████▍           67% | 305.00/455.02 MB [00:32<00:18,  8.14MB/s]:
#
#
#                                            0% | 0.00/74.21 MB [00:00<?, ?MB/s]:
#
# ███████████████████▊           68% | 310.00/455.02 MB [00:32<00:16,  8.92MB/s]:
#
#
#
#                                           0% | 0.00/151.51 MB [00:00<?, ?MB/s]:
#
#
# ████▏                            13% | 10.00/74.21 MB [00:00<00:02, 23.86MB/s]:
#
# ████████████████████           69% | 315.00/455.02 MB [00:32<00:14,  9.56MB/s]:
#
#
#
# █▉                               7% | 10.00/151.51 MB [00:00<00:06, 23.22MB/s]:
#
#
# ██████▎                          20% | 15.00/74.21 MB [00:00<00:03, 16.65MB/s]:
#
# ████████████████████▍          70% | 320.00/455.02 MB [00:33<00:13, 10.11MB/s]:
#
#
#
# ██▉                             10% | 15.00/151.51 MB [00:00<00:08, 16.58MB/s]:
#
#
# ████████▎                        27% | 20.00/74.21 MB [00:01<00:04, 12.71MB/s]:
#
# ████████████████████▋          71% | 325.00/455.02 MB [00:33<00:12, 10.41MB/s]:
#
#
# ███████████▊                   41% | 165.00/406.86 MB [00:16<00:22, 10.62MB/s]:
#
#
#
# ██████████▍                      34% | 25.00/74.21 MB [00:01<00:04, 11.70MB/s]:
#
# █████████████████████          73% | 330.00/455.02 MB [00:34<00:12, 10.26MB/s]:
#
#
# █████████████████████████████ 100% | 456.99/456.99 MB [00:51<00:00,  8.84MB/s]:
#
#
#
#
# ████████████▌                    40% | 30.00/74.21 MB [00:02<00:04, 10.69MB/s]:
#
#
# ████████████▍                  43% | 175.00/406.86 MB [00:18<00:23, 10.03MB/s]:
#
# █████████████████████▎         74% | 335.00/455.02 MB [00:34<00:12,  9.86MB/s]:
#
#
#
# ██████████████▌                  47% | 35.00/74.21 MB [00:02<00:03, 10.35MB/s]:
#
#
# ████████████▊                  44% | 180.00/406.86 MB [00:18<00:22,  9.91MB/s]:
#
# █████████████████████▋         75% | 340.00/455.02 MB [00:35<00:11,  9.69MB/s]:
#
#
#
# ████████████████▋                54% | 40.00/74.21 MB [00:03<00:03, 10.15MB/s]:
#
#
# █████████████▏                 45% | 185.00/406.86 MB [00:19<00:22,  9.79MB/s]:
#
# █████████████████████▉         76% | 345.00/455.02 MB [00:35<00:11,  9.53MB/s]:
#
#
#
# ██████████████████▊              61% | 45.00/74.21 MB [00:03<00:02, 10.04MB/s]:
#
#
# █████████████▌                 47% | 190.00/406.86 MB [00:19<00:22,  9.71MB/s]:
#
# ██████████████████████▎        77% | 350.00/455.02 MB [00:36<00:11,  9.50MB/s]:
#
#
#
# ████████████████████▉            67% | 50.00/74.21 MB [00:04<00:02,  9.87MB/s]:
#
#
# █████████████▉                 48% | 195.00/406.86 MB [00:20<00:21,  9.66MB/s]:
#
# ██████████████████████▋        78% | 355.00/455.02 MB [00:37<00:10,  9.50MB/s]:
#
#
#
# ██████████████████████▉          74% | 55.00/74.21 MB [00:05<00:01,  9.65MB/s]:
#
#
# ██████████████▎                49% | 200.00/406.86 MB [00:20<00:21,  9.66MB/s]:
#
# ██████████████████████▉        79% | 360.00/455.02 MB [00:37<00:10,  9.40MB/s]:
#
#
#
# █████████████████████████        81% | 60.00/74.21 MB [00:05<00:01,  9.65MB/s]:
#
#
# ██████████████▌                50% | 205.00/406.86 MB [00:21<00:21,  9.59MB/s]:
#
# ███████████████████████▎       80% | 365.00/455.02 MB [00:38<00:09,  9.50MB/s]:
#
#
#
# ███████████████████████████▏     88% | 65.00/74.21 MB [00:06<00:00,  9.67MB/s]:
#
#
# ██████████████▉                52% | 210.00/406.86 MB [00:21<00:20,  9.56MB/s]:
#
# ███████████████████████▌       81% | 370.00/455.02 MB [00:38<00:08,  9.48MB/s]:
#
#
#
# █████████████████████████████▏   94% | 70.00/74.21 MB [00:06<00:00,  9.70MB/s]:
#
#
# ███████████████▎               53% | 215.00/406.86 MB [00:22<00:19,  9.62MB/s]:
#
# ███████████████████████▉       82% | 375.00/455.02 MB [00:39<00:08,  9.48MB/s]:
#
#
#
# ██████████████████████████████▉ 100% | 74.20/74.21 MB [00:07<00:00,  9.59MB/s]:
#
#
# ███████████████▋               54% | 220.00/406.86 MB [00:22<00:18,  9.86MB/s]:
#
# ████████████████████████▏      84% | 380.00/455.02 MB [00:39<00:07,  9.90MB/s]:
#
#
#
# ███████████████████████████████ 100% | 74.21/74.21 MB [00:07<00:00,  9.76MB/s]:
#
#
#
# ████████████████               55% | 225.00/406.86 MB [00:23<00:17, 10.38MB/s]:
#
# ████████████████████████▌      85% | 385.00/455.02 MB [00:40<00:06, 10.34MB/s]:
#
#
#
# ███████████████▊                53% | 80.00/151.51 MB [00:07<00:06, 10.45MB/s]:
#
#
# ████████████████▍              57% | 230.00/406.86 MB [00:23<00:16, 10.79MB/s]:
#
# ████████████████████████▊      86% | 390.00/455.02 MB [00:40<00:06, 10.62MB/s]:
#
#
#
# ████████████████▊               56% | 85.00/151.51 MB [00:07<00:06, 10.71MB/s]:
#
#
# ████████████████▊              58% | 235.00/406.86 MB [00:23<00:15, 11.08MB/s]:
#
# █████████████████████████▏     87% | 395.00/455.02 MB [00:40<00:05, 10.81MB/s]:
#
#
#
# █████████████████▊              59% | 90.00/151.51 MB [00:08<00:05, 10.99MB/s]:
#
#
# █████████████████              59% | 240.00/406.86 MB [00:24<00:14, 11.21MB/s]:
#
# █████████████████████████▍     88% | 400.00/455.02 MB [00:41<00:04, 11.00MB/s]:
#
#
#
# ██████████████████▊             63% | 95.00/151.51 MB [00:08<00:05, 11.23MB/s]:
#
#
# █████████████████▍             60% | 245.00/406.86 MB [00:24<00:14, 11.27MB/s]:
#
# █████████████████████████▊     89% | 405.00/455.02 MB [00:41<00:04, 11.20MB/s]:
#
#
#
# ███████████████████▏           66% | 100.00/151.51 MB [00:09<00:04, 11.36MB/s]:
#
#
# █████████████████▊             61% | 250.00/406.86 MB [00:25<00:13, 11.42MB/s]:
#
# ██████████████████████████▏    90% | 410.00/455.02 MB [00:42<00:03, 11.33MB/s]:
#
#
#
# ████████████████████           69% | 105.00/151.51 MB [00:09<00:04, 11.47MB/s]:
#
#
# ██████████████████▏            63% | 255.00/406.86 MB [00:25<00:13, 11.53MB/s]:
#
# ██████████████████████████▍    91% | 415.00/455.02 MB [00:42<00:03, 11.44MB/s]:
#
#
#
# █████████████████████          73% | 110.00/151.51 MB [00:10<00:03, 11.48MB/s]:
#
#
# ██████████████████▌            64% | 260.00/406.86 MB [00:26<00:12, 11.58MB/s]:
#
# ██████████████████████████▊    92% | 420.00/455.02 MB [00:43<00:03, 11.40MB/s]:
#
#
#
# ██████████████████████         76% | 115.00/151.51 MB [00:10<00:03, 11.46MB/s]:
#
#
# ██████████████████▉            65% | 265.00/406.86 MB [00:26<00:12, 11.49MB/s]:
#
#
#
# ██████████████████████▉        79% | 120.00/151.51 MB [00:10<00:02, 11.52MB/s]:
#
# ███████████████████████████    93% | 425.00/455.02 MB [00:43<00:02, 11.37MB/s]:
#
#
# ███████████████████▏           66% | 270.00/406.86 MB [00:26<00:11, 11.59MB/s]:
#
#
#
# ███████████████████████▉       83% | 125.00/151.51 MB [00:11<00:02, 11.56MB/s]:
#
# ███████████████████████████▍   95% | 430.00/455.02 MB [00:43<00:02, 11.34MB/s]:
#
#
# ███████████████████▌           68% | 275.00/406.86 MB [00:27<00:13,  9.83MB/s]:
#
#
#
# ████████████████████████▉      86% | 130.00/151.51 MB [00:12<00:02,  9.95MB/s]:
#
# ███████████████████████████▋   96% | 435.00/455.02 MB [00:44<00:02,  9.53MB/s]:
#
#
# ███████████████████▉           69% | 280.00/406.86 MB [00:28<00:12, 10.36MB/s]:
#
#
#
# █████████████████████████▊     89% | 135.00/151.51 MB [00:12<00:01, 10.11MB/s]:
#
# ████████████████████████████   97% | 440.00/455.02 MB [00:45<00:01, 10.08MB/s]:
#
#
# ████████████████████▎          70% | 285.00/406.86 MB [00:28<00:11, 10.77MB/s]:
#
#
#
# ██████████████████████████▊    92% | 140.00/151.51 MB [00:12<00:01, 10.54MB/s]:
#
# ████████████████████████████▎  98% | 445.00/455.02 MB [00:45<00:00, 10.38MB/s]:
#
#
# ████████████████████▋          71% | 290.00/406.86 MB [00:28<00:10, 10.73MB/s]:
#
#
#
# ███████████████████████████▊   96% | 145.00/151.51 MB [00:13<00:00, 10.73MB/s]:
#
# ████████████████████████████▋  99% | 450.00/455.02 MB [00:46<00:00, 10.56MB/s]:
#
#
# █████████████████████          73% | 295.00/406.86 MB [00:29<00:10, 10.94MB/s]:
#
#
#
# ████████████████████████████▋  99% | 150.00/151.51 MB [00:13<00:00, 10.97MB/s]:
#
# ████████████████████████████▉ 100% | 455.00/455.02 MB [00:46<00:00, 10.79MB/s]:
#
#
#
# ████████████████████████████▉ 100% | 151.50/151.51 MB [00:13<00:00, 11.00MB/s]:
#
#
# █████████████████████▍         74% | 300.00/406.86 MB [00:29<00:09, 11.16MB/s]:
#
#
# █████████████████████▋         75% | 305.00/406.86 MB [00:30<00:08, 11.37MB/s]:
#
#
# █████████████████████████████ 100% | 151.51/151.51 MB [00:15<00:00,  9.89MB/s]:
#
#
#
# ██████████████████████▍        77% | 315.00/406.86 MB [00:31<00:07, 11.55MB/s]:
#
#
# ██████████████████████▊        79% | 320.00/406.86 MB [00:31<00:07, 11.57MB/s]:
#
#
# ███████████████████████▏       80% | 325.00/406.86 MB [00:31<00:07, 11.58MB/s]:
#
#
# ███████████████████████▌       81% | 330.00/406.86 MB [00:32<00:06, 11.62MB/s]:
#
#
# ███████████████████████▉       82% | 335.00/406.86 MB [00:32<00:06, 11.70MB/s]:
#
#
# ████████████████████████▏      84% | 340.00/406.86 MB [00:33<00:05, 11.72MB/s]:
#
#
# ████████████████████████▌      85% | 345.00/406.86 MB [00:33<00:05, 11.71MB/s]:
#
#
# ████████████████████████▉      86% | 350.00/406.86 MB [00:34<00:04, 11.69MB/s]:
#
#
# █████████████████████████▎     87% | 355.00/406.86 MB [00:34<00:04, 11.66MB/s]:
#
#
# █████████████████████████████ 100% | 455.02/455.02 MB [00:51<00:00,  8.77MB/s]:
#
#
#
# ██████████████████████████     90% | 365.00/406.86 MB [00:35<00:03, 11.74MB/s]:
#
#
# ██████████████████████████▎    91% | 370.00/406.86 MB [00:35<00:03, 11.74MB/s]:
#
#
# ██████████████████████████▋    92% | 375.00/406.86 MB [00:36<00:02, 11.69MB/s]:
#
#
# ███████████████████████████    93% | 380.00/406.86 MB [00:36<00:02, 11.71MB/s]:
#
#
# ███████████████████████████▍   95% | 385.00/406.86 MB [00:37<00:01, 11.68MB/s]:
#
#
# ███████████████████████████▊   96% | 390.00/406.86 MB [00:37<00:01, 11.67MB/s]:
#
#
# ████████████████████████████▏  97% | 395.00/406.86 MB [00:37<00:01, 11.75MB/s]:
#
#
# ████████████████████████████▌  98% | 400.00/406.86 MB [00:38<00:00, 11.76MB/s]:
#
#
# ████████████████████████████▊ 100% | 405.00/406.86 MB [00:38<00:00, 11.70MB/s]:
#
#
# █████████████████████████████ 100% | 406.86/406.86 MB [00:42<00:00,  9.55MB/s]:
# File compression and upload completed: total size 5.44 GiB, 12 chunk(s) stored (average size 464.27 MiB)
# ███████████████████████████████ 100% | 74.21/74.21 MB [00:06<00:00, 11.22MB/s]:
# ███████████████████████████████ 100% | 74.21/74.21 MB [00:06<00:00, 11.28MB/s]:

# %%
# from clearml import Dataset

# # 1. 获取之前的旧版本作为基准 (Parent)
# old_dataset = Dataset.get(dataset_project='InfinifyX', dataset_name='bdd100k')

# # 2. 创建一个新版本，继承自旧版本
# # 这步非常关键，它会告诉 ClearML 尽量复用已有的文件
# new_dataset = Dataset.create(
#     dataset_project='InfinifyX', 
#     dataset_name='bdd100k',
#     parent_datasets=[old_dataset.id]
# )

# # 3. 添加你现在已经移动好位置的新路径
# # 它会自动扫描你的本地结构并更新云端的索引
# new_dataset.add_files(path='bdd100k')

# # 4. 上传并锁定
# new_dataset.upload()
# new_dataset.finalize()

# print("✅ New Version v1.1.0 Updated！")

# %% [markdown]
# ### Upload Segmentation Dataset

# %%
from clearml import Dataset

# 1. Create a new Dataset object
# Project name: 'InfinifyX', Dataset name: 'bdd100k_seg'
dataset = Dataset.create(
    dataset_project='InfinityX', 
    dataset_name='bdd100k_seg'
)

# 2. Specify the local folder path to upload
# This path contains color_labels, images, and labels folders
local_data_path = '/home/sagemaker-user/InfinifyX/data_preprocessing/dataset_seg/bdd100k_seg/bdd100k/seg'

# Verify if the path exists before adding files
if os.path.exists(local_data_path):
    print(f"Path confirmed: {local_data_path}")
    # Add all files from the directory to the ClearML dataset
    dataset.add_files(path=local_data_path)
else:
    print(f"ERROR: Could not find path {local_data_path}. Please check the directory.")

# 3. Start uploading to the ClearML file server
print("Uploading data to ClearML...")
dataset.upload()

# finalize() locks the dataset and makes it read-only for version control
dataset.finalize()

print("Dataset 'bdd100k_seg' uploaded and finalized successfully!")
# Out:
# ClearML results page: https://app.clear.ml/projects/24599766ce0d4bbcb480bd8cb6f039cd/experiments/69e4c55680a246e29b0e2b64d2bad906/output/log
# ClearML dataset page: https://app.clear.ml/datasets/simple/24599766ce0d4bbcb480bd8cb6f039cd/experiments/69e4c55680a246e29b0e2b64d2bad906
# Path confirmed: /home/sagemaker-user/InfinifyX/data_preprocessing/dataset_seg/bdd100k_seg/bdd100k/seg
# Generating SHA2 hash for 26000 files
# 100%|██████████| 26000/26000 [00:04<00:00, 6435.84it/s]
# Hash generation completed
# ████████████████████████████████ 100% | 11.70/11.7 MB [00:00<00:00, 12.58MB/s]:
# Uploading data to ClearML...
# Uploading dataset changes (6540 files compressed to 304.37 MiB) to https://files.clear.ml
# ███████████████████████████████ 100% | 10.73/10.73 MB [00:00<00:00, 10.98MB/s]:
# ███▍                            11% | 35.00/304.37 MB [00:02<00:21, 12.66MB/s]:
# Uploading dataset changes (6515 files compressed to 304.23 MiB) to https://files.clear.ml
# █████▍                          18% | 55.00/304.37 MB [00:04<00:23, 10.68MB/s]:
# █████▉                          20% | 60.00/304.37 MB [00:05<00:21, 11.18MB/s]:
# █████████████████████████████████ 100% | 9.78/9.78 MB [00:00<00:00, 12.70MB/s]:
# ███████▍                        25% | 75.00/304.37 MB [00:06<00:19, 12.01MB/s]:
#                                           0% | 0.00/304.23 MB [00:00<?, ?MB/s]:
# ████████▍                       28% | 85.00/304.37 MB [00:07<00:19, 11.30MB/s]:
# ████████▊                       30% | 90.00/304.37 MB [00:07<00:18, 11.64MB/s]:
# █████████▎                      31% | 95.00/304.37 MB [00:08<00:17, 11.89MB/s]:
# █████████▌                     33% | 100.00/304.37 MB [00:08<00:16, 12.07MB/s]:
# ██████████                     34% | 105.00/304.37 MB [00:08<00:17, 11.14MB/s]:
# Uploading dataset changes (6504 files compressed to 302.4 MiB) to https://files.clear.ml
# ██████████▍                    36% | 110.00/304.37 MB [00:09<00:20,  9.40MB/s]:
# ██████████▉                    38% | 115.00/304.37 MB [00:10<00:18, 10.11MB/s]:
# ███████████▍                   39% | 120.00/304.37 MB [00:10<00:17, 10.65MB/s]:
# ███████████▉                   41% | 125.00/304.37 MB [00:10<00:16, 11.08MB/s]:
#
#                                             0% | 0.00/8.84 MB [00:00<?, ?MB/s]:
# █████▍                          18% | 55.00/304.23 MB [00:04<00:22, 10.95MB/s]:
#
# ████████████▍                  43% | 130.00/304.37 MB [00:11<00:15, 11.21MB/s]:
# █████████████████████████████████ 100% | 8.84/8.84 MB [00:00<00:00, 11.51MB/s]:
# ████████████▊                  44% | 135.00/304.37 MB [00:11<00:14, 11.42MB/s]:
# █████████████▎                 46% | 140.00/304.37 MB [00:12<00:14, 11.05MB/s]:
# ██████▉                         23% | 70.00/304.23 MB [00:05<00:20, 11.58MB/s]:
#
# █████████████▊                 48% | 145.00/304.37 MB [00:12<00:13, 11.39MB/s]:
# ███████▍                        25% | 75.00/304.23 MB [00:06<00:19, 11.65MB/s]:
#
# ██████████████▎                49% | 150.00/304.37 MB [00:13<00:13, 11.62MB/s]:
# ██████████████▊                51% | 155.00/304.37 MB [00:13<00:12, 11.75MB/s]:
#
# █▌                                5% | 15.00/302.4 MB [00:00<00:20, 14.34MB/s]:
# ███████████████▏               53% | 160.00/304.37 MB [00:13<00:12, 11.71MB/s]:
#
# ██                                7% | 20.00/302.4 MB [00:01<00:21, 13.39MB/s]:
# ████████▊                       30% | 90.00/304.23 MB [00:07<00:18, 11.61MB/s]:
#
# ███████████████▋               54% | 165.00/304.37 MB [00:14<00:12, 11.19MB/s]:
# █████████▎                      31% | 95.00/304.23 MB [00:08<00:17, 11.74MB/s]:
#
# ████████████████▏              56% | 170.00/304.37 MB [00:14<00:11, 11.47MB/s]:
# █████████▌                     33% | 100.00/304.23 MB [00:08<00:17, 11.75MB/s]:
# Uploading dataset changes (6441 files compressed to 301.5 MiB) to https://files.clear.ml
# ████████████████▋              57% | 175.00/304.37 MB [00:15<00:13,  9.94MB/s]:
# ██████████                     35% | 105.00/304.23 MB [00:09<00:21,  9.45MB/s]:
#
# █████████████████▏             59% | 180.00/304.37 MB [00:15<00:12, 10.22MB/s]:
# ██████████▍                    36% | 110.00/304.23 MB [00:09<00:19, 10.02MB/s]:
#
# █████████████████▋             61% | 185.00/304.37 MB [00:16<00:11, 10.61MB/s]:
# ██████████▉                    38% | 115.00/304.23 MB [00:10<00:18, 10.43MB/s]:
#
# ██████████████████             62% | 190.00/304.37 MB [00:16<00:10, 10.84MB/s]:
#
#
#                                             0% | 0.00/7.91 MB [00:00<?, ?MB/s]:
# ███████████▍                   39% | 120.00/304.23 MB [00:10<00:17, 10.67MB/s]:
#
#
# ████████████████████████████████▉ 100% | 7.90/7.91 MB [00:00<00:00, 34.50MB/s]:
#
# ██████████████████▌            64% | 195.00/304.37 MB [00:17<00:09, 11.10MB/s]:
# █████████████████████████████████ 100% | 7.91/7.91 MB [00:00<00:00, 13.49MB/s]:
# ███████████████████            66% | 200.00/304.37 MB [00:17<00:09, 11.33MB/s]:
#
# ██████▏                          20% | 60.00/302.4 MB [00:05<00:21, 11.21MB/s]:
# ███████████████████▌           67% | 205.00/304.37 MB [00:18<00:08, 11.45MB/s]:
#
# ██████▋                          21% | 65.00/302.4 MB [00:05<00:20, 11.34MB/s]:
# ████████████████████           69% | 210.00/304.37 MB [00:18<00:08, 11.51MB/s]:
#
# ███████▏                         23% | 70.00/302.4 MB [00:05<00:20, 11.41MB/s]:
# ████████████████████▍          71% | 215.00/304.37 MB [00:18<00:07, 11.49MB/s]:
#
# ███████▋                         25% | 75.00/302.4 MB [00:06<00:19, 11.46MB/s]:
#
#
#                                            0% | 0.00/301.5 MB [00:00<?, ?MB/s]:
# ████████████████████▉          72% | 220.00/304.37 MB [00:19<00:07, 11.48MB/s]:
#
# ████████▏                        26% | 80.00/302.4 MB [00:06<00:19, 11.38MB/s]:
#
#
# █                                 3% | 10.00/301.5 MB [00:00<00:13, 22.00MB/s]:
# █████████████████████▍         74% | 225.00/304.37 MB [00:19<00:07, 11.23MB/s]:
#
# ████████▋                        28% | 85.00/302.4 MB [00:07<00:19, 11.01MB/s]:
#
#
# █▌                                5% | 15.00/301.5 MB [00:01<00:21, 13.60MB/s]:
# █████████████████████▉         76% | 230.00/304.37 MB [00:20<00:06, 10.72MB/s]:
#
# █████████▏                       30% | 90.00/302.4 MB [00:07<00:20, 10.58MB/s]:
#
#
# ██                                7% | 20.00/301.5 MB [00:01<00:23, 11.95MB/s]:
# ██████████████████████▍        77% | 235.00/304.37 MB [00:20<00:06, 10.43MB/s]:
#
# █████████▋                       31% | 95.00/302.4 MB [00:08<00:20, 10.27MB/s]:
#
#
# ██▌                               8% | 25.00/301.5 MB [00:02<00:25, 11.01MB/s]:
# ██████████████████████▊        79% | 240.00/304.37 MB [00:21<00:06, 10.27MB/s]:
#
# █████████▉                      33% | 100.00/302.4 MB [00:08<00:19, 10.16MB/s]:
#
#
# ███                              10% | 30.00/301.5 MB [00:02<00:25, 10.58MB/s]:
# ███████████████████████▎       80% | 245.00/304.37 MB [00:21<00:05, 10.17MB/s]:
#
# ██████████▍                     35% | 105.00/302.4 MB [00:09<00:19, 10.13MB/s]:
#
#
# ███▌                             12% | 35.00/301.5 MB [00:03<00:25, 10.45MB/s]:
# ███████████████████████▊       82% | 250.00/304.37 MB [00:22<00:05, 10.20MB/s]:
#
# ██████████▉                     36% | 110.00/302.4 MB [00:09<00:18, 10.15MB/s]:
#
#
# ████                             13% | 40.00/301.5 MB [00:03<00:25, 10.30MB/s]:
# ████████████████████████▎      84% | 255.00/304.37 MB [00:22<00:04, 10.19MB/s]:
#
# ███████████▍                    38% | 115.00/302.4 MB [00:10<00:18, 10.10MB/s]:
#
#
# ████▋                            15% | 45.00/301.5 MB [00:04<00:24, 10.27MB/s]:
# ████████████████████████▊      85% | 260.00/304.37 MB [00:23<00:04, 10.23MB/s]:
#
# ███████████▉                    40% | 120.00/302.4 MB [00:10<00:18, 10.07MB/s]:
#
#
# █████▏                           17% | 50.00/301.5 MB [00:04<00:24, 10.18MB/s]:
# █████████████████████████▏     87% | 265.00/304.37 MB [00:23<00:03, 10.14MB/s]:
#
# ████████████▍                   41% | 125.00/302.4 MB [00:11<00:17, 10.07MB/s]:
#
#
# █████▋                           18% | 55.00/301.5 MB [00:05<00:24, 10.25MB/s]:
# █████████████████████████▋     89% | 270.00/304.37 MB [00:24<00:03, 10.09MB/s]:
#
# ████████████▉                   43% | 130.00/302.4 MB [00:11<00:17, 10.08MB/s]:
#
#
# ██████▏                          20% | 60.00/301.5 MB [00:05<00:23, 10.17MB/s]:
# ██████████████████████████▏    90% | 275.00/304.37 MB [00:24<00:02, 10.13MB/s]:
#
# █████████████▍                  45% | 135.00/302.4 MB [00:12<00:16, 10.15MB/s]:
#
#
# ██████▋                          22% | 65.00/301.5 MB [00:06<00:23, 10.18MB/s]:
# ██████████████████████████▋    92% | 280.00/304.37 MB [00:25<00:02, 10.09MB/s]:
#
# █████████████▉                  46% | 140.00/302.4 MB [00:12<00:15, 10.20MB/s]:
#
#
# ███████▏                         23% | 70.00/301.5 MB [00:06<00:22, 10.19MB/s]:
# ███████████████████████████▏   94% | 285.00/304.37 MB [00:25<00:01, 10.15MB/s]:
#
# ██████████████▍                 48% | 145.00/302.4 MB [00:13<00:15, 10.23MB/s]:
#
#
# ███████▋                         25% | 75.00/301.5 MB [00:06<00:22, 10.14MB/s]:
# ███████████████████████████▋   95% | 290.00/304.37 MB [00:26<00:01, 10.14MB/s]:
#
# ██████████████▉                 50% | 150.00/302.4 MB [00:13<00:15, 10.15MB/s]:
#
#
# ████████▏                        27% | 80.00/301.5 MB [00:07<00:21, 10.22MB/s]:
# ████████████████████████████   97% | 295.00/304.37 MB [00:26<00:00, 10.08MB/s]:
#
# ███████████████▍                51% | 155.00/302.4 MB [00:14<00:14, 10.08MB/s]:
#
#
# ████████▋                        28% | 85.00/301.5 MB [00:07<00:21, 10.28MB/s]:
# ████████████████████████████▌  99% | 300.00/304.37 MB [00:27<00:00, 10.01MB/s]:
#
# ███████████████▊                53% | 160.00/302.4 MB [00:14<00:14, 10.06MB/s]:
#
#
# █████████▎                       30% | 90.00/301.5 MB [00:08<00:20, 10.28MB/s]:
# █████████████████████████████ 100% | 304.37/304.37 MB [00:27<00:00,  9.98MB/s]:
#
# ████████████████▎               55% | 165.00/302.4 MB [00:15<00:13, 10.27MB/s]:
#
#
# █████████▊                       32% | 95.00/301.5 MB [00:08<00:19, 10.39MB/s]:
# ██████████████████████▍        77% | 235.00/304.23 MB [00:21<00:06, 10.39MB/s]:
#
# ████████████████▊               56% | 170.00/302.4 MB [00:15<00:12, 10.60MB/s]:
#
#
# █████████▉                      33% | 100.00/301.5 MB [00:09<00:18, 10.73MB/s]:
# ██████████████████████▉        79% | 240.00/304.23 MB [00:22<00:06, 10.70MB/s]:
#
# █████████████████▎              58% | 175.00/302.4 MB [00:16<00:11, 10.83MB/s]:
#
#
# ██████████▍                     35% | 105.00/301.5 MB [00:09<00:17, 11.03MB/s]:
# █████████████████████████████ 100% | 304.37/304.37 MB [00:28<00:00, 10.52MB/s]:
#
#
# █████████████████▊              60% | 180.00/302.4 MB [00:16<00:11, 11.00MB/s]:
#
#
# ██████████▉                     36% | 110.00/301.5 MB [00:10<00:17, 11.20MB/s]:
# ███████████████████████▊       82% | 250.00/304.23 MB [00:22<00:04, 11.10MB/s]:
#
# ██████████████████▎             61% | 185.00/302.4 MB [00:17<00:10, 11.14MB/s]:
#
#
# ███████████▍                    38% | 115.00/301.5 MB [00:10<00:16, 11.29MB/s]:
# ████████████████████████▎      84% | 255.00/304.23 MB [00:23<00:04, 11.22MB/s]:
#
# ██████████████████▊             63% | 190.00/302.4 MB [00:17<00:09, 11.27MB/s]:
#
#
# ███████████▉                    40% | 120.00/301.5 MB [00:11<00:16, 11.31MB/s]:
# ████████████████████████▊      85% | 260.00/304.23 MB [00:23<00:03, 11.36MB/s]:
#
# ███████████████████▎            64% | 195.00/302.4 MB [00:17<00:09, 11.41MB/s]:
#
#
# ████████████▍                   41% | 125.00/301.5 MB [00:11<00:15, 11.33MB/s]:
# █████████████████████████▎     87% | 265.00/304.23 MB [00:24<00:03, 11.46MB/s]:
#
# ███████████████████▊            66% | 200.00/302.4 MB [00:18<00:08, 11.45MB/s]:
#
#
# ████████████▉                   43% | 130.00/301.5 MB [00:11<00:15, 11.43MB/s]:
# █████████████████████████▋     89% | 270.00/304.23 MB [00:24<00:02, 11.52MB/s]:
#
# ████████████████████▎           68% | 205.00/302.4 MB [00:18<00:08, 11.44MB/s]:
#
#
# █████████████▍                  45% | 135.00/301.5 MB [00:12<00:14, 11.49MB/s]:
# ██████████████████████████▏    90% | 275.00/304.23 MB [00:25<00:02, 11.55MB/s]:
#
# ████████████████████▊           69% | 210.00/302.4 MB [00:19<00:08, 11.42MB/s]:
#
#
# █████████████▉                  46% | 140.00/301.5 MB [00:12<00:13, 11.56MB/s]:
# ██████████████████████████▋    92% | 280.00/304.23 MB [00:25<00:02, 11.51MB/s]:
#
# █████████████████████▎          71% | 215.00/302.4 MB [00:19<00:07, 11.45MB/s]:
#
#
# ██████████████▍                 48% | 145.00/301.5 MB [00:13<00:13, 11.57MB/s]:
# ███████████████████████████▏   94% | 285.00/304.23 MB [00:25<00:01, 11.53MB/s]:
#
# █████████████████████▊          73% | 220.00/302.4 MB [00:20<00:07, 11.49MB/s]:
#
#
# ██████████████▉                 50% | 150.00/301.5 MB [00:13<00:13, 11.50MB/s]:
# ███████████████████████████▋   95% | 290.00/304.23 MB [00:26<00:01, 11.56MB/s]:
#
# ██████████████████████▎         74% | 225.00/302.4 MB [00:20<00:06, 11.57MB/s]:
#
#
# ███████████████▍                51% | 155.00/301.5 MB [00:14<00:12, 11.45MB/s]:
# ████████████████████████████   97% | 295.00/304.23 MB [00:26<00:00, 11.60MB/s]:
#
# ██████████████████████▊         76% | 230.00/302.4 MB [00:20<00:06, 11.57MB/s]:
#
#
# ███████████████▉                53% | 160.00/301.5 MB [00:14<00:12, 11.52MB/s]:
# ████████████████████████████▌  99% | 300.00/304.23 MB [00:27<00:00, 11.64MB/s]:
#
# ███████████████████████▎        78% | 235.00/302.4 MB [00:21<00:05, 11.51MB/s]:
# █████████████████████████████ 100% | 304.23/304.23 MB [00:27<00:00, 11.58MB/s]:
#
#
# ████████████████▍               55% | 165.00/301.5 MB [00:14<00:11, 11.57MB/s]:
#
# ███████████████████████▊        79% | 240.00/302.4 MB [00:21<00:05, 11.48MB/s]:
#
#
# ████████████████▉               56% | 170.00/301.5 MB [00:15<00:11, 11.61MB/s]:
#
# ████████████████████████▎       81% | 245.00/302.4 MB [00:22<00:05, 11.47MB/s]:
#
#
# █████████████████▍              58% | 175.00/301.5 MB [00:15<00:10, 11.60MB/s]:
#
# ████████████████████████▊       83% | 250.00/302.4 MB [00:22<00:04, 11.52MB/s]:
#
#
# █████████████████▉              60% | 180.00/301.5 MB [00:16<00:10, 11.53MB/s]:
#
# █████████████████████████▎      84% | 255.00/302.4 MB [00:23<00:04, 11.60MB/s]:
#
#
# █████████████████████████████ 100% | 304.23/304.23 MB [00:29<00:00, 10.32MB/s]:
#
#
# █████████████████████████▊      86% | 260.00/302.4 MB [00:23<00:03, 11.59MB/s]:
#
#
# ██████████████████▉             63% | 190.00/301.5 MB [00:17<00:09, 11.54MB/s]:
#
# ██████████████████████████▎     88% | 265.00/302.4 MB [00:23<00:03, 11.51MB/s]:
#
#
# ███████████████████▍            65% | 195.00/301.5 MB [00:17<00:09, 11.59MB/s]:
#
# ██████████████████████████▊     89% | 270.00/302.4 MB [00:24<00:02, 11.50MB/s]:
#
#
# ███████████████████▉            66% | 200.00/301.5 MB [00:17<00:08, 11.62MB/s]:
#
# ███████████████████████████▎    91% | 275.00/302.4 MB [00:24<00:02, 11.49MB/s]:
#
#
# ████████████████████▍           68% | 205.00/301.5 MB [00:18<00:08, 11.59MB/s]:
#
# ███████████████████████████▊    93% | 280.00/302.4 MB [00:25<00:01, 11.53MB/s]:
#
#
# ████████████████████▉           70% | 210.00/301.5 MB [00:18<00:07, 11.53MB/s]:
#
# ████████████████████████████▎   94% | 285.00/302.4 MB [00:25<00:01, 11.61MB/s]:
#
#
# █████████████████████▍          71% | 215.00/301.5 MB [00:19<00:07, 11.47MB/s]:
#
# ████████████████████████████▊   96% | 290.00/302.4 MB [00:26<00:01, 11.59MB/s]:
#
#
# █████████████████████▉          73% | 220.00/301.5 MB [00:19<00:07, 11.54MB/s]:
#
# █████████████████████████████▎  98% | 295.00/302.4 MB [00:26<00:00, 11.51MB/s]:
#
#
# ██████████████████████▍         75% | 225.00/301.5 MB [00:20<00:06, 11.59MB/s]:
#
# █████████████████████████████▊  99% | 300.00/302.4 MB [00:26<00:00, 11.49MB/s]:
#
#
# ██████████████████████▉         76% | 230.00/301.5 MB [00:20<00:06, 11.63MB/s]:
#
# █████████████████████████████▉ 100% | 302.39/302.4 MB [00:27<00:00, 11.52MB/s]:
#
#
# ███████████████████████▍        78% | 235.00/301.5 MB [00:21<00:05, 11.57MB/s]:
#
#
# ██████████████████████████████ 100% | 302.40/302.4 MB [00:28<00:00, 10.68MB/s]:
#
#
#
# ████████████████████████▍       81% | 245.00/301.5 MB [00:21<00:04, 11.49MB/s]:
#
#
# ████████████████████████▉       83% | 250.00/301.5 MB [00:22<00:04, 11.55MB/s]:
#
#
# █████████████████████████▎      85% | 255.00/301.5 MB [00:22<00:04, 11.60MB/s]:
#
#
# █████████████████████████▊      86% | 260.00/301.5 MB [00:23<00:03, 11.64MB/s]:
#
#
# ██████████████████████████▎     88% | 265.00/301.5 MB [00:23<00:03, 11.58MB/s]:
#
#
# ██████████████████████████▊     90% | 270.00/301.5 MB [00:24<00:02, 11.50MB/s]:
#
#
# ███████████████████████████▎    91% | 275.00/301.5 MB [00:24<00:02, 11.49MB/s]:
#
#
# ███████████████████████████▊    93% | 280.00/301.5 MB [00:24<00:01, 11.52MB/s]:
#
#
# ████████████████████████████▎   95% | 285.00/301.5 MB [00:25<00:01, 11.60MB/s]:
#
#
# ████████████████████████████▊   96% | 290.00/301.5 MB [00:25<00:00, 11.65MB/s]:
#
#
# █████████████████████████████▎  98% | 295.00/301.5 MB [00:26<00:00, 11.58MB/s]:
#
#
# █████████████████████████████▊ 100% | 300.00/301.5 MB [00:26<00:00, 11.51MB/s]:
#
#
# ██████████████████████████████ 100% | 301.50/301.5 MB [00:27<00:00, 10.81MB/s]:
# File compression and upload completed: total size 1.18 GiB, 4 chunk(s) stored (average size 303.12 MiB)
# █████████████████████████████████ 100% | 7.91/7.91 MB [00:00<00:00, 14.04MB/s]:
# █████████████████████████████████ 100% | 7.91/7.91 MB [00:00<00:00, 14.88MB/s]:
# Dataset 'bdd100k_seg' uploaded and finalized successfully!

# %%
from clearml import Dataset

# 1. Create a new Dataset object
# Project name: 'InfinifyX', Dataset name: 'bdd100k_seg'
dataset = Dataset.create(
    dataset_project='InfinityX', 
    dataset_name='nuscenes-mini'
)

# 2. Specify the local folder path to upload
# This path contains color_labels, images, and labels folders
local_data_path = '/home/sagemaker-user/InfinifyX/data_preprocessing/nuscenes-mini'

# Verify if the path exists before adding files
if os.path.exists(local_data_path):
    print(f"Path confirmed: {local_data_path}")
    # Add all files from the directory to the ClearML dataset
    dataset.add_files(path=local_data_path)
else:
    print(f"ERROR: Could not find path {local_data_path}. Please check the directory.")

# 3. Start uploading to the ClearML file server
print("Uploading data to ClearML...")
dataset.upload()

# finalize() locks the dataset and makes it read-only for version control
dataset.finalize()

print("Dataset 'bdd100k_seg' uploaded and finalized successfully!")
# Out:
# ClearML results page: https://app.clear.ml/projects/20a41517313d47ce9fe2dd6345043986/experiments/d533fa94d8ab47c09dfd2aeddb527bf8/output/log
# ClearML dataset page: https://app.clear.ml/datasets/simple/20a41517313d47ce9fe2dd6345043986/experiments/d533fa94d8ab47c09dfd2aeddb527bf8
# Path confirmed: /home/sagemaker-user/InfinifyX/data_preprocessing/nuscenes-mini
# Generating SHA2 hash for 31230 files
# 100%|██████████| 31230/31230 [00:08<00:00, 3678.65it/s]
# Hash generation completed
# ███████████████████████████████ 100% | 16.12/16.12 MB [00:01<00:00, 11.56MB/s]:
# Uploading data to ClearML...
# Uploading dataset changes (1427 files compressed to 512.23 MiB) to https://files.clear.ml
# ███████████████████████████████ 100% | 15.88/15.88 MB [00:01<00:00, 11.12MB/s]:
# ██                               7% | 35.00/512.23 MB [00:02<00:37, 12.67MB/s]:
# Uploading dataset changes (1424 files compressed to 512.36 MiB) to https://files.clear.ml
# ███▏                            11% | 55.00/512.23 MB [00:04<00:43, 10.45MB/s]:
# ███▌                            12% | 60.00/512.23 MB [00:05<00:41, 10.96MB/s]:
# ███▊                            13% | 65.00/512.23 MB [00:05<00:39, 11.36MB/s]:
# ███████████████████████████████ 100% | 15.65/15.65 MB [00:01<00:00, 11.53MB/s]:
# ████▋                           16% | 80.00/512.23 MB [00:07<00:39, 11.07MB/s]:
# ████▉                           17% | 85.00/512.23 MB [00:07<00:37, 11.44MB/s]:
# █████▎                          18% | 90.00/512.23 MB [00:07<00:36, 11.70MB/s]:
# █████▌                          19% | 95.00/512.23 MB [00:08<00:35, 11.90MB/s]:
# █████▋                         20% | 100.00/512.23 MB [00:08<00:34, 12.02MB/s]:
# █████▉                         20% | 105.00/512.23 MB [00:09<00:37, 10.84MB/s]:
# ██████▏                        21% | 110.00/512.23 MB [00:09<00:35, 11.22MB/s]:
# ██                               7% | 35.00/512.36 MB [00:02<00:37, 12.60MB/s]:
# Uploading dataset changes (1427 files compressed to 512.37 MiB) to https://files.clear.ml
# ██████▌                        22% | 115.00/512.23 MB [00:10<00:43,  9.04MB/s]:
# ██████▊                        23% | 120.00/512.23 MB [00:10<00:40,  9.78MB/s]:
# ███████                        24% | 125.00/512.23 MB [00:11<00:37, 10.37MB/s]:
# ███████▎                       25% | 130.00/512.23 MB [00:11<00:35, 10.84MB/s]:
# ███▏                            11% | 55.00/512.36 MB [00:04<00:42, 10.71MB/s]:
#
# ███████▋                       26% | 135.00/512.23 MB [00:12<00:36, 10.47MB/s]:
# ███▌                            12% | 60.00/512.36 MB [00:05<00:40, 11.09MB/s]:
#
# ███████▉                       27% | 140.00/512.23 MB [00:12<00:34, 10.84MB/s]:
# ███▊                            13% | 65.00/512.36 MB [00:05<00:39, 11.37MB/s]:
#
# ████████▏                      28% | 145.00/512.23 MB [00:13<00:32, 11.18MB/s]:
# ███████████████████████████████ 100% | 15.42/15.42 MB [00:01<00:00, 10.99MB/s]:
# ████████▍                      29% | 150.00/512.23 MB [00:13<00:31, 11.45MB/s]:
# ████████▊                      30% | 155.00/512.23 MB [00:13<00:30, 11.58MB/s]:
#
#                                           0% | 0.00/512.37 MB [00:00<?, ?MB/s]:
# █████████                      31% | 160.00/512.23 MB [00:14<00:29, 11.77MB/s]:
#
# ▌                                2% | 10.00/512.37 MB [00:00<00:21, 23.40MB/s]:
# █████████▎                     32% | 165.00/512.23 MB [00:14<00:31, 11.01MB/s]:
#
# ▉                                3% | 15.00/512.37 MB [00:00<00:30, 16.37MB/s]:
# █████████▌                     33% | 170.00/512.23 MB [00:15<00:30, 11.31MB/s]:
# █████▌                          19% | 95.00/512.36 MB [00:08<00:35, 11.73MB/s]:
#
# █████████▉                     34% | 175.00/512.23 MB [00:15<00:29, 11.53MB/s]:
# █████▋                         20% | 100.00/512.36 MB [00:08<00:34, 11.84MB/s]:
#
# ██████████▏                    35% | 180.00/512.23 MB [00:16<00:28, 11.70MB/s]:
#
# █▊                               6% | 30.00/512.37 MB [00:02<00:37, 12.89MB/s]:
# ██████████▍                    36% | 185.00/512.23 MB [00:16<00:27, 11.77MB/s]:
#
# ██                               7% | 35.00/512.37 MB [00:02<00:37, 12.79MB/s]:
# ██████▏                        21% | 110.00/512.36 MB [00:09<00:35, 11.29MB/s]:
# Uploading dataset changes (1425 files compressed to 512.26 MiB) to https://files.clear.ml
# ██████████▊                    37% | 190.00/512.23 MB [00:17<00:35,  8.99MB/s]:
#
# ██▎                              8% | 40.00/512.37 MB [00:03<00:55,  8.55MB/s]:
# ███████████                    38% | 195.00/512.23 MB [00:17<00:33,  9.54MB/s]:
#
# ██▋                              9% | 45.00/512.37 MB [00:03<00:49,  9.35MB/s]:
# ███████████▎                   39% | 200.00/512.23 MB [00:18<00:31, 10.03MB/s]:
#
# ██▉                             10% | 50.00/512.37 MB [00:04<00:46, 10.00MB/s]:
# ███████████▌                   40% | 205.00/512.23 MB [00:18<00:29, 10.41MB/s]:
#
# ███▏                            11% | 55.00/512.37 MB [00:04<00:43, 10.46MB/s]:
# ███████▎                       25% | 130.00/512.36 MB [00:11<00:36, 10.36MB/s]:
#
#
# ███████████▉                   41% | 210.00/512.23 MB [00:19<00:28, 10.49MB/s]:
#
# ███▌                            12% | 60.00/512.37 MB [00:05<00:44, 10.26MB/s]:
# ███████▋                       26% | 135.00/512.36 MB [00:12<00:37, 10.14MB/s]:
#
#
# ████████████▏                  42% | 215.00/512.23 MB [00:19<00:29, 10.20MB/s]:
#
# ███▊                            13% | 65.00/512.37 MB [00:05<00:44,  9.99MB/s]:
# ███████▉                       27% | 140.00/512.36 MB [00:12<00:37,  9.81MB/s]:
#
#
# ████████████▍                  43% | 220.00/512.23 MB [00:20<00:28, 10.28MB/s]:
#
# ████                            14% | 70.00/512.37 MB [00:06<00:42, 10.29MB/s]:
# ███████████████████████████████ 100% | 15.18/15.18 MB [00:01<00:00,  9.96MB/s]:
# ████████████▋                  44% | 225.00/512.23 MB [00:20<00:27, 10.60MB/s]:
#
# ████▍                           15% | 75.00/512.37 MB [00:06<00:40, 10.74MB/s]:
# █████████████                  45% | 230.00/512.23 MB [00:20<00:26, 10.80MB/s]:
#
# ████▋                           16% | 80.00/512.37 MB [00:07<00:39, 11.00MB/s]:
# █████████████▎                 46% | 235.00/512.23 MB [00:21<00:25, 10.95MB/s]:
#
# ████▉                           17% | 85.00/512.37 MB [00:07<00:38, 11.18MB/s]:
# █████████████▌                 47% | 240.00/512.23 MB [00:21<00:24, 11.10MB/s]:
#
# █████▎                          18% | 90.00/512.37 MB [00:08<00:37, 11.31MB/s]:
# █████████▎                     32% | 165.00/512.36 MB [00:15<00:31, 11.09MB/s]:
#
#
# █████████████▊                 48% | 245.00/512.23 MB [00:22<00:23, 11.23MB/s]:
#
# █████▌                          19% | 95.00/512.37 MB [00:08<00:36, 11.41MB/s]:
# █████████▌                     33% | 170.00/512.36 MB [00:15<00:30, 11.27MB/s]:
#
#
# ██████████████▏                49% | 250.00/512.23 MB [00:22<00:23, 11.40MB/s]:
#
# █████▋                         20% | 100.00/512.37 MB [00:08<00:35, 11.51MB/s]:
# █████████▉                     34% | 175.00/512.36 MB [00:15<00:30, 11.19MB/s]:
#
#
# ██████████████▍                50% | 255.00/512.23 MB [00:23<00:23, 11.15MB/s]:
#
# █████▉                         20% | 105.00/512.37 MB [00:09<00:35, 11.32MB/s]:
# ██████████▏                    35% | 180.00/512.36 MB [00:16<00:30, 10.97MB/s]:
#
#
# ██████████████▋                51% | 260.00/512.23 MB [00:23<00:23, 10.88MB/s]:
#
# ██████▏                        21% | 110.00/512.37 MB [00:09<00:36, 11.02MB/s]:
# ██████████▍                    36% | 185.00/512.36 MB [00:16<00:30, 10.75MB/s]:
#
#
# ███████████████                52% | 265.00/512.23 MB [00:24<00:23, 10.72MB/s]:
#
# ██████▌                        22% | 115.00/512.37 MB [00:10<00:36, 10.85MB/s]:
# ██████████▊                    37% | 190.00/512.36 MB [00:17<00:30, 10.68MB/s]:
#
#
# ███████████████▎               53% | 270.00/512.23 MB [00:24<00:22, 10.73MB/s]:
#
# ██████▊                        23% | 120.00/512.37 MB [00:10<00:36, 10.80MB/s]:
# ███████████                    38% | 195.00/512.36 MB [00:17<00:30, 10.58MB/s]:
#
#
# ███████████████▌               54% | 275.00/512.23 MB [00:25<00:22, 10.59MB/s]:
#
# ███████                        24% | 125.00/512.37 MB [00:11<00:35, 10.77MB/s]:
# ███████████▎                   39% | 200.00/512.36 MB [00:18<00:29, 10.56MB/s]:
#
#
# ███████████████▊               55% | 280.00/512.23 MB [00:25<00:22, 10.53MB/s]:
#
# ███████▎                       25% | 130.00/512.37 MB [00:11<00:35, 10.70MB/s]:
# ███████████▌                   40% | 205.00/512.36 MB [00:18<00:29, 10.58MB/s]:
#
#
# ████████████████▏              56% | 285.00/512.23 MB [00:26<00:21, 10.54MB/s]:
#
# ███████▋                       26% | 135.00/512.37 MB [00:12<00:35, 10.65MB/s]:
# ███████████▉                   41% | 210.00/512.36 MB [00:19<00:28, 10.58MB/s]:
#
#
# ████████████████▍              57% | 290.00/512.23 MB [00:26<00:21, 10.50MB/s]:
#
# ███████▉                       27% | 140.00/512.37 MB [00:12<00:35, 10.59MB/s]:
# ████████████▏                  42% | 215.00/512.36 MB [00:19<00:28, 10.56MB/s]:
#
#
# ████████████████▋              58% | 295.00/512.23 MB [00:27<00:20, 10.49MB/s]:
#
# ████████▏                      28% | 145.00/512.37 MB [00:13<00:34, 10.57MB/s]:
# ████████████▍                  43% | 220.00/512.36 MB [00:20<00:27, 10.52MB/s]:
#
#
# ████████████████▉              59% | 300.00/512.23 MB [00:27<00:20, 10.58MB/s]:
#
# ████████▍                      29% | 150.00/512.37 MB [00:13<00:34, 10.52MB/s]:
# ████████████▋                  44% | 225.00/512.36 MB [00:20<00:27, 10.56MB/s]:
#
#
# █████████████████▎             60% | 305.00/512.23 MB [00:27<00:19, 10.56MB/s]:
#
# ████████▊                      30% | 155.00/512.37 MB [00:14<00:33, 10.59MB/s]:
# █████████████                  45% | 230.00/512.36 MB [00:21<00:26, 10.54MB/s]:
#
#
# █████████████████▌             61% | 310.00/512.23 MB [00:28<00:19, 10.57MB/s]:
#
# █████████                      31% | 160.00/512.37 MB [00:14<00:33, 10.52MB/s]:
# █████████████▎                 46% | 235.00/512.36 MB [00:21<00:26, 10.55MB/s]:
#
#
# █████████████████▊             61% | 315.00/512.23 MB [00:28<00:18, 10.51MB/s]:
#
# █████████▎                     32% | 165.00/512.37 MB [00:15<00:33, 10.51MB/s]:
# █████████████▌                 47% | 240.00/512.36 MB [00:22<00:25, 10.54MB/s]:
#
#
# ██████████████████             62% | 320.00/512.23 MB [00:29<00:18, 10.44MB/s]:
#
# █████████▌                     33% | 170.00/512.37 MB [00:15<00:32, 10.43MB/s]:
# █████████████▊                 48% | 245.00/512.36 MB [00:22<00:25, 10.52MB/s]:
#
#
# ██████████████████▍            63% | 325.00/512.23 MB [00:29<00:18, 10.34MB/s]:
#
# █████████▉                     34% | 175.00/512.37 MB [00:16<00:32, 10.27MB/s]:
# ██████████████▏                49% | 250.00/512.36 MB [00:23<00:25, 10.49MB/s]:
#
#
# ██████████████████▋            64% | 330.00/512.23 MB [00:30<00:17, 10.40MB/s]:
#
# ██████████▏                    35% | 180.00/512.37 MB [00:16<00:31, 10.42MB/s]:
# ██████████████▍                50% | 255.00/512.36 MB [00:23<00:24, 10.51MB/s]:
#
#
# ██████████████████▉            65% | 335.00/512.23 MB [00:30<00:16, 10.43MB/s]:
#
# ██████████▍                    36% | 185.00/512.37 MB [00:16<00:31, 10.43MB/s]:
# ██████████████▋                51% | 260.00/512.36 MB [00:23<00:24, 10.51MB/s]:
#
#
# ███████████████████▏           66% | 340.00/512.23 MB [00:31<00:16, 10.52MB/s]:
#
# ██████████▊                    37% | 190.00/512.37 MB [00:17<00:30, 10.43MB/s]:
# ██████████████▉                52% | 265.00/512.36 MB [00:24<00:23, 10.61MB/s]:
#
#
# ███████████████████▌           67% | 345.00/512.23 MB [00:31<00:15, 10.48MB/s]:
#
# ███████████                    38% | 195.00/512.37 MB [00:17<00:30, 10.44MB/s]:
# ███████████████▎               53% | 270.00/512.36 MB [00:24<00:22, 10.59MB/s]:
#
#
# ███████████████████▊           68% | 350.00/512.23 MB [00:32<00:15, 10.47MB/s]:
#
# ███████████▎                   39% | 200.00/512.37 MB [00:18<00:29, 10.47MB/s]:
# ███████████████▌               54% | 275.00/512.36 MB [00:25<00:22, 10.55MB/s]:
#
#
# ████████████████████           69% | 355.00/512.23 MB [00:32<00:14, 10.51MB/s]:
#
# ███████████▌                   40% | 205.00/512.37 MB [00:18<00:29, 10.42MB/s]:
# ███████████████▊               55% | 280.00/512.36 MB [00:25<00:21, 10.63MB/s]:
#
#
# ████████████████████▍          70% | 360.00/512.23 MB [00:33<00:14, 10.51MB/s]:
#
# ███████████▉                   41% | 210.00/512.37 MB [00:19<00:28, 10.49MB/s]:
# ████████████████▏              56% | 285.00/512.36 MB [00:26<00:21, 10.49MB/s]:
#
#
# ████████████████████▋          71% | 365.00/512.23 MB [00:33<00:14, 10.52MB/s]:
#
# ████████████▏                  42% | 215.00/512.37 MB [00:19<00:28, 10.43MB/s]:
# ████████████████▍              57% | 290.00/512.36 MB [00:26<00:21, 10.43MB/s]:
#
#
# ████████████████████▉          72% | 370.00/512.23 MB [00:34<00:13, 10.55MB/s]:
#
# ████████████▍                  43% | 220.00/512.37 MB [00:20<00:28, 10.35MB/s]:
# █████████████████████▏         73% | 375.00/512.23 MB [00:34<00:12, 10.81MB/s]:
#
# ████████████▋                  44% | 225.00/512.37 MB [00:20<00:26, 10.72MB/s]:
# ████████████████▉              59% | 300.00/512.36 MB [00:27<00:19, 10.83MB/s]:
#
#
# █████████████████████▌         74% | 380.00/512.23 MB [00:35<00:12, 10.87MB/s]:
#
# █████████████                  45% | 230.00/512.37 MB [00:21<00:25, 10.99MB/s]:
# █████████████████▎             60% | 305.00/512.36 MB [00:28<00:19, 10.91MB/s]:
#
#
# █████████████████████▊         75% | 385.00/512.23 MB [00:35<00:11, 11.04MB/s]:
#
# █████████████▎                 46% | 235.00/512.37 MB [00:21<00:24, 11.19MB/s]:
# ██████████████████████         76% | 390.00/512.23 MB [00:35<00:10, 11.18MB/s]:
#
# █████████████▌                 47% | 240.00/512.37 MB [00:22<00:24, 11.31MB/s]:
# █████████████████▊             61% | 315.00/512.36 MB [00:29<00:17, 11.10MB/s]:
#
#
# ██████████████████████▎        77% | 395.00/512.23 MB [00:36<00:10, 11.10MB/s]:
#
# █████████████▊                 48% | 245.00/512.37 MB [00:22<00:24, 11.11MB/s]:
# ██████████████████             62% | 320.00/512.36 MB [00:29<00:17, 11.05MB/s]:
#
#
# ██████████████████████▋        78% | 400.00/512.23 MB [00:36<00:10, 11.21MB/s]:
#
# ██████████████▏                49% | 250.00/512.37 MB [00:22<00:23, 11.36MB/s]:
# ██████████████████████▉        79% | 405.00/512.23 MB [00:37<00:09, 11.28MB/s]:
#
# ██████████████▍                50% | 255.00/512.37 MB [00:23<00:22, 11.40MB/s]:
#
#
# ████████▊                      30% | 155.00/512.26 MB [00:15<00:42,  8.44MB/s]:
# ███████████████████████▏       80% | 410.00/512.23 MB [00:37<00:09, 11.31MB/s]:
#
# ██████████████▋                51% | 260.00/512.37 MB [00:23<00:22, 11.35MB/s]:
#
#
# █████████                      31% | 160.00/512.26 MB [00:15<00:40,  8.71MB/s]:
# ███████████████████████▍       81% | 415.00/512.23 MB [00:38<00:08, 11.26MB/s]:
#
# ██████████████▉                52% | 265.00/512.37 MB [00:24<00:21, 11.25MB/s]:
#
#
# █████████▎                     32% | 165.00/512.26 MB [00:16<00:38,  9.12MB/s]:
# ███████████████████████▊       82% | 420.00/512.23 MB [00:38<00:08, 11.25MB/s]:
#
# ███████████████▎               53% | 270.00/512.37 MB [00:24<00:21, 11.48MB/s]:
# ███████████████████▌           67% | 345.00/512.36 MB [00:31<00:15, 11.13MB/s]:
#
#
# ████████████████████████       83% | 425.00/512.23 MB [00:39<00:07, 11.14MB/s]:
#
# ███████████████▌               54% | 275.00/512.37 MB [00:25<00:21, 11.29MB/s]:
# ███████████████████▊           68% | 350.00/512.36 MB [00:32<00:14, 11.03MB/s]:
#
#
# ████████████████████████▎      84% | 430.00/512.23 MB [00:39<00:07, 11.05MB/s]:
#
# ███████████████▊               55% | 280.00/512.37 MB [00:25<00:20, 11.15MB/s]:
# ████████████████████           69% | 355.00/512.36 MB [00:32<00:14, 10.92MB/s]:
#
#
# ████████████████████████▋      85% | 435.00/512.23 MB [00:39<00:07, 10.92MB/s]:
#
# ████████████████▏              56% | 285.00/512.37 MB [00:26<00:20, 11.10MB/s]:
# ████████████████████▍          70% | 360.00/512.36 MB [00:33<00:13, 10.92MB/s]:
#
#
# ████████████████████████▉      86% | 440.00/512.23 MB [00:40<00:06, 10.97MB/s]:
#
# ████████████████▍              57% | 290.00/512.37 MB [00:26<00:20, 10.97MB/s]:
# ████████████████████▋          71% | 365.00/512.36 MB [00:33<00:13, 10.79MB/s]:
#
#
# █████████████████████████▏     87% | 445.00/512.23 MB [00:40<00:06, 10.96MB/s]:
#
# ████████████████▋              58% | 295.00/512.37 MB [00:26<00:19, 11.06MB/s]:
# █████████████████████████▍     88% | 450.00/512.23 MB [00:41<00:05, 11.09MB/s]:
#
# ████████████████▉              59% | 300.00/512.37 MB [00:27<00:19, 11.14MB/s]:
# █████████████████████▏         73% | 375.00/512.36 MB [00:34<00:12, 11.12MB/s]:
#
#
# █████████████████████████▊     89% | 455.00/512.23 MB [00:41<00:05, 11.22MB/s]:
#
# █████████████████▎             60% | 305.00/512.37 MB [00:27<00:18, 11.35MB/s]:
# ██████████████████████████     90% | 460.00/512.23 MB [00:42<00:04, 11.32MB/s]:
#
# █████████████████▌             61% | 310.00/512.37 MB [00:28<00:17, 11.42MB/s]:
#
#
# ███████████▎                   39% | 200.00/512.26 MB [00:20<00:40,  7.76MB/s]:
# ██████████████████████████▎    91% | 465.00/512.23 MB [00:42<00:04, 11.33MB/s]:
#
# █████████████████▊             61% | 315.00/512.37 MB [00:28<00:17, 11.49MB/s]:
# ██████████████████████████▌    92% | 470.00/512.23 MB [00:43<00:03, 11.35MB/s]:
#
# ██████████████████             62% | 320.00/512.37 MB [00:29<00:16, 11.56MB/s]:
#
#
# ███████████▌                   40% | 205.00/512.26 MB [00:21<00:42,  7.31MB/s]:
# ██████████████████████▎        77% | 395.00/512.36 MB [00:36<00:10, 11.44MB/s]:
#
# ██████████████████████████▉    93% | 475.00/512.23 MB [00:43<00:03, 11.44MB/s]:
# ██████████████████████▋        78% | 400.00/512.36 MB [00:36<00:09, 11.47MB/s]:
#
# ███████████████████████████▏   94% | 480.00/512.23 MB [00:43<00:02, 11.55MB/s]:
#
#
# ███████████▉                   41% | 210.00/512.26 MB [00:21<00:43,  6.93MB/s]:
# ██████████████████████▉        79% | 405.00/512.36 MB [00:37<00:09, 11.43MB/s]:
#
# ███████████████████████████▍   95% | 485.00/512.23 MB [00:44<00:02, 11.49MB/s]:
# ███████████████████████▏       80% | 410.00/512.36 MB [00:37<00:08, 11.46MB/s]:
#
# ███████████████████████████▋   96% | 490.00/512.23 MB [00:44<00:01, 11.49MB/s]:
#
#
# ████████████▏                  42% | 215.00/512.26 MB [00:22<00:46,  6.37MB/s]:
# ███████████████████████▍       81% | 415.00/512.36 MB [00:37<00:08, 11.45MB/s]:
#
# ████████████████████████████   97% | 495.00/512.23 MB [00:45<00:01, 11.54MB/s]:
# ███████████████████████▊       82% | 420.00/512.36 MB [00:38<00:08, 11.45MB/s]:
#
# ████████████████████████████▎  98% | 500.00/512.23 MB [00:45<00:01, 11.50MB/s]:
# ████████████████████████       83% | 425.00/512.36 MB [00:38<00:07, 11.46MB/s]:
#
# ████████████████████           69% | 355.00/512.37 MB [00:32<00:13, 11.90MB/s]:
#
#
# ████████████████████████████▌  99% | 505.00/512.23 MB [00:46<00:00, 11.48MB/s]:
# ████████████████████████▎      84% | 430.00/512.36 MB [00:39<00:07, 11.44MB/s]:
#
# █████████████████████████████ 100% | 512.23/512.23 MB [00:46<00:00, 11.51MB/s]:
# ████████████████████████▌      85% | 435.00/512.36 MB [00:39<00:06, 11.48MB/s]:
#
# ████████████████████▋          71% | 365.00/512.37 MB [00:32<00:12, 11.76MB/s]:
#
#
# ████████████▋                  44% | 225.00/512.26 MB [00:24<00:53,  5.37MB/s]:
# ████████████████████████▉      86% | 440.00/512.36 MB [00:40<00:06, 11.57MB/s]:
#
# ████████████████████▉          72% | 370.00/512.37 MB [00:33<00:12, 11.72MB/s]:
# █████████████████████████▏     87% | 445.00/512.36 MB [00:40<00:05, 11.53MB/s]:
#
# █████████████████████▏         73% | 375.00/512.37 MB [00:33<00:11, 11.74MB/s]:
# █████████████████████████▍     88% | 450.00/512.36 MB [00:41<00:05, 11.49MB/s]:
#
# █████████████████████▌         74% | 380.00/512.37 MB [00:34<00:11, 11.78MB/s]:
#
#
# █████████████                  45% | 230.00/512.26 MB [00:26<01:00,  4.69MB/s]:
# █████████████████████████▊     89% | 455.00/512.36 MB [00:41<00:04, 11.48MB/s]:
#
# █████████████████████▊         75% | 385.00/512.37 MB [00:34<00:10, 11.92MB/s]:
# ██████████████████████████     90% | 460.00/512.36 MB [00:41<00:04, 11.48MB/s]:
#
# ██████████████████████         76% | 390.00/512.37 MB [00:35<00:10, 11.89MB/s]:
# ██████████████████████████▎    91% | 465.00/512.36 MB [00:42<00:04, 11.51MB/s]:
#
# ██████████████████████▎        77% | 395.00/512.37 MB [00:35<00:09, 11.77MB/s]:
# ██████████████████████████▌    92% | 470.00/512.36 MB [00:42<00:03, 11.60MB/s]:
#
# ██████████████████████▋        78% | 400.00/512.37 MB [00:35<00:09, 11.72MB/s]:
#
#
# █████████████▎                 46% | 235.00/512.26 MB [00:28<01:10,  3.93MB/s]:
#
# ██████████████████████▉        79% | 405.00/512.37 MB [00:36<00:09, 11.75MB/s]:
# █████████████████████████████ 100% | 512.23/512.23 MB [00:50<00:00, 10.12MB/s]:
#
#
# ███████████████████████▏       80% | 410.00/512.37 MB [00:36<00:08, 11.78MB/s]:
# ███████████████████████████▏   94% | 480.00/512.36 MB [00:43<00:02, 11.50MB/s]:
#
# ███████████████████████▍       81% | 415.00/512.37 MB [00:37<00:08, 11.94MB/s]:
# ███████████████████████████▍   95% | 485.00/512.36 MB [00:44<00:02, 11.50MB/s]:
#
# ███████████████████████▊       82% | 420.00/512.37 MB [00:37<00:07, 11.89MB/s]:
# ███████████████████████████▋   96% | 490.00/512.36 MB [00:44<00:01, 11.49MB/s]:
#
# ████████████████████████       83% | 425.00/512.37 MB [00:38<00:07, 11.78MB/s]:
# ████████████████████████████   97% | 495.00/512.36 MB [00:44<00:01, 11.50MB/s]:
#
#
# █████████████▌                 47% | 240.00/512.26 MB [00:30<01:21,  3.34MB/s]:
#
# ████████████████████████▎      84% | 430.00/512.37 MB [00:38<00:07, 11.72MB/s]:
# ████████████████████████████▎  98% | 500.00/512.36 MB [00:45<00:01, 11.60MB/s]:
#
# ████████████████████████▌      85% | 435.00/512.37 MB [00:38<00:06, 11.76MB/s]:
# ████████████████████████████▌  99% | 505.00/512.36 MB [00:45<00:00, 11.52MB/s]:
#
# ████████████████████████▉      86% | 440.00/512.37 MB [00:39<00:06, 11.78MB/s]:
# ████████████████████████████▊ 100% | 510.00/512.36 MB [00:46<00:00, 11.49MB/s]:
# ████████████████████████████▉ 100% | 512.35/512.36 MB [00:46<00:00, 11.47MB/s]:
#
# █████████████████████████▏     87% | 445.00/512.37 MB [00:39<00:05, 11.92MB/s]:
#
# █████████████████████████▍     88% | 450.00/512.37 MB [00:40<00:05, 11.90MB/s]:
#
#
# █████████████▊                 48% | 245.00/512.26 MB [00:32<01:27,  3.06MB/s]:
#
# █████████████████████████▊     89% | 455.00/512.37 MB [00:40<00:04, 11.77MB/s]:
#
# ██████████████████████████     90% | 460.00/512.37 MB [00:40<00:04, 11.72MB/s]:
#
# ██████████████████████████▎    91% | 465.00/512.37 MB [00:41<00:04, 11.77MB/s]:
#
# ██████████████████████████▌    92% | 470.00/512.37 MB [00:41<00:03, 11.78MB/s]:
#
#
# ██████████████▏                49% | 250.00/512.26 MB [00:33<01:30,  2.91MB/s]:
#
# ██████████████████████████▉    93% | 475.00/512.37 MB [00:42<00:03, 11.92MB/s]:
#
# ███████████████████████████▏   94% | 480.00/512.37 MB [00:42<00:02, 11.88MB/s]:
#
# █████████████████████████████ 100% | 512.36/512.36 MB [00:50<00:00, 10.17MB/s]:
#
#
# ███████████████████████████▋   96% | 490.00/512.37 MB [00:43<00:01, 11.70MB/s]:
#
# ████████████████████████████   97% | 495.00/512.37 MB [00:43<00:01, 11.79MB/s]:
#
#
# ██████████████▍                50% | 255.00/512.26 MB [00:35<01:31,  2.81MB/s]:
#
# ████████████████████████████▎  98% | 500.00/512.37 MB [00:44<00:01, 11.80MB/s]:
#
# ████████████████████████████▌  99% | 505.00/512.37 MB [00:44<00:00, 11.93MB/s]:
#
# ████████████████████████████▊ 100% | 510.00/512.37 MB [00:45<00:00, 11.87MB/s]:
#
# █████████████████████████████ 100% | 512.37/512.37 MB [00:45<00:00, 11.82MB/s]:
#
#
# ██████████████▋                51% | 260.00/512.26 MB [00:37<01:32,  2.74MB/s]:
#
#
# █████████████████████████████ 100% | 512.37/512.37 MB [00:49<00:00, 10.38MB/s]:
#
#
#
# ███████████████▎               53% | 270.00/512.26 MB [00:41<01:30,  2.67MB/s]:
#
#
# ███████████████▌               54% | 275.00/512.26 MB [00:43<01:27,  2.70MB/s]:
#
#
# ███████████████▊               55% | 280.00/512.26 MB [00:45<01:23,  2.79MB/s]:
#
#
# ████████████████▏              56% | 285.00/512.26 MB [00:46<01:19,  2.85MB/s]:
#
#
# ████████████████▍              57% | 290.00/512.26 MB [00:48<01:16,  2.89MB/s]:
#
#
# ████████████████▋              58% | 295.00/512.26 MB [00:50<01:14,  2.93MB/s]:
#
#
# ████████████████▉              59% | 300.00/512.26 MB [00:51<01:10,  3.03MB/s]:
#
#
# █████████████████▎             60% | 305.00/512.26 MB [00:52<01:04,  3.19MB/s]:
#
#
# █████████████████▌             61% | 310.00/512.26 MB [00:54<00:59,  3.41MB/s]:
#
#
# █████████████████▊             61% | 315.00/512.26 MB [00:55<00:53,  3.72MB/s]:
#
#
# ██████████████████             62% | 320.00/512.26 MB [00:56<00:47,  4.05MB/s]:
#
#
# ██████████████████▍            63% | 325.00/512.26 MB [00:56<00:41,  4.54MB/s]:
#
#
# ██████████████████▋            64% | 330.00/512.26 MB [00:57<00:36,  5.02MB/s]:
#
#
# ██████████████████▉            65% | 335.00/512.26 MB [00:58<00:31,  5.66MB/s]:
#
#
# ███████████████████▏           66% | 340.00/512.26 MB [00:58<00:27,  6.29MB/s]:
#
#
# ███████████████████▌           67% | 345.00/512.26 MB [00:59<00:24,  6.85MB/s]:
#
#
# ███████████████████▊           68% | 350.00/512.26 MB [01:00<00:21,  7.57MB/s]:
#
#
# ████████████████████           69% | 355.00/512.26 MB [01:00<00:19,  8.25MB/s]:
#
#
# ████████████████████▍          70% | 360.00/512.26 MB [01:00<00:16,  9.18MB/s]:
#
#
# ████████████████████▋          71% | 365.00/512.26 MB [01:01<00:14,  9.89MB/s]:
#
#
# ████████████████████▉          72% | 370.00/512.26 MB [01:01<00:14, 10.14MB/s]:
#
#
# █████████████████████▏         73% | 375.00/512.26 MB [01:02<00:12, 10.70MB/s]:
#
#
# █████████████████████▌         74% | 380.00/512.26 MB [01:02<00:12, 10.73MB/s]:
#
#
# █████████████████████▊         75% | 385.00/512.26 MB [01:03<00:11, 11.18MB/s]:
#
#
# ██████████████████████         76% | 390.00/512.26 MB [01:03<00:10, 11.53MB/s]:
#
#
# ██████████████████████▎        77% | 395.00/512.26 MB [01:03<00:10, 11.70MB/s]:
#
#
# ██████████████████████▋        78% | 400.00/512.26 MB [01:04<00:09, 11.43MB/s]:
#
#
# ██████████████████████▉        79% | 405.00/512.26 MB [01:04<00:09, 11.67MB/s]:
#
#
# ███████████████████████▏       80% | 410.00/512.26 MB [01:05<00:08, 11.40MB/s]:
#
#
# ███████████████████████▍       81% | 415.00/512.26 MB [01:05<00:08, 11.67MB/s]:
#
#
# ███████████████████████▊       82% | 420.00/512.26 MB [01:06<00:07, 11.87MB/s]:
#
#
# ████████████████████████       83% | 425.00/512.26 MB [01:06<00:08,  9.98MB/s]:
#
#
# ████████████████████████▎      84% | 430.00/512.26 MB [01:07<00:07, 10.54MB/s]:
#
#
# ████████████████████████▋      85% | 435.00/512.26 MB [01:07<00:07,  9.89MB/s]:
#
#
# ████████████████████████▉      86% | 440.00/512.26 MB [01:08<00:07,  9.52MB/s]:
#
#
# █████████████████████████▏     87% | 445.00/512.26 MB [01:08<00:06, 10.16MB/s]:
#
#
# █████████████████████████▍     88% | 450.00/512.26 MB [01:09<00:06, 10.37MB/s]:
#
#
# █████████████████████████▊     89% | 455.00/512.26 MB [01:09<00:05, 10.15MB/s]:
#
#
# ██████████████████████████     90% | 460.00/512.26 MB [01:10<00:04, 10.62MB/s]:
#
#
# ██████████████████████████▎    91% | 465.00/512.26 MB [01:10<00:04, 10.18MB/s]:
#
#
# ██████████████████████████▌    92% | 470.00/512.26 MB [01:11<00:04, 10.03MB/s]:
#
#
# ██████████████████████████▉    93% | 475.00/512.26 MB [01:11<00:03, 10.62MB/s]:
#
#
# ███████████████████████████▏   94% | 480.00/512.26 MB [01:11<00:02, 11.07MB/s]:
#
#
# ███████████████████████████▍   95% | 485.00/512.26 MB [01:12<00:02, 11.40MB/s]:
#
#
# ███████████████████████████▋   96% | 490.00/512.26 MB [01:12<00:01, 11.65MB/s]:
#
#
# ████████████████████████████   97% | 495.00/512.26 MB [01:13<00:01, 11.03MB/s]:
#
#
# ████████████████████████████▎  98% | 500.00/512.26 MB [01:13<00:01, 11.36MB/s]:
#
#
# ████████████████████████████▌  99% | 505.00/512.26 MB [01:14<00:00, 11.56MB/s]:
#
#
# ████████████████████████████▊ 100% | 510.00/512.26 MB [01:14<00:00, 11.72MB/s]:
#
#
# ████████████████████████████▉ 100% | 512.25/512.26 MB [01:14<00:00, 11.72MB/s]:
# Uploading dataset changes (6395 files compressed to 485.37 MiB) to https://files.clear.ml
# █████████████████████████████ 100% | 512.26/512.26 MB [01:18<00:00,  6.52MB/s]:
# ███████████████████████████████ 100% | 14.11/14.11 MB [00:01<00:00, 11.52MB/s]:
# ███▋                            12% | 60.00/485.37 MB [00:04<00:36, 11.67MB/s]:
# Uploading dataset changes (6389 files compressed to 484.33 MiB) to https://files.clear.ml
# ████▉                           16% | 80.00/485.37 MB [00:06<00:40, 10.06MB/s]:
# █████▎                          18% | 85.00/485.37 MB [00:07<00:37, 10.66MB/s]:
# █████▌                          19% | 90.00/485.37 MB [00:07<00:35, 11.14MB/s]:
# ███████████████████████████████ 100% | 13.03/13.03 MB [00:01<00:00, 11.18MB/s]:
# █████▉                         21% | 100.00/485.37 MB [00:08<00:32, 11.74MB/s]:
# ██████▎                        22% | 105.00/485.37 MB [00:08<00:31, 11.94MB/s]:
# ▌                                2% | 10.00/484.33 MB [00:00<00:19, 24.58MB/s]:
# ██████▊                        24% | 115.00/485.37 MB [00:09<00:33, 11.18MB/s]:
# ███████▏                       25% | 120.00/485.37 MB [00:10<00:31, 11.52MB/s]:
# ███████▍                       26% | 125.00/485.37 MB [00:10<00:30, 11.77MB/s]:
# ███████▊                       27% | 130.00/485.37 MB [00:11<00:29, 11.96MB/s]:
# ████████                       28% | 135.00/485.37 MB [00:11<00:31, 11.24MB/s]:
# ██▍                              8% | 40.00/484.33 MB [00:03<00:35, 12.38MB/s]:
# Uploading dataset changes (6376 files compressed to 483.17 MiB) to https://files.clear.ml
# ████████▎                      29% | 140.00/485.37 MB [00:12<00:37,  9.19MB/s]:
# ████████▋                      30% | 145.00/485.37 MB [00:12<00:34,  9.93MB/s]:
# ████████▉                      31% | 150.00/485.37 MB [00:13<00:31, 10.53MB/s]:
# █████████▎                     32% | 155.00/485.37 MB [00:13<00:30, 10.99MB/s]:
# ███▋                            12% | 60.00/484.33 MB [00:05<00:39, 10.64MB/s]:
#
# █████████▌                     33% | 160.00/485.37 MB [00:14<00:28, 11.33MB/s]:
# ████                            13% | 65.00/484.33 MB [00:05<00:38, 11.02MB/s]:
#
# █████████▊                     34% | 165.00/485.37 MB [00:14<00:27, 11.58MB/s]:
# ███████████████████████████████ 100% | 11.96/11.96 MB [00:00<00:00, 12.01MB/s]:
# ██████████▏                    35% | 170.00/485.37 MB [00:14<00:29, 10.86MB/s]:
# ██████████▍                    36% | 175.00/485.37 MB [00:15<00:27, 11.25MB/s]:
# ████▉                           17% | 80.00/484.33 MB [00:06<00:37, 10.81MB/s]:
#
# ██████████▊                    37% | 180.00/485.37 MB [00:15<00:26, 11.53MB/s]:
# █████▎                          18% | 85.00/484.33 MB [00:07<00:35, 11.17MB/s]:
#
# ███████████                    38% | 185.00/485.37 MB [00:16<00:25, 11.73MB/s]:
# █████▌                          19% | 90.00/484.33 MB [00:07<00:34, 11.41MB/s]:
#
# ███████████▎                   39% | 190.00/485.37 MB [00:16<00:24, 11.88MB/s]:
# ███████████▋                   40% | 195.00/485.37 MB [00:17<00:24, 11.75MB/s]:
#
# █▏                               4% | 20.00/483.17 MB [00:01<00:36, 12.81MB/s]:
# █████▉                         21% | 100.00/484.33 MB [00:08<00:32, 11.76MB/s]:
#
# ███████████▉                   41% | 200.00/485.37 MB [00:17<00:25, 11.17MB/s]:
# ██████▎                        22% | 105.00/484.33 MB [00:09<00:31, 11.88MB/s]:
#
# ████████████▏                  42% | 205.00/485.37 MB [00:17<00:24, 11.49MB/s]:
# ██████▌                        23% | 110.00/484.33 MB [00:09<00:34, 11.00MB/s]:
#
# ████████████▌                  43% | 210.00/485.37 MB [00:18<00:23, 11.69MB/s]:
# Uploading dataset changes (6367 files compressed to 483.13 MiB) to https://files.clear.ml
# ██████▉                        24% | 115.00/484.33 MB [00:10<00:38,  9.53MB/s]:
#
# ████████████▊                  44% | 215.00/485.37 MB [00:19<00:27,  9.75MB/s]:
# ███████▏                       25% | 120.00/484.33 MB [00:10<00:36,  9.91MB/s]:
#
# █████████████▏                 45% | 220.00/485.37 MB [00:19<00:26, 10.20MB/s]:
# ███████▍                       26% | 125.00/484.33 MB [00:11<00:34, 10.30MB/s]:
#
# █████████████▍                 46% | 225.00/485.37 MB [00:19<00:24, 10.53MB/s]:
# ███████▊                       27% | 130.00/484.33 MB [00:11<00:33, 10.61MB/s]:
#
# █████████████▋                 47% | 230.00/485.37 MB [00:20<00:23, 10.79MB/s]:
#
#
#                                            0% | 0.00/10.89 MB [00:00<?, ?MB/s]:
# ████████                       28% | 135.00/484.33 MB [00:12<00:32, 10.76MB/s]:
#
# ██████████████                 48% | 235.00/485.37 MB [00:20<00:23, 10.77MB/s]:
#
#
# ████████████████████████████▍    92% | 10.00/10.89 MB [00:00<00:00, 17.56MB/s]:
# ████████▍                      29% | 140.00/484.33 MB [00:12<00:33, 10.34MB/s]:
#
# ███████████████████████████████ 100% | 10.89/10.89 MB [00:01<00:00, 10.55MB/s]:
#
# ████████▋                      30% | 145.00/484.33 MB [00:13<00:32, 10.55MB/s]:
#
# ██████████████▋                50% | 245.00/485.37 MB [00:21<00:22, 10.72MB/s]:
# ████████▉                      31% | 150.00/484.33 MB [00:13<00:30, 10.80MB/s]:
#
# ██████████████▉                52% | 250.00/485.37 MB [00:22<00:21, 11.03MB/s]:
# █████████▎                     32% | 155.00/484.33 MB [00:13<00:29, 10.99MB/s]:
#
# ███████████████▏               53% | 255.00/485.37 MB [00:22<00:20, 11.20MB/s]:
# █████████▌                     33% | 160.00/484.33 MB [00:14<00:29, 11.08MB/s]:
#
# ███████████████▌               54% | 260.00/485.37 MB [00:23<00:19, 11.27MB/s]:
#
#
#                                           0% | 0.00/483.13 MB [00:00<?, ?MB/s]:
# █████████▉                     34% | 165.00/484.33 MB [00:14<00:28, 11.18MB/s]:
#
# ███████████████▊               55% | 265.00/485.37 MB [00:23<00:19, 11.28MB/s]:
#
#
# ▌                                2% | 10.00/483.13 MB [00:00<00:23, 20.04MB/s]:
# ██████████▏                    35% | 170.00/484.33 MB [00:15<00:28, 11.13MB/s]:
#
# ████████████████▏              56% | 270.00/485.37 MB [00:23<00:19, 11.18MB/s]:
#
#
# ▉                                3% | 15.00/483.13 MB [00:00<00:32, 14.46MB/s]:
# ██████████▍                    36% | 175.00/484.33 MB [00:15<00:28, 10.97MB/s]:
#
# ████████████████▍              57% | 275.00/485.37 MB [00:24<00:19, 11.01MB/s]:
#
#
# █▏                               4% | 20.00/483.13 MB [00:01<00:37, 12.43MB/s]:
# ██████████▊                    37% | 180.00/484.33 MB [00:16<00:28, 10.67MB/s]:
#
# ████████████████▋              58% | 280.00/485.37 MB [00:24<00:19, 10.77MB/s]:
#
#
# █▌                               5% | 25.00/483.13 MB [00:01<00:39, 11.65MB/s]:
# ███████████                    38% | 185.00/484.33 MB [00:16<00:28, 10.60MB/s]:
#
# █████████████████              59% | 285.00/485.37 MB [00:25<00:19, 10.43MB/s]:
#
#
# █▊                               6% | 30.00/483.13 MB [00:02<00:41, 11.05MB/s]:
# ███████████▍                   39% | 190.00/484.33 MB [00:17<00:28, 10.39MB/s]:
#
# █████████████████▎             60% | 290.00/485.37 MB [00:25<00:18, 10.38MB/s]:
#
#
# ██▏                              7% | 35.00/483.13 MB [00:02<00:40, 10.96MB/s]:
# ███████████▋                   40% | 195.00/484.33 MB [00:17<00:27, 10.48MB/s]:
#
# █████████████████▋             61% | 295.00/485.37 MB [00:26<00:18, 10.45MB/s]:
#
#
# ██▍                              8% | 40.00/483.13 MB [00:03<00:41, 10.76MB/s]:
# ███████████▉                   41% | 200.00/484.33 MB [00:18<00:27, 10.50MB/s]:
#
# █████████████████▉             62% | 300.00/485.37 MB [00:26<00:17, 10.45MB/s]:
#
#
# ██▊                              9% | 45.00/483.13 MB [00:03<00:40, 10.74MB/s]:
# ████████████▎                  42% | 205.00/484.33 MB [00:18<00:26, 10.58MB/s]:
#
# ██████████████████▏            63% | 305.00/485.37 MB [00:27<00:17, 10.45MB/s]:
#
#
# ███                             10% | 50.00/483.13 MB [00:04<00:40, 10.65MB/s]:
# ████████████▌                  43% | 210.00/484.33 MB [00:19<00:26, 10.54MB/s]:
#
# ██████████████████▌            64% | 310.00/485.37 MB [00:27<00:16, 10.44MB/s]:
#
#
# ███▍                            11% | 55.00/483.13 MB [00:04<00:40, 10.63MB/s]:
# ████████████▊                  44% | 215.00/484.33 MB [00:19<00:25, 10.54MB/s]:
#
# ██████████████████▊            65% | 315.00/485.37 MB [00:28<00:16, 10.45MB/s]:
#
#
# ███▋                            12% | 60.00/483.13 MB [00:05<00:39, 10.66MB/s]:
# █████████████▏                 45% | 220.00/484.33 MB [00:20<00:25, 10.49MB/s]:
#
# ███████████████████            66% | 320.00/485.37 MB [00:28<00:15, 10.36MB/s]:
#
#
# ████                            13% | 65.00/483.13 MB [00:05<00:39, 10.61MB/s]:
# █████████████▍                 46% | 225.00/484.33 MB [00:20<00:24, 10.49MB/s]:
#
# ███████████████████▍           67% | 325.00/485.37 MB [00:29<00:15, 10.40MB/s]:
#
#
# ████▎                           14% | 70.00/483.13 MB [00:06<00:38, 10.60MB/s]:
# █████████████▊                 47% | 230.00/484.33 MB [00:20<00:24, 10.50MB/s]:
#
# ███████████████████▋           68% | 330.00/485.37 MB [00:29<00:14, 10.46MB/s]:
#
#
# ████▋                           16% | 75.00/483.13 MB [00:06<00:38, 10.60MB/s]:
# ██████████████                 49% | 235.00/484.33 MB [00:21<00:23, 10.51MB/s]:
#
# ████████████████████           69% | 335.00/485.37 MB [00:30<00:14, 10.42MB/s]:
#
#
# ████▉                           17% | 80.00/483.13 MB [00:07<00:38, 10.53MB/s]:
# ██████████████▎                50% | 240.00/484.33 MB [00:21<00:23, 10.52MB/s]:
#
# ████████████████████▎          70% | 340.00/485.37 MB [00:30<00:13, 10.51MB/s]:
#
#
# █████▎                          18% | 85.00/483.13 MB [00:07<00:37, 10.56MB/s]:
# ██████████████▋                51% | 245.00/484.33 MB [00:22<00:22, 10.56MB/s]:
#
# ████████████████████▌          71% | 345.00/485.37 MB [00:31<00:13, 10.46MB/s]:
#
#
# █████▌                          19% | 90.00/483.13 MB [00:08<00:37, 10.58MB/s]:
# ██████████████▉                52% | 250.00/484.33 MB [00:22<00:22, 10.56MB/s]:
#
# ████████████████████▉          72% | 350.00/485.37 MB [00:31<00:13, 10.41MB/s]:
#
#
# █████▉                          20% | 95.00/483.13 MB [00:08<00:37, 10.32MB/s]:
# ███████████████▎               53% | 255.00/484.33 MB [00:23<00:22, 10.42MB/s]:
#
# █████████████████████▏         73% | 355.00/485.37 MB [00:32<00:12, 10.29MB/s]:
#
#
# ██████                         21% | 100.00/483.13 MB [00:09<00:36, 10.36MB/s]:
# ███████████████▌               54% | 260.00/484.33 MB [00:23<00:21, 10.42MB/s]:
#
# █████████████████████▌         74% | 360.00/485.37 MB [00:32<00:12, 10.31MB/s]:
#
#
# ██████▎                        22% | 105.00/483.13 MB [00:09<00:36, 10.44MB/s]:
# ███████████████▊               55% | 265.00/484.33 MB [00:24<00:20, 10.46MB/s]:
#
# █████████████████████▊         75% | 365.00/485.37 MB [00:33<00:11, 10.35MB/s]:
#
#
# ██████▌                        23% | 110.00/483.13 MB [00:10<00:35, 10.49MB/s]:
# ████████████████▏              56% | 270.00/484.33 MB [00:24<00:20, 10.40MB/s]:
#
# ██████████████████████         76% | 370.00/485.37 MB [00:33<00:11, 10.36MB/s]:
#
#
# ██████▉                        24% | 115.00/483.13 MB [00:10<00:35, 10.41MB/s]:
# ████████████████▍              57% | 275.00/484.33 MB [00:25<00:19, 10.52MB/s]:
#
# ██████████████████████▍        77% | 375.00/485.37 MB [00:34<00:10, 10.35MB/s]:
#
#
# ███████▏                       25% | 120.00/483.13 MB [00:11<00:34, 10.40MB/s]:
# ████████████████▊              58% | 280.00/484.33 MB [00:25<00:19, 10.46MB/s]:
#
# ██████████████████████▋        78% | 380.00/485.37 MB [00:34<00:10, 10.34MB/s]:
#
#
# ███████▌                       26% | 125.00/483.13 MB [00:11<00:34, 10.34MB/s]:
# █████████████████              59% | 285.00/484.33 MB [00:26<00:19, 10.49MB/s]:
#
# ███████████████████████        79% | 385.00/485.37 MB [00:35<00:09, 10.31MB/s]:
#
#
# ███████▊                       27% | 130.00/483.13 MB [00:12<00:34, 10.33MB/s]:
# █████████████████▎             60% | 290.00/484.33 MB [00:26<00:18, 10.33MB/s]:
#
# ███████████████████████▎       80% | 390.00/485.37 MB [00:35<00:09, 10.41MB/s]:
#
#
# ████████                       28% | 135.00/483.13 MB [00:12<00:33, 10.34MB/s]:
# █████████████████▋             61% | 295.00/484.33 MB [00:27<00:18, 10.40MB/s]:
#
# ███████████████████████▌       81% | 395.00/485.37 MB [00:36<00:08, 10.40MB/s]:
#
#
# ████████▍                      29% | 140.00/483.13 MB [00:12<00:33, 10.39MB/s]:
# █████████████████▉             62% | 300.00/484.33 MB [00:27<00:17, 10.52MB/s]:
#
# ███████████████████████▉       82% | 400.00/485.37 MB [00:36<00:08, 10.38MB/s]:
#
#
# ████████▋                      30% | 145.00/483.13 MB [00:13<00:32, 10.47MB/s]:
# ██████████████████▎            63% | 305.00/484.33 MB [00:28<00:17, 10.53MB/s]:
#
# ████████████████████████▏      83% | 405.00/485.37 MB [00:36<00:07, 10.48MB/s]:
#
#
# █████████                      31% | 150.00/483.13 MB [00:13<00:31, 10.47MB/s]:
# ██████████████████▌            64% | 310.00/484.33 MB [00:28<00:16, 10.42MB/s]:
#
# ████████████████████████▍      84% | 410.00/485.37 MB [00:37<00:07, 10.46MB/s]:
#
#
# █████████▎                     32% | 155.00/483.13 MB [00:14<00:31, 10.57MB/s]:
# ██████████████████▊            65% | 315.00/484.33 MB [00:29<00:16, 10.33MB/s]:
#
# ████████████████████████▊      86% | 415.00/485.37 MB [00:37<00:06, 10.54MB/s]:
# ███████████████████▏           66% | 320.00/484.33 MB [00:29<00:15, 10.64MB/s]:
#
# ██████████████▋                51% | 245.00/483.17 MB [00:22<00:22, 10.72MB/s]:
#
#
# █████████████████████████      87% | 420.00/485.37 MB [00:38<00:06, 10.74MB/s]:
# ███████████████████▍           67% | 325.00/484.33 MB [00:30<00:14, 10.66MB/s]:
#
# ███████████████                52% | 250.00/483.17 MB [00:23<00:21, 10.69MB/s]:
#
#
# █████████████████████████▍     88% | 425.00/485.37 MB [00:38<00:05, 10.67MB/s]:
# ███████████████████▊           68% | 330.00/484.33 MB [00:30<00:14, 10.55MB/s]:
#
# ███████████████▎               53% | 255.00/483.17 MB [00:23<00:21, 10.66MB/s]:
#
#
# █████████████████████████▋     89% | 430.00/485.37 MB [00:39<00:05, 10.60MB/s]:
# ████████████████████           69% | 335.00/484.33 MB [00:30<00:14, 10.53MB/s]:
#
# ███████████████▌               54% | 260.00/483.17 MB [00:23<00:20, 10.66MB/s]:
#
#
# █████████████████████████▉     90% | 435.00/485.37 MB [00:39<00:04, 10.54MB/s]:
# ████████████████████▎          70% | 340.00/484.33 MB [00:31<00:13, 10.47MB/s]:
#
# ███████████████▉               55% | 265.00/483.17 MB [00:24<00:20, 10.59MB/s]:
#
#
# ██████████████████████████▎    91% | 440.00/485.37 MB [00:40<00:04, 10.50MB/s]:
# ████████████████████▋          71% | 345.00/484.33 MB [00:31<00:13, 10.42MB/s]:
#
# ████████████████▏              56% | 270.00/483.17 MB [00:24<00:20, 10.53MB/s]:
#
#
# ██████████████████████████▌    92% | 445.00/485.37 MB [00:40<00:03, 10.59MB/s]:
# ████████████████████▉          72% | 350.00/484.33 MB [00:32<00:12, 10.35MB/s]:
#
# ████████████████▌              57% | 275.00/483.17 MB [00:25<00:19, 10.51MB/s]:
#
#
# ██████████████████████████▉    93% | 450.00/485.37 MB [00:41<00:03, 10.49MB/s]:
# █████████████████████▎         73% | 355.00/484.33 MB [00:32<00:12, 10.42MB/s]:
#
# ████████████████▊              58% | 280.00/483.17 MB [00:25<00:19, 10.47MB/s]:
#
#
# ███████████████████████████▏   94% | 455.00/485.37 MB [00:41<00:02, 10.38MB/s]:
# █████████████████████▌         74% | 360.00/484.33 MB [00:33<00:11, 10.43MB/s]:
#
#
# ████████████                   41% | 200.00/483.13 MB [00:18<00:26, 10.63MB/s]:
#
# ███████████████████████████▍   95% | 460.00/485.37 MB [00:42<00:02, 10.39MB/s]:
# █████████████████████▊         75% | 365.00/484.33 MB [00:33<00:11, 10.43MB/s]:
#
#
# ████████████▎                  42% | 205.00/483.13 MB [00:19<00:26, 10.61MB/s]:
#
# ███████████████████████████▊   96% | 465.00/485.37 MB [00:42<00:01, 10.35MB/s]:
# ██████████████████████▏        76% | 370.00/484.33 MB [00:34<00:10, 10.44MB/s]:
#
#
# ████████████▌                  43% | 210.00/483.13 MB [00:19<00:25, 10.61MB/s]:
#
# ████████████████████████████   97% | 470.00/485.37 MB [00:43<00:01, 10.31MB/s]:
# ██████████████████████▍        77% | 375.00/484.33 MB [00:34<00:10, 10.38MB/s]:
#
#
# ████████████▉                  45% | 215.00/483.13 MB [00:20<00:25, 10.63MB/s]:
#
# ████████████████████████████▍  98% | 475.00/485.37 MB [00:43<00:01, 10.27MB/s]:
# ██████████████████████▊        78% | 380.00/484.33 MB [00:35<00:09, 10.46MB/s]:
#
#
# █████████████▏                 46% | 220.00/483.13 MB [00:20<00:24, 10.59MB/s]:
#
# ████████████████████████████▋  99% | 480.00/485.37 MB [00:44<00:00, 10.24MB/s]:
# ███████████████████████        79% | 385.00/484.33 MB [00:35<00:09, 10.39MB/s]:
#
#
# █████████████▌                 47% | 225.00/483.13 MB [00:21<00:24, 10.58MB/s]:
#
# ████████████████████████████▉ 100% | 485.00/485.37 MB [00:44<00:00, 10.23MB/s]:
# ███████████████████████▎       81% | 390.00/484.33 MB [00:36<00:08, 10.54MB/s]:
#
#
# █████████████▊                 48% | 230.00/483.13 MB [00:21<00:23, 10.75MB/s]:
#
# ██████████████████▉            65% | 315.00/483.17 MB [00:29<00:15, 10.78MB/s]:
# ███████████████████████▋       82% | 395.00/484.33 MB [00:36<00:08, 10.83MB/s]:
#
#
# ██████████████                 49% | 235.00/483.13 MB [00:22<00:22, 11.04MB/s]:
#
# ███████████████████▏           66% | 320.00/483.17 MB [00:29<00:14, 11.08MB/s]:
# ███████████████████████▉       83% | 400.00/484.33 MB [00:37<00:07, 11.07MB/s]:
#
#
# ██████████████▍                50% | 240.00/483.13 MB [00:22<00:21, 11.20MB/s]:
#
# ███████████████████▌           67% | 325.00/483.17 MB [00:30<00:14, 11.25MB/s]:
# ████████████████████████▏      84% | 405.00/484.33 MB [00:37<00:07, 11.21MB/s]:
#
# ███████████████████▊           68% | 330.00/483.17 MB [00:30<00:13, 11.37MB/s]:
#
#
# ██████████████▋                51% | 245.00/483.13 MB [00:22<00:21, 11.26MB/s]:
# ████████████████████████▌      85% | 410.00/484.33 MB [00:37<00:06, 11.30MB/s]:
#
# ████████████████████           69% | 335.00/483.17 MB [00:30<00:12, 11.48MB/s]:
#
#
# ███████████████                52% | 250.00/483.13 MB [00:23<00:20, 11.33MB/s]:
# ████████████████████████▊      86% | 415.00/484.33 MB [00:38<00:06, 11.35MB/s]:
#
# ████████████████████▍          70% | 340.00/483.17 MB [00:31<00:12, 11.53MB/s]:
#
#
# ███████████████▎               53% | 255.00/483.13 MB [00:23<00:20, 11.34MB/s]:
#
# ████████████████████▋          71% | 345.00/483.17 MB [00:31<00:11, 11.69MB/s]:
# █████████████████████████▏     87% | 420.00/484.33 MB [00:38<00:05, 11.37MB/s]:
#
#
# ███████████████▌               54% | 260.00/483.13 MB [00:24<00:19, 11.41MB/s]:
#
# █████████████████████          72% | 350.00/483.17 MB [00:32<00:11, 11.73MB/s]:
# █████████████████████████▍     88% | 425.00/484.33 MB [00:39<00:05, 11.43MB/s]:
#
#
# ███████████████▉               55% | 265.00/483.13 MB [00:24<00:18, 11.53MB/s]:
#
# █████████████████████▎         73% | 355.00/483.17 MB [00:32<00:10, 11.71MB/s]:
# █████████████████████████▋     89% | 430.00/484.33 MB [00:39<00:04, 11.49MB/s]:
#
#
# █████████████████████████████ 100% | 485.37/485.37 MB [00:48<00:00, 10.03MB/s]:
#
#
# █████████████████████▌         75% | 360.00/483.17 MB [00:33<00:10, 11.69MB/s]:
# ██████████████████████████     90% | 435.00/484.33 MB [00:40<00:04, 11.52MB/s]:
#
#
# ████████████████▌              57% | 275.00/483.13 MB [00:25<00:18, 11.51MB/s]:
#
# █████████████████████▉         76% | 365.00/483.17 MB [00:33<00:10, 11.71MB/s]:
# ██████████████████████████▎    91% | 440.00/484.33 MB [00:40<00:03, 11.50MB/s]:
#
#
# ████████████████▊              58% | 280.00/483.13 MB [00:26<00:17, 11.47MB/s]:
#
# ██████████████████████▏        77% | 370.00/483.17 MB [00:33<00:09, 11.69MB/s]:
# ██████████████████████████▋    92% | 445.00/484.33 MB [00:41<00:03, 11.46MB/s]:
#
#
# █████████████████              59% | 285.00/483.13 MB [00:26<00:17, 11.46MB/s]:
#
# ██████████████████████▌        78% | 375.00/483.17 MB [00:34<00:09, 11.80MB/s]:
# ██████████████████████████▉    93% | 450.00/484.33 MB [00:41<00:02, 11.48MB/s]:
#
#
# █████████████████▍             60% | 290.00/483.13 MB [00:26<00:16, 11.51MB/s]:
#
# ██████████████████████▊        79% | 380.00/483.17 MB [00:34<00:08, 11.79MB/s]:
# ███████████████████████████▏   94% | 455.00/484.33 MB [00:41<00:02, 11.52MB/s]:
#
#
# █████████████████▋             61% | 295.00/483.13 MB [00:27<00:16, 11.59MB/s]:
#
# ███████████████████████        80% | 385.00/483.17 MB [00:35<00:08, 11.76MB/s]:
# ███████████████████████████▌   95% | 460.00/484.33 MB [00:42<00:02, 11.54MB/s]:
#
#
# ██████████████████             62% | 300.00/483.13 MB [00:27<00:15, 11.60MB/s]:
#
# ███████████████████████▍       81% | 390.00/483.17 MB [00:35<00:07, 11.72MB/s]:
# ███████████████████████████▊   96% | 465.00/484.33 MB [00:42<00:01, 11.56MB/s]:
#
#
# ██████████████████▎            63% | 305.00/483.13 MB [00:28<00:15, 11.54MB/s]:
#
# ███████████████████████▋       82% | 395.00/483.17 MB [00:36<00:07, 11.73MB/s]:
# ████████████████████████████▏  97% | 470.00/484.33 MB [00:43<00:01, 11.55MB/s]:
#
#
# ██████████████████▌            64% | 310.00/483.13 MB [00:28<00:15, 11.48MB/s]:
#
# ████████████████████████       83% | 400.00/483.17 MB [00:36<00:07, 11.72MB/s]:
# ████████████████████████████▍  98% | 475.00/484.33 MB [00:43<00:00, 11.47MB/s]:
#
#
# ██████████████████▉            65% | 315.00/483.13 MB [00:29<00:14, 11.48MB/s]:
#
# ████████████████████████▎      84% | 405.00/483.17 MB [00:36<00:06, 11.84MB/s]:
# ████████████████████████████▋  99% | 480.00/484.33 MB [00:44<00:00, 11.50MB/s]:
#
#
# ███████████████████▏           66% | 320.00/483.13 MB [00:29<00:14, 11.52MB/s]:
#
# ████████████████████████▌      85% | 410.00/483.17 MB [00:37<00:06, 11.81MB/s]:
# █████████████████████████████ 100% | 484.33/484.33 MB [00:44<00:00, 11.53MB/s]:
#
#
# ███████████████████▌           67% | 325.00/483.13 MB [00:29<00:13, 11.59MB/s]:
#
# ████████████████████████▉      86% | 415.00/483.17 MB [00:37<00:05, 11.67MB/s]:
#
#
# ███████████████████▊           68% | 330.00/483.13 MB [00:30<00:13, 11.61MB/s]:
#
# █████████████████████████▏     87% | 420.00/483.17 MB [00:38<00:05, 11.76MB/s]:
#
#
# ████████████████████           69% | 335.00/483.13 MB [00:30<00:12, 11.54MB/s]:
#
# █████████████████████████▌     88% | 425.00/483.17 MB [00:38<00:04, 11.75MB/s]:
#
#
# ████████████████████▍          70% | 340.00/483.13 MB [00:31<00:12, 11.49MB/s]:
#
# █████████████████████████▊     89% | 430.00/483.17 MB [00:38<00:04, 11.74MB/s]:
#
#
# ████████████████████▋          71% | 345.00/483.13 MB [00:31<00:12, 11.49MB/s]:
#
# ██████████████████████████     90% | 435.00/483.17 MB [00:39<00:04, 11.86MB/s]:
#
#
# █████████████████████          72% | 350.00/483.13 MB [00:32<00:11, 11.52MB/s]:
#
# ██████████████████████████▍    91% | 440.00/483.17 MB [00:39<00:03, 11.82MB/s]:
#
#
# █████████████████████▎         73% | 355.00/483.13 MB [00:32<00:11, 11.61MB/s]:
#
# ██████████████████████████▋    92% | 445.00/483.17 MB [00:40<00:03, 11.70MB/s]:
#
#
# █████████████████████▌         75% | 360.00/483.13 MB [00:32<00:10, 11.62MB/s]:
#
# ███████████████████████████    93% | 450.00/483.17 MB [00:40<00:02, 11.77MB/s]:
#
#
# █████████████████████▉         76% | 365.00/483.13 MB [00:33<00:10, 11.54MB/s]:
#
# █████████████████████████████ 100% | 484.33/484.33 MB [00:48<00:00, 10.04MB/s]:
#
#
#
# ██████████████████████▏        77% | 370.00/483.13 MB [00:33<00:09, 11.49MB/s]:
#
# ███████████████████████████▌   95% | 460.00/483.17 MB [00:41<00:01, 11.75MB/s]:
#
#
# ██████████████████████▌        78% | 375.00/483.13 MB [00:34<00:09, 11.50MB/s]:
#
# ███████████████████████████▉   96% | 465.00/483.17 MB [00:41<00:01, 11.86MB/s]:
#
#
# ██████████████████████▊        79% | 380.00/483.13 MB [00:34<00:08, 11.54MB/s]:
#
# ████████████████████████████▏  97% | 470.00/483.17 MB [00:42<00:01, 11.83MB/s]:
#
#
# ███████████████████████        80% | 385.00/483.13 MB [00:35<00:08, 11.60MB/s]:
#
# ████████████████████████████▌  98% | 475.00/483.17 MB [00:42<00:00, 11.68MB/s]:
#
#
# ███████████████████████▍       81% | 390.00/483.13 MB [00:35<00:08, 11.60MB/s]:
#
# ████████████████████████████▊  99% | 480.00/483.17 MB [00:43<00:00, 11.77MB/s]:
#
#
# ███████████████████████▋       82% | 395.00/483.13 MB [00:35<00:07, 11.55MB/s]:
#
# ████████████████████████████▉ 100% | 483.16/483.17 MB [00:43<00:00, 11.77MB/s]:
#
#
# ████████████████████████       83% | 400.00/483.13 MB [00:36<00:07, 11.49MB/s]:
#
#
# ████████████████████████▎      84% | 405.00/483.13 MB [00:36<00:06, 11.47MB/s]:
#
#
# ████████████████████████▌      85% | 410.00/483.13 MB [00:37<00:06, 11.55MB/s]:
#
#
# ████████████████████████▉      86% | 415.00/483.13 MB [00:37<00:05, 11.61MB/s]:
#
#
# █████████████████████████▏     87% | 420.00/483.13 MB [00:38<00:05, 11.60MB/s]:
#
#
# █████████████████████████▌     88% | 425.00/483.13 MB [00:38<00:05, 11.55MB/s]:
#
#
# █████████████████████████▊     89% | 430.00/483.13 MB [00:39<00:04, 11.49MB/s]:
#
#
# █████████████████████████████ 100% | 483.17/483.17 MB [00:47<00:00, 10.26MB/s]:
#
#
#
# ██████████████████████████▍    91% | 440.00/483.13 MB [00:39<00:03, 11.55MB/s]:
#
#
# ██████████████████████████▋    92% | 445.00/483.13 MB [00:40<00:03, 11.61MB/s]:
#
#
# ███████████████████████████    93% | 450.00/483.13 MB [00:40<00:02, 11.59MB/s]:
#
#
# ███████████████████████████▎   94% | 455.00/483.13 MB [00:41<00:02, 11.56MB/s]:
#
#
# ███████████████████████████▌   95% | 460.00/483.13 MB [00:41<00:02, 11.49MB/s]:
#
#
# ███████████████████████████▉   96% | 465.00/483.13 MB [00:42<00:01, 11.48MB/s]:
#
#
# ████████████████████████████▏  97% | 470.00/483.13 MB [00:42<00:01, 11.54MB/s]:
#
#
# ████████████████████████████▌  98% | 475.00/483.13 MB [00:42<00:00, 11.62MB/s]:
#
#
# ████████████████████████████▊  99% | 480.00/483.13 MB [00:43<00:00, 11.59MB/s]:
#
#
# █████████████████████████████ 100% | 483.13/483.13 MB [00:47<00:00, 10.22MB/s]:
# File compression and upload completed: total size 3.89 GiB, 8 chunk(s) stored (average size 498.15 MiB)
# ███████████████████████████████ 100% | 10.89/10.89 MB [00:00<00:00, 11.15MB/s]:
# ███████████████████████████████ 100% | 10.89/10.89 MB [00:00<00:00, 11.31MB/s]:
# Dataset 'bdd100k_seg' uploaded and finalized successfully!
