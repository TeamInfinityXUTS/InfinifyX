# %%
# !pip install kagglehub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [kagglehub]/2 [kagglehub]
# ...

# %%
import os

os.environ['KAGGLE_API_TOKEN'] = 'KGAT_8199ef5ba7fcea7126425785fc74194f'

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("marquis03/bdd100k")

print("Path to dataset files:", path)
# Out:
# ...
#   0%|          | 13.0M/5.38G [00:02<19:08, 5.02MB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 import kagglehub
#       3 # Download latest version
# ----> 4 path = kagglehub.dataset_download("marquis03/bdd100k")
#       6 print("Path to dataset files:", path)
#
# File d:\Anaconda\envs\ai\Lib\site-packages\kagglehub\datasets.py:52, in dataset_download(handle, path, force_download, output_dir)
#      50 h = parse_dataset_handle(handle)
#      51 logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 52 resolved_path, _ = registry.dataset_resolver(
#      53     h,
#      54     path,
#      55     force_download=force_download,
#      56     output_dir=output_dir,
#      57 )
#      58 return resolved_path
#
# ...

# %%
# !mv /home/sagemaker-user/.cache/kagglehub/datasets/marquis03/bdd100k/versions/1/* /home/sagemaker-user/ProjectX/bdd100k/

# %%
import os

base_path = "/home/sagemaker-user/ProjectX/bdd100k/"

print(f"Checking: {base_path}\n" + "-"*30)

for folder in sorted(os.listdir(base_path)):
    folder_path = os.path.join(base_path, folder)
    
    if os.path.isdir(folder_path):
        # Count files in the main folder
        count = len([f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))])
        print(f"{folder}/ ({count} files)")
        
        # Check subdirectories (e.g., train/val/test)
        for subfolder in sorted(os.listdir(folder_path)):
            sub_path = os.path.join(folder_path, subfolder)
            if os.path.isdir(sub_path):
                sub_count = len(os.listdir(sub_path))
                print(f"  └── {subfolder}: {sub_count}")

# %%
'''
@InProceedings{bdd100k,
    author = {Yu, Fisher and Chen, Haofeng and Wang, Xin and Xian, Wenqi and Chen,
              Yingying and Liu, Fangchen and Madhavan, Vashisht and Darrell, Trevor},
    title = {BDD100K: A Diverse Driving Dataset for Heterogeneous Multitask Learning},
    booktitle = {IEEE/CVF Conference on Computer Vision and Pattern Recognition (CVPR)},
    month = {June},
    year = {2020}
}
'''

# %% [markdown]
# ### Segment Download

# %%
import kagglehub
import os
import shutil


target_base_dir = "."


os.makedirs(target_base_dir, exist_ok=True)

# 2. 下载数据集（这会先下载到默认缓存路径）
print("Downloading...")
cache_path = kagglehub.dataset_download("solesensei/solesensei_bdd100k")

# 3. 确定数据集文件夹名称并将移动到目标位置
dataset_name = os.path.basename(cache_path)
final_destination = os.path.join(target_base_dir, dataset_name)

if os.path.exists(final_destination):
    print(f"目标路径 {final_destination} 已存在，正在清理以准备更新...")
    shutil.rmtree(final_destination)

# 移动文件夹
shutil.move(cache_path, target_base_dir)

print("-" * 30)
print(f"下载并移动完成！")
print(f"数据集当前位置: {os.path.abspath(final_destination)}")

# %% [markdown]
# ### Video Clip Download

# %%
import kagglehub
import os
import shutil


target_base_dir = "."


os.makedirs(target_base_dir, exist_ok=True)

# 2. 下载数据集（这会先下载到默认缓存路径）
print("Downloading...")
cache_path = kagglehub.dataset_download("aadimator/nuscenes-mini")

# 3. 确定数据集文件夹名称并将移动到目标位置
dataset_name = os.path.basename(cache_path)
final_destination = os.path.join(target_base_dir, dataset_name)

if os.path.exists(final_destination):
    print(f"目标路径 {final_destination} 已存在，正在清理以准备更新...")
    shutil.rmtree(final_destination)

# 移动文件夹
shutil.move(cache_path, target_base_dir)

print("-" * 30)
print(f"下载并移动完成！")
print(f"数据集当前位置: {os.path.abspath(final_destination)}")

# %%
import kagglehub
import os
import shutil


target_base_dir = "./datasets/"


os.makedirs(target_base_dir, exist_ok=True)

# 2. 下载数据集（这会先下载到默认缓存路径）
print("Downloading...")
cache_path = kagglehub.dataset_download("marquis03/bdd100k")

# 3. 确定数据集文件夹名称并将移动到目标位置
dataset_name = os.path.basename(cache_path)
final_destination = os.path.join(target_base_dir, dataset_name)

if os.path.exists(final_destination):
    print(f"目标路径 {final_destination} 已存在，正在清理以准备更新...")
    shutil.rmtree(final_destination)

# 移动文件夹
shutil.move(cache_path, target_base_dir)

print("-" * 30)
print(f"下载并移动完成！")
print(f"数据集当前位置: {os.path.abspath(final_destination)}")
# Out:
# Downloading...
# ...
# 100%|██████████| 5.38G/5.38G [04:18<00:00, 22.3MB/s]
# Extracting files...
# ------------------------------
# 下载并移动完成！
# 数据集当前位置: /home/sagemaker-user/InfinifyX/data_preprocessing/datasets/1
