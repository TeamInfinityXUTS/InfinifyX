# %%
import os

# %env CLEARML_WEB_HOST=https://app.clear.ml/
# %env CLEARML_API_HOST=https://api.clear.ml
# %env CLEARML_FILES_HOST=https://files.clear.ml
# %env CLEARML_API_ACCESS_KEY=R58U0GS1V7DPMV9POEA3L3E6WHH8EV
# %env CLEARML_API_SECRET_KEY=XQWoX03bgFcB4eJa6Ux8Kt7zmkaVmVdjg-3xBMa1kFdAdpywfbwfAKb8UzS-Rc2WWXU
# Out:
# env: CLEARML_WEB_HOST=https://app.clear.ml/
# env: CLEARML_API_HOST=https://api.clear.ml
# env: CLEARML_FILES_HOST=https://files.clear.ml
# env: CLEARML_API_ACCESS_KEY=R58U0GS1V7DPMV9POEA3L3E6WHH8EV
# env: CLEARML_API_SECRET_KEY=XQWoX03bgFcB4eJa6Ux8Kt7zmkaVmVdjg-3xBMa1kFdAdpywfbwfAKb8UzS-Rc2WWXU

# %%
# %pip install clearml
# Out:
# Requirement already satisfied: clearml in /opt/conda/lib/python3.12/site-packages (2.1.5)
# Requirement already satisfied: attrs>=18.0 in /opt/conda/lib/python3.12/site-packages (from clearml) (23.2.0)
# Requirement already satisfied: furl>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from clearml) (2.1.4)
# Requirement already satisfied: jsonschema>=2.6.0 in /opt/conda/lib/python3.12/site-packages (from clearml) (4.23.0)
# Requirement already satisfied: pathlib2>=2.3.0 in /opt/conda/lib/python3.12/site-packages (from clearml) (2.3.7.post1)
# Requirement already satisfied: psutil>=3.4.2 in /opt/conda/lib/python3.12/site-packages (from clearml) (5.9.8)
# Requirement already satisfied: pyparsing>=2.0.3 in /opt/conda/lib/python3.12/site-packages (from clearml) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/conda/lib/python3.12/site-packages (from clearml) (2.9.0.post0)
# Requirement already satisfied: pyjwt<3.0.0,>=2.4.0 in /opt/conda/lib/python3.12/site-packages (from clearml) (2.11.0)
# Requirement already satisfied: PyYAML>=3.12 in /opt/conda/lib/python3.12/site-packages (from clearml) (6.0.3)
# Requirement already satisfied: six>=1.16.0 in /opt/conda/lib/python3.12/site-packages (from clearml) (1.17.0)
# Requirement already satisfied: urllib3>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from clearml) (1.26.20)
# Requirement already satisfied: Pillow>=10.3.0 in /opt/conda/lib/python3.12/site-packages (from clearml) (11.3.0)
# Requirement already satisfied: referencing<0.40 in /opt/conda/lib/python3.12/site-packages (from clearml) (0.37.0)
# Requirement already satisfied: requests>=2.32.0 in /opt/conda/lib/python3.12/site-packages (from clearml) (2.32.5)
# Requirement already satisfied: numpy>=1.26.4 in /opt/conda/lib/python3.12/site-packages (from clearml) (2.4.4)
# Requirement already satisfied: rpds-py>=0.7.0 in /opt/conda/lib/python3.12/site-packages (from referencing<0.40->clearml) (0.27.1)
# Requirement already satisfied: typing-extensions>=4.4.0 in /opt/conda/lib/python3.12/site-packages (from referencing<0.40->clearml) (4.15.0)
# Requirement already satisfied: orderedmultidict>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from furl>=2.0.0->clearml) (1.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=2.6.0->clearml) (2025.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests>=2.32.0->clearml) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests>=2.32.0->clearml) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests>=2.32.0->clearml) (2026.2.25)
# Note: you may need to restart the kernel to use updated packages.

# %%
from clearml import Dataset


dataset = Dataset.create(
    dataset_project='InfinifyX', 
    dataset_name='bdd100k_augmented'
)


dataset.add_files(path='bdd100k_augmented')

dataset.upload()

dataset.finalize()

print("Dataset Upload")
# Out:
# ClearML results page: https://app.clear.ml/projects/eec698c6c58f4166a200e12d4a4d0ca7/experiments/959421541a9342b1b2ac18e614167def/output/log
# ClearML dataset page: https://app.clear.ml/datasets/simple/eec698c6c58f4166a200e12d4a4d0ca7/experiments/959421541a9342b1b2ac18e614167def
# Generating SHA2 hash for 24002 files
# 100%|██████████| 24002/24002 [00:08<00:00, 2784.34it/s]
# Hash generation completed
# ███████████████████████████████ 100% | 10.42/10.42 MB [00:00<00:00, 11.32MB/s]:
#
#
#
# ████████▏                      28% | 145.00/512.13 MB [00:14<00:37,  9.67MB/s]:
#
# ████████████▋                  44% | 225.00/512.17 MB [00:21<00:29,  9.72MB/s]:
# ████████████████████▉          72% | 370.00/512.14 MB [00:34<00:14,  9.78MB/s]:
#
#
# ████████▍                      29% | 150.00/512.13 MB [00:14<00:37,  9.60MB/s]:
#
# █████████████                  45% | 230.00/512.17 MB [00:22<00:28,  9.74MB/s]:
# █████████████████████▏         73% | 375.00/512.14 MB [00:35<00:14,  9.76MB/s]:
#
#
# ████████▊                      30% | 155.00/512.13 MB [00:15<00:37,  9.62MB/s]:
#
# █████████████▎                 46% | 235.00/512.17 MB [00:22<00:28,  9.80MB/s]:
# █████████████████████▌         74% | 380.00/512.14 MB [00:35<00:13,  9.62MB/s]:
#
#
# █████████                      31% | 160.00/512.13 MB [00:15<00:36,  9.68MB/s]:
#
# █████████████▌                 47% | 240.00/512.17 MB [00:23<00:27,  9.75MB/s]:
# █████████████████████▊         75% | 385.00/512.14 MB [00:36<00:13,  9.67MB/s]:
#
#
# █████████▎                     32% | 165.00/512.13 MB [00:16<00:35,  9.69MB/s]:
#
# █████████████▊                 48% | 245.00/512.17 MB [00:24<00:27,  9.75MB/s]:
# ██████████████████████         76% | 390.00/512.14 MB [00:36<00:12,  9.68MB/s]:
#
#
# █████████▋                     33% | 170.00/512.13 MB [00:16<00:35,  9.74MB/s]:
#
# ██████████████▏                49% | 250.00/512.17 MB [00:24<00:26,  9.99MB/s]:
# ██████████████████████▎        77% | 395.00/512.14 MB [00:37<00:12,  9.56MB/s]:
#
#
# █████████▉                     34% | 175.00/512.13 MB [00:17<00:34,  9.71MB/s]:
#
# ██████████████▍                50% | 255.00/512.17 MB [00:24<00:25, 10.19MB/s]:
# ██████████████████████▋        78% | 400.00/512.14 MB [00:37<00:11,  9.60MB/s]:
#
#
# ██████████▏                    35% | 180.00/512.13 MB [00:17<00:34,  9.76MB/s]:
#
# ██████████████▋                51% | 260.00/512.17 MB [00:25<00:24, 10.15MB/s]:
# ██████████████████████▉        79% | 405.00/512.14 MB [00:38<00:11,  9.57MB/s]:
#
#
# ██████████▍                    36% | 185.00/512.13 MB [00:18<00:33,  9.77MB/s]:
#
# ███████████████                52% | 265.00/512.17 MB [00:25<00:24, 10.03MB/s]:
# ███████████████████████▏       80% | 410.00/512.14 MB [00:38<00:10,  9.62MB/s]:
#
#
# ██████████▊                    37% | 190.00/512.13 MB [00:18<00:32,  9.77MB/s]:
#
# ███████████████▎               53% | 270.00/512.17 MB [00:26<00:24,  9.96MB/s]:
# ███████████████████████▍       81% | 415.00/512.14 MB [00:39<00:10,  9.62MB/s]:
#
#
# ███████████                    38% | 195.00/512.13 MB [00:19<00:32,  9.87MB/s]:
#
# ███████████████▌               54% | 275.00/512.17 MB [00:27<00:24,  9.87MB/s]:
# ███████████████████████▊       82% | 420.00/512.14 MB [00:40<00:09,  9.58MB/s]:
#
#
# ███████████▎                   39% | 200.00/512.13 MB [00:19<00:31,  9.92MB/s]:
#
# ███████████████▊               55% | 280.00/512.17 MB [00:27<00:23,  9.85MB/s]:
# ████████████████████████       83% | 425.00/512.14 MB [00:40<00:09,  9.60MB/s]:
#
#
# ███████████▌                   40% | 205.00/512.13 MB [00:20<00:30,  9.92MB/s]:
#
# ████████████████▏              56% | 285.00/512.17 MB [00:28<00:23,  9.82MB/s]:
# ████████████████████████▎      84% | 430.00/512.14 MB [00:41<00:08,  9.68MB/s]:
#
#
# ███████████▉                   41% | 210.00/512.13 MB [00:20<00:30,  9.96MB/s]:
#
# ████████████████▍              57% | 290.00/512.17 MB [00:28<00:22,  9.79MB/s]:
# ████████████████████████▋      85% | 435.00/512.14 MB [00:41<00:07,  9.69MB/s]:
#
#
# ████████████▏                  42% | 215.00/512.13 MB [00:21<00:30,  9.82MB/s]:
#
# ████████████████▋              58% | 295.00/512.17 MB [00:29<00:22,  9.87MB/s]:
# ████████████████████████▉      86% | 440.00/512.14 MB [00:42<00:07,  9.69MB/s]:
#
#
# ████████████▍                  43% | 220.00/512.13 MB [00:22<00:29,  9.80MB/s]:
#
# ████████████████▉              59% | 300.00/512.17 MB [00:29<00:21,  9.84MB/s]:
# █████████████████████████▏     87% | 445.00/512.14 MB [00:42<00:06,  9.67MB/s]:
#
#
# ████████████▋                  44% | 225.00/512.13 MB [00:22<00:29,  9.73MB/s]:
#
# █████████████████▎             60% | 305.00/512.17 MB [00:30<00:21,  9.81MB/s]:
# █████████████████████████▍     88% | 450.00/512.14 MB [00:43<00:06,  9.77MB/s]:
#
#
# █████████████                  45% | 230.00/512.13 MB [00:23<00:28,  9.74MB/s]:
#
# █████████████████▌             61% | 310.00/512.17 MB [00:30<00:20,  9.85MB/s]:
# █████████████████████████▊     89% | 455.00/512.14 MB [00:43<00:05,  9.80MB/s]:
#
#
# █████████████▎                 46% | 235.00/512.13 MB [00:23<00:28,  9.75MB/s]:
#
# █████████████████▊             62% | 315.00/512.17 MB [00:31<00:20,  9.84MB/s]:
# ██████████████████████████     90% | 460.00/512.14 MB [00:44<00:05,  9.88MB/s]:
#
#
# █████████████▌                 47% | 240.00/512.13 MB [00:24<00:27,  9.74MB/s]:
#
# ██████████████████             62% | 320.00/512.17 MB [00:31<00:19,  9.84MB/s]:
# ██████████████████████████▎    91% | 465.00/512.14 MB [00:44<00:04,  9.83MB/s]:
#
#
# █████████████▊                 48% | 245.00/512.13 MB [00:24<00:27,  9.78MB/s]:
#
# ██████████████████▍            63% | 325.00/512.17 MB [00:32<00:19,  9.78MB/s]:
# ██████████████████████████▌    92% | 470.00/512.14 MB [00:45<00:04,  9.82MB/s]:
#
#
# ██████████████▏                49% | 250.00/512.13 MB [00:25<00:26,  9.80MB/s]:
#
# ██████████████████▋            64% | 330.00/512.17 MB [00:32<00:18,  9.78MB/s]:
# ██████████████████████████▉    93% | 475.00/512.14 MB [00:45<00:03,  9.85MB/s]:
#
#
# ██████████████▍                50% | 255.00/512.13 MB [00:25<00:26,  9.81MB/s]:
#
# ██████████████████▉            65% | 335.00/512.17 MB [00:33<00:18,  9.77MB/s]:
# ███████████████████████████▏   94% | 480.00/512.14 MB [00:46<00:03,  9.88MB/s]:
#
#
# ██████████████▋                51% | 260.00/512.13 MB [00:26<00:25,  9.77MB/s]:
#
# ███████████████████▎           66% | 340.00/512.17 MB [00:33<00:17,  9.83MB/s]:
# ███████████████████████████▍   95% | 485.00/512.14 MB [00:46<00:02,  9.85MB/s]:
#
#
# ███████████████                52% | 265.00/512.13 MB [00:26<00:24,  9.92MB/s]:
#
# ███████████████████▌           67% | 345.00/512.17 MB [00:34<00:17,  9.68MB/s]:
# ███████████████████████████▋   96% | 490.00/512.14 MB [00:47<00:02,  9.88MB/s]:
#
#
# ███████████████▎               53% | 270.00/512.13 MB [00:27<00:24,  9.87MB/s]:
#
# ███████████████████▊           68% | 350.00/512.17 MB [00:34<00:16,  9.74MB/s]:
# ████████████████████████████   97% | 495.00/512.14 MB [00:47<00:01,  9.84MB/s]:
#
#
# ███████████████▌               54% | 275.00/512.13 MB [00:27<00:24,  9.83MB/s]:
#
# ████████████████████           69% | 355.00/512.17 MB [00:35<00:16,  9.70MB/s]:
# ████████████████████████████▎  98% | 500.00/512.14 MB [00:48<00:01,  9.77MB/s]:
#
#
# ███████████████▊               55% | 280.00/512.13 MB [00:28<00:23,  9.79MB/s]:
#
# ████████████████████▍          70% | 360.00/512.17 MB [00:35<00:15,  9.68MB/s]:
# ████████████████████████████▌  99% | 505.00/512.14 MB [00:48<00:00,  9.67MB/s]:
#
#
# ████████████████▏              56% | 285.00/512.13 MB [00:28<00:23,  9.75MB/s]:
#
# ████████████████████▋          71% | 365.00/512.17 MB [00:36<00:15,  9.76MB/s]:
# ████████████████████████████▉ 100% | 510.00/512.14 MB [00:49<00:00,  9.67MB/s]:
#
#
# ████████████████▍              57% | 290.00/512.13 MB [00:29<00:22,  9.78MB/s]:
#
# ████████████████████████████▉ 100% | 512.13/512.14 MB [00:49<00:00,  9.64MB/s]:
# ████████████████████████▉      86% | 440.00/512.54 MB [00:43<00:07,  9.95MB/s]:
#
#
# ████████████████▋              58% | 295.00/512.13 MB [00:29<00:21, 10.23MB/s]:
#
# █████████████████████▏         73% | 375.00/512.17 MB [00:37<00:13, 10.22MB/s]:
# █████████████████████████▏     87% | 445.00/512.54 MB [00:43<00:06, 10.35MB/s]:
#
#
# ████████████████▉              59% | 300.00/512.13 MB [00:30<00:20, 10.59MB/s]:
#
# █████████████████████▌         74% | 380.00/512.17 MB [00:37<00:12, 10.63MB/s]:
# █████████████████████████▍     88% | 450.00/512.54 MB [00:44<00:05, 10.62MB/s]:
#
#
# █████████████████▎             60% | 305.00/512.13 MB [00:30<00:19, 10.83MB/s]:
#
# █████████████████████▊         75% | 385.00/512.17 MB [00:38<00:11, 11.00MB/s]:
# █████████████████████████▋     89% | 455.00/512.54 MB [00:44<00:05, 10.83MB/s]:
#
#
# █████████████████▌             61% | 310.00/512.13 MB [00:30<00:18, 11.03MB/s]:
#
# ██████████████████████         76% | 390.00/512.17 MB [00:38<00:10, 11.22MB/s]:
# ██████████████████████████     90% | 460.00/512.54 MB [00:45<00:04, 11.03MB/s]:
#
#
# █████████████████▊             62% | 315.00/512.13 MB [00:31<00:17, 11.26MB/s]:
#
# ██████████████████████▎        77% | 395.00/512.17 MB [00:38<00:10, 11.38MB/s]:
# ██████████████████████████▎    91% | 465.00/512.54 MB [00:45<00:04, 11.19MB/s]:
#
#
# ██████████████████             62% | 320.00/512.13 MB [00:31<00:16, 11.43MB/s]:
#
# ██████████████████████▋        78% | 400.00/512.17 MB [00:39<00:09, 11.40MB/s]:
# ██████████████████████████▌    92% | 470.00/512.54 MB [00:45<00:03, 11.41MB/s]:
#
#
# ██████████████████▍            63% | 325.00/512.13 MB [00:32<00:16, 11.53MB/s]:
#
# ██████████████████████▉        79% | 405.00/512.17 MB [00:39<00:09, 11.43MB/s]:
# ██████████████████████████▉    93% | 475.00/512.54 MB [00:46<00:03, 11.40MB/s]:
#
#
# ██████████████████▋            64% | 330.00/512.13 MB [00:32<00:15, 11.51MB/s]:
#
# ███████████████████████▏       80% | 410.00/512.17 MB [00:40<00:08, 11.51MB/s]:
# ███████████████████████████▏   94% | 480.00/512.54 MB [00:46<00:02, 11.39MB/s]:
#
#
# ██████████████████▉            65% | 335.00/512.13 MB [00:33<00:15, 11.50MB/s]:
#
# ███████████████████████▍       81% | 415.00/512.17 MB [00:40<00:08, 11.65MB/s]:
# ███████████████████████████▍   95% | 485.00/512.54 MB [00:47<00:02, 11.37MB/s]:
#
#
# ███████████████████▎           66% | 340.00/512.13 MB [00:33<00:14, 11.51MB/s]:
#
# ███████████████████████▊       82% | 420.00/512.17 MB [00:40<00:07, 11.68MB/s]:
# ███████████████████████████▋   96% | 490.00/512.54 MB [00:47<00:01, 11.42MB/s]:
#
#
# ███████████████████▌           67% | 345.00/512.13 MB [00:33<00:14, 11.60MB/s]:
#
# █████████████████████████████ 100% | 512.14/512.14 MB [00:54<00:00,  9.45MB/s]:
#
# ████████████████████████████   97% | 495.00/512.54 MB [00:48<00:01, 11.46MB/s]:
#
#
# ███████████████████▊           68% | 350.00/512.13 MB [00:34<00:13, 11.63MB/s]:
#
# ████████████████████████▎      84% | 430.00/512.17 MB [00:41<00:07, 11.63MB/s]:
# ████████████████████████████▎  98% | 500.00/512.54 MB [00:48<00:01, 11.61MB/s]:
#
#
# ████████████████████           69% | 355.00/512.13 MB [00:34<00:13, 11.72MB/s]:
#
# ████████████████████████▋      85% | 435.00/512.17 MB [00:42<00:06, 11.61MB/s]:
# ████████████████████████████▌  99% | 505.00/512.54 MB [00:48<00:00, 11.54MB/s]:
#
#
# ████████████████████▍          70% | 360.00/512.13 MB [00:35<00:13, 11.61MB/s]:
#
# ████████████████████████▉      86% | 440.00/512.17 MB [00:42<00:06, 11.62MB/s]:
# ████████████████████████████▊ 100% | 510.00/512.54 MB [00:49<00:00, 11.48MB/s]:
#
#
# ████████████████████▋          71% | 365.00/512.13 MB [00:35<00:12, 11.61MB/s]:
#
# █████████████████████████▏     87% | 445.00/512.17 MB [00:43<00:05, 11.68MB/s]:
# ████████████████████████████▉ 100% | 512.53/512.54 MB [00:49<00:00, 11.47MB/s]:
#
#
# ████████████████████▉          72% | 370.00/512.13 MB [00:36<00:12, 11.58MB/s]:
#
# █████████████████████████▍     88% | 450.00/512.17 MB [00:43<00:05, 11.75MB/s]:
#
#
# █████████████████████▏         73% | 375.00/512.13 MB [00:36<00:11, 11.64MB/s]:
#
# █████████████████████████▊     89% | 455.00/512.17 MB [00:43<00:04, 11.74MB/s]:
#
#
# █████████████████████▌         74% | 380.00/512.13 MB [00:36<00:11, 11.67MB/s]:
#
# ██████████████████████████     90% | 460.00/512.17 MB [00:44<00:04, 11.68MB/s]:
#
#
# █████████████████████▊         75% | 385.00/512.13 MB [00:37<00:10, 11.75MB/s]:
#
# ██████████████████████████▎    91% | 465.00/512.17 MB [00:44<00:04, 11.63MB/s]:
#
#
# ██████████████████████         76% | 390.00/512.13 MB [00:37<00:10, 11.63MB/s]:
#
# ██████████████████████████▌    92% | 470.00/512.17 MB [00:45<00:03, 11.66MB/s]:
#
#
# ██████████████████████▎        77% | 395.00/512.13 MB [00:38<00:10, 11.62MB/s]:
#
# ██████████████████████████▉    93% | 475.00/512.17 MB [00:45<00:03, 11.68MB/s]:
#
#
# ██████████████████████▋        78% | 400.00/512.13 MB [00:38<00:09, 11.58MB/s]:
#
# ███████████████████████████▏   94% | 480.00/512.17 MB [00:46<00:02, 11.77MB/s]:
#
#
# ██████████████████████▉        79% | 405.00/512.13 MB [00:39<00:09, 11.65MB/s]:
#
# ███████████████████████████▍   95% | 485.00/512.17 MB [00:46<00:02, 11.75MB/s]:
#
#
# ███████████████████████▏       80% | 410.00/512.13 MB [00:39<00:08, 11.68MB/s]:
#
# ███████████████████████████▋   96% | 490.00/512.17 MB [00:46<00:01, 11.65MB/s]:
#
#
# ███████████████████████▍       81% | 415.00/512.13 MB [00:39<00:08, 11.74MB/s]:
#
# ████████████████████████████   97% | 495.00/512.17 MB [00:47<00:01, 11.61MB/s]:
#
#
# ███████████████████████▊       82% | 420.00/512.13 MB [00:40<00:07, 11.64MB/s]:
#
# ████████████████████████████▎  98% | 500.00/512.17 MB [00:47<00:01, 11.68MB/s]:
#
#
# ████████████████████████       83% | 425.00/512.13 MB [00:40<00:07, 11.62MB/s]:
#
# █████████████████████████████ 100% | 512.54/512.54 MB [00:54<00:00,  9.36MB/s]:
#
#
#
# ████████████████████████▎      84% | 430.00/512.13 MB [00:41<00:07, 11.58MB/s]:
#
# ████████████████████████████▉ 100% | 510.00/512.17 MB [00:48<00:00, 11.78MB/s]:
#
# ████████████████████████████▉ 100% | 512.16/512.17 MB [00:48<00:00, 11.76MB/s]:
#
#
# ████████████████████████▋      85% | 435.00/512.13 MB [00:41<00:06, 11.66MB/s]:
#
#
# ████████████████████████▉      86% | 440.00/512.13 MB [00:42<00:06, 11.68MB/s]:
#
#
# █████████████████████████▏     87% | 445.00/512.13 MB [00:42<00:05, 11.75MB/s]:
#
#
# █████████████████████████▍     88% | 450.00/512.13 MB [00:42<00:05, 11.64MB/s]:
#
#
# █████████████████████████▊     89% | 455.00/512.13 MB [00:43<00:04, 11.61MB/s]:
#
#
# ██████████████████████████     90% | 460.00/512.13 MB [00:43<00:04, 11.58MB/s]:
#
#
# ██████████████████████████▎    91% | 465.00/512.13 MB [00:44<00:04, 11.67MB/s]:
#
#
# ██████████████████████████▌    92% | 470.00/512.13 MB [00:44<00:03, 11.69MB/s]:
#
#
# ██████████████████████████▉    93% | 475.00/512.13 MB [00:45<00:03, 11.75MB/s]:
#
#
# ███████████████████████████▏   94% | 480.00/512.13 MB [00:45<00:02, 11.64MB/s]:
#
#
# █████████████████████████████ 100% | 512.17/512.17 MB [00:53<00:00,  9.56MB/s]:
#
#
#
# ███████████████████████████▋   96% | 490.00/512.13 MB [00:46<00:01, 11.58MB/s]:
#
#
# ████████████████████████████   97% | 495.00/512.13 MB [00:46<00:01, 11.66MB/s]:
#
#
# ████████████████████████████▎  98% | 500.00/512.13 MB [00:47<00:01, 11.68MB/s]:
#
#
# ████████████████████████████▌  99% | 505.00/512.13 MB [00:47<00:00, 11.75MB/s]:
#
#
# ████████████████████████████▉ 100% | 510.00/512.13 MB [00:48<00:00, 11.64MB/s]:
#
#
# █████████████████████████████ 100% | 512.13/512.13 MB [00:52<00:00,  9.67MB/s]:
# Uploading dataset changes (5414 files compressed to 443.2 MiB) to https://files.clear.ml
# █████████████████████████████████ 100% | 9.38/9.38 MB [00:00<00:00, 12.72MB/s]:
# ██▊                               9% | 40.00/443.2 MB [00:02<00:32, 12.50MB/s]:
# Uploading dataset changes (5360 files compressed to 438.18 MiB) to https://files.clear.ml
# ████▏                            14% | 60.00/443.2 MB [00:04<00:33, 11.31MB/s]:
# ████▌                            15% | 65.00/443.2 MB [00:05<00:32, 11.65MB/s]:
# █████████████████████████████████ 100% | 8.69/8.69 MB [00:00<00:00, 11.86MB/s]:
# █████▏                           17% | 75.00/443.2 MB [00:06<00:31, 11.63MB/s]:
# █████▌                           18% | 80.00/443.2 MB [00:06<00:33, 10.94MB/s]:
# █████▉                           19% | 85.00/443.2 MB [00:07<00:31, 11.37MB/s]:
# ██████▎                          20% | 90.00/443.2 MB [00:07<00:30, 11.69MB/s]:
# ██████▋                          21% | 95.00/443.2 MB [00:07<00:29, 11.92MB/s]:
# ██████▊                         23% | 100.00/443.2 MB [00:08<00:28, 12.09MB/s]:
# ███████                         24% | 105.00/443.2 MB [00:08<00:31, 10.86MB/s]:
# ███████▍                        25% | 110.00/443.2 MB [00:09<00:29, 11.30MB/s]:
# ██▋                              9% | 40.00/438.18 MB [00:02<00:31, 12.55MB/s]:
# Uploading dataset changes (5315 files compressed to 436.92 MiB) to https://files.clear.ml
# ███████▊                        26% | 115.00/443.2 MB [00:09<00:31, 10.26MB/s]:
# ████████                        27% | 120.00/443.2 MB [00:10<00:29, 10.78MB/s]:
# ████████▍                       28% | 125.00/443.2 MB [00:10<00:28, 11.17MB/s]:
# ████████▊                       29% | 130.00/443.2 MB [00:11<00:27, 11.29MB/s]:
# ████                            14% | 60.00/438.18 MB [00:04<00:33, 11.41MB/s]:
#
# █████████▏                      30% | 135.00/443.2 MB [00:11<00:28, 10.80MB/s]:
# ████▍                           15% | 65.00/438.18 MB [00:05<00:31, 11.67MB/s]:
#
# █████████████████████████████████ 100% | 8.01/8.01 MB [00:00<00:00, 14.35MB/s]:
#
# █████████▊                      33% | 145.00/443.2 MB [00:12<00:26, 11.47MB/s]:
# ██████████▏                     34% | 150.00/443.2 MB [00:12<00:25, 11.62MB/s]:
#
#                                           0% | 0.00/436.92 MB [00:00<?, ?MB/s]:
# ██████████▍                     35% | 155.00/443.2 MB [00:13<00:24, 11.74MB/s]:
#
# ▋                                2% | 10.00/436.92 MB [00:00<00:17, 24.48MB/s]:
# ██████████▊                     36% | 160.00/443.2 MB [00:13<00:24, 11.77MB/s]:
#
# █                                3% | 15.00/436.92 MB [00:00<00:24, 17.38MB/s]:
# ███████████▏                    37% | 165.00/443.2 MB [00:14<00:24, 11.18MB/s]:
# ██████▌                         22% | 95.00/438.18 MB [00:07<00:28, 11.92MB/s]:
#
# ███████████▌                    38% | 170.00/443.2 MB [00:14<00:23, 11.46MB/s]:
# ██████▌                        23% | 100.00/438.18 MB [00:08<00:28, 11.94MB/s]:
#
# ███████████▊                    39% | 175.00/443.2 MB [00:15<00:22, 11.69MB/s]:
# ██████▉                        24% | 105.00/438.18 MB [00:08<00:28, 11.72MB/s]:
#
# ████████████▏                   41% | 180.00/443.2 MB [00:15<00:22, 11.78MB/s]:
# ███████▎                       25% | 110.00/438.18 MB [00:09<00:28, 11.42MB/s]:
#
# ██▍                              8% | 35.00/436.92 MB [00:02<00:32, 12.51MB/s]:
# Uploading dataset changes (5279 files compressed to 434.15 MiB) to https://files.clear.ml
# ████████████▌                   42% | 185.00/443.2 MB [00:16<00:26,  9.74MB/s]:
# ███████▌                       26% | 115.00/438.18 MB [00:09<00:33,  9.64MB/s]:
#
# ████████████▊                   43% | 190.00/443.2 MB [00:16<00:25,  9.97MB/s]:
# ███████▉                       27% | 120.00/438.18 MB [00:10<00:31, 10.11MB/s]:
#
# █████████████▏                  44% | 195.00/443.2 MB [00:17<00:23, 10.41MB/s]:
# ████████▎                      29% | 125.00/438.18 MB [00:10<00:29, 10.51MB/s]:
#
# █████████████▌                  45% | 200.00/443.2 MB [00:17<00:22, 10.67MB/s]:
# ████████▌                      30% | 130.00/438.18 MB [00:11<00:28, 10.84MB/s]:
#
# ███▊                            13% | 55.00/436.92 MB [00:04<00:35, 10.80MB/s]:
#
#
#                                             0% | 0.00/7.33 MB [00:00<?, ?MB/s]:
#
#
# █████████████▉                  46% | 205.00/443.2 MB [00:17<00:22, 10.38MB/s]:
# ████████▉                      31% | 135.00/438.18 MB [00:11<00:28, 10.59MB/s]:
#
# █████████████████████████████████ 100% | 7.33/7.33 MB [00:00<00:00, 11.61MB/s]:
# ██████████████▏                 47% | 210.00/443.2 MB [00:18<00:21, 10.66MB/s]:
# █████████▎                     32% | 140.00/438.18 MB [00:12<00:27, 10.70MB/s]:
#
# ██████████████▌                 49% | 215.00/443.2 MB [00:18<00:20, 10.88MB/s]:
# █████████▌                     33% | 145.00/438.18 MB [00:12<00:26, 10.93MB/s]:
#
# ██████████████▉                 50% | 220.00/443.2 MB [00:19<00:20, 11.06MB/s]:
# █████████▉                     34% | 150.00/438.18 MB [00:12<00:25, 11.14MB/s]:
#
# ███████████████▏                51% | 225.00/443.2 MB [00:19<00:19, 11.15MB/s]:
# ██████████▎                    35% | 155.00/438.18 MB [00:13<00:25, 11.28MB/s]:
#
# █████▍                          18% | 80.00/436.92 MB [00:06<00:31, 11.28MB/s]:
#
#
# ███████████████▌                52% | 230.00/443.2 MB [00:20<00:19, 11.20MB/s]:
# ██████████▌                    37% | 160.00/438.18 MB [00:13<00:24, 11.32MB/s]:
#
# █████▊                          19% | 85.00/436.92 MB [00:07<00:31, 11.24MB/s]:
#
#
# ███████████████▉                53% | 235.00/443.2 MB [00:20<00:18, 11.00MB/s]:
# ██████████▉                    38% | 165.00/438.18 MB [00:14<00:24, 11.05MB/s]:
#
# ██████▏                         21% | 90.00/436.92 MB [00:07<00:32, 10.63MB/s]:
#
#
# ████████████████▏               54% | 240.00/443.2 MB [00:21<00:19, 10.54MB/s]:
# ███████████▎                   39% | 170.00/438.18 MB [00:14<00:25, 10.51MB/s]:
#
# ██████▌                         22% | 95.00/436.92 MB [00:08<00:33, 10.25MB/s]:
#
#
# ████████████████▌               55% | 245.00/443.2 MB [00:21<00:19, 10.14MB/s]:
# ███████████▌                   40% | 175.00/438.18 MB [00:15<00:25, 10.27MB/s]:
#
# ██████▋                        23% | 100.00/436.92 MB [00:08<00:33, 10.11MB/s]:
#
#
# ████████████████▉               56% | 250.00/443.2 MB [00:22<00:19,  9.88MB/s]:
# ███████████▉                   41% | 180.00/438.18 MB [00:15<00:25,  9.98MB/s]:
#
# ██████▉                        24% | 105.00/436.92 MB [00:09<00:33,  9.91MB/s]:
#
#
# █████████████████▎              58% | 255.00/443.2 MB [00:22<00:18,  9.91MB/s]:
# ████████████▏                  42% | 185.00/438.18 MB [00:16<00:25,  9.98MB/s]:
#
# ███████▎                       25% | 110.00/436.92 MB [00:10<00:33,  9.81MB/s]:
#
#
# █████████████████▌              59% | 260.00/443.2 MB [00:23<00:18,  9.87MB/s]:
# ████████████▌                  43% | 190.00/438.18 MB [00:16<00:25,  9.86MB/s]:
#
# ███████▋                       26% | 115.00/436.92 MB [00:10<00:32,  9.81MB/s]:
#
#
# █████████████████▉              60% | 265.00/443.2 MB [00:23<00:18,  9.88MB/s]:
# ████████████▉                  45% | 195.00/438.18 MB [00:17<00:24,  9.82MB/s]:
#
# ███████▉                       27% | 120.00/436.92 MB [00:11<00:32,  9.77MB/s]:
#
#
# ██████████████████▎             61% | 270.00/443.2 MB [00:24<00:17,  9.90MB/s]:
# █████████████▏                 46% | 200.00/438.18 MB [00:17<00:24,  9.74MB/s]:
#
# ████████▎                      29% | 125.00/436.92 MB [00:11<00:31,  9.84MB/s]:
#
#
# ██████████████████▌             62% | 275.00/443.2 MB [00:24<00:17,  9.87MB/s]:
# █████████████▌                 47% | 205.00/438.18 MB [00:18<00:23,  9.73MB/s]:
#
# ████████▋                      30% | 130.00/436.92 MB [00:12<00:31,  9.79MB/s]:
#
#
# ██████████████████▉             63% | 280.00/443.2 MB [00:25<00:16,  9.85MB/s]:
# █████████████▉                 48% | 210.00/438.18 MB [00:18<00:23,  9.73MB/s]:
#
# ████████▉                      31% | 135.00/436.92 MB [00:12<00:30,  9.78MB/s]:
#
#
# ███████████████████▎            64% | 285.00/443.2 MB [00:25<00:16,  9.84MB/s]:
# ██████████████▏                49% | 215.00/438.18 MB [00:19<00:22,  9.73MB/s]:
#
# █████████▎                     32% | 140.00/436.92 MB [00:13<00:30,  9.81MB/s]:
#
#
# ███████████████████▋            65% | 290.00/443.2 MB [00:26<00:15,  9.86MB/s]:
# ██████████████▌                50% | 220.00/438.18 MB [00:20<00:22,  9.78MB/s]:
#
# █████████▌                     33% | 145.00/436.92 MB [00:13<00:29,  9.75MB/s]:
#
#
# ███████████████████▉            67% | 295.00/443.2 MB [00:26<00:15,  9.76MB/s]:
# ██████████████▉                51% | 225.00/438.18 MB [00:20<00:21,  9.77MB/s]:
#
# █████████▉                     34% | 150.00/436.92 MB [00:14<00:29,  9.74MB/s]:
#
#
# ████████████████████▎           68% | 300.00/443.2 MB [00:27<00:14,  9.79MB/s]:
# ███████████████▏               52% | 230.00/438.18 MB [00:21<00:21,  9.79MB/s]:
#
# ██████████▎                    35% | 155.00/436.92 MB [00:14<00:29,  9.72MB/s]:
#
#
# ████████████████████▋           69% | 305.00/443.2 MB [00:27<00:14,  9.82MB/s]:
# ███████████████▌               54% | 235.00/438.18 MB [00:21<00:20,  9.83MB/s]:
#
# ██████████▌                    37% | 160.00/436.92 MB [00:15<00:28,  9.73MB/s]:
#
#
# ████████████████████▉           70% | 310.00/443.2 MB [00:28<00:13,  9.83MB/s]:
# ███████████████▉               55% | 240.00/438.18 MB [00:22<00:20,  9.82MB/s]:
#
# ██████████▉                    38% | 165.00/436.92 MB [00:15<00:27,  9.75MB/s]:
#
#
# █████████████████████▎          71% | 315.00/443.2 MB [00:28<00:13,  9.76MB/s]:
# ████████████████▏              56% | 245.00/438.18 MB [00:22<00:19,  9.84MB/s]:
#
# ███████████▎                   39% | 170.00/436.92 MB [00:16<00:27,  9.76MB/s]:
#
#
# █████████████████████▋          72% | 320.00/443.2 MB [00:29<00:12,  9.92MB/s]:
# ████████████████▌              57% | 250.00/438.18 MB [00:23<00:19,  9.88MB/s]:
#
# █████████████████████▉          73% | 325.00/443.2 MB [00:29<00:11,  9.98MB/s]:
#
#
# ██████▋                        23% | 100.00/434.15 MB [00:09<00:34,  9.61MB/s]:
# ████████████████▉              58% | 255.00/438.18 MB [00:23<00:18,  9.87MB/s]:
#
# ██████████████████████▎         74% | 330.00/443.2 MB [00:30<00:11, 10.00MB/s]:
#
#
# ███████                        24% | 105.00/434.15 MB [00:10<00:34,  9.67MB/s]:
# █████████████████▏             59% | 260.00/438.18 MB [00:24<00:18,  9.77MB/s]:
#
# ██████████████████████▋         76% | 335.00/443.2 MB [00:30<00:10,  9.96MB/s]:
#
#
# ███████▎                       25% | 110.00/434.15 MB [00:10<00:33,  9.80MB/s]:
# █████████████████▌             60% | 265.00/438.18 MB [00:24<00:17,  9.80MB/s]:
#
# ███████████████████████         77% | 340.00/443.2 MB [00:31<00:10,  9.93MB/s]:
#
#
# ███████▋                       26% | 115.00/434.15 MB [00:11<00:32,  9.80MB/s]:
# █████████████████▊             62% | 270.00/438.18 MB [00:25<00:17,  9.63MB/s]:
#
# ███████████████████████▎        78% | 345.00/443.2 MB [00:31<00:10,  9.74MB/s]:
#
#
# ████████                       28% | 120.00/434.15 MB [00:11<00:32,  9.55MB/s]:
# ██████████████████▏            63% | 275.00/438.18 MB [00:25<00:17,  9.50MB/s]:
#
# ███████████████████████▋        79% | 350.00/443.2 MB [00:32<00:09,  9.70MB/s]:
#
#
# ████████▎                      29% | 125.00/434.15 MB [00:12<00:32,  9.60MB/s]:
# ██████████████████▌            64% | 280.00/438.18 MB [00:26<00:16,  9.61MB/s]:
#
# ████████████████████████        80% | 355.00/443.2 MB [00:32<00:09,  9.74MB/s]:
#
#
# ████████▋                      30% | 130.00/434.15 MB [00:13<00:31,  9.63MB/s]:
# ██████████████████▊            65% | 285.00/438.18 MB [00:26<00:15,  9.68MB/s]:
#
# ████████████████████████▎       81% | 360.00/443.2 MB [00:33<00:08,  9.72MB/s]:
#
#
# █████████                      31% | 135.00/434.15 MB [00:13<00:30,  9.68MB/s]:
# ███████████████████▏           66% | 290.00/438.18 MB [00:27<00:15,  9.74MB/s]:
#
# ████████████████████████▋       82% | 365.00/443.2 MB [00:33<00:08,  9.71MB/s]:
#
#
# █████████▎                     32% | 140.00/434.15 MB [00:14<00:30,  9.76MB/s]:
# ███████████████████▌           67% | 295.00/438.18 MB [00:27<00:14,  9.73MB/s]:
#
# █████████████████████████       83% | 370.00/443.2 MB [00:34<00:07,  9.78MB/s]:
#
#
# █████████▋                     33% | 145.00/434.15 MB [00:14<00:29,  9.78MB/s]:
# ███████████████████▊           68% | 300.00/438.18 MB [00:28<00:14,  9.80MB/s]:
#
# █████████████████████████▍      85% | 375.00/443.2 MB [00:34<00:06,  9.79MB/s]:
#
#
# ██████████                     35% | 150.00/434.15 MB [00:15<00:29,  9.76MB/s]:
# ████████████████████▏          70% | 305.00/438.18 MB [00:28<00:13,  9.81MB/s]:
#
# █████████████████████████▋      86% | 380.00/443.2 MB [00:35<00:06,  9.79MB/s]:
#
#
# ██████████▎                    36% | 155.00/434.15 MB [00:15<00:28,  9.86MB/s]:
# ████████████████████▌          71% | 310.00/438.18 MB [00:29<00:13,  9.77MB/s]:
#
# ██████████████████████████      87% | 385.00/443.2 MB [00:35<00:05,  9.84MB/s]:
#
#
# ██████████▋                    37% | 160.00/434.15 MB [00:16<00:27,  9.86MB/s]:
# ████████████████████▊          72% | 315.00/438.18 MB [00:29<00:12,  9.81MB/s]:
#
# ██████████████████████████▍     88% | 390.00/443.2 MB [00:36<00:05,  9.84MB/s]:
#
#
# ███████████                    38% | 165.00/434.15 MB [00:16<00:27,  9.82MB/s]:
# █████████████████████▏         73% | 320.00/438.18 MB [00:30<00:12,  9.84MB/s]:
#
# ██████████████████████████▋     89% | 395.00/443.2 MB [00:37<00:04,  9.85MB/s]:
#
#
# ███████████▎                   39% | 170.00/434.15 MB [00:17<00:26,  9.87MB/s]:
# █████████████████████▌         74% | 325.00/438.18 MB [00:30<00:11,  9.84MB/s]:
#
# ███████████████████████████     90% | 400.00/443.2 MB [00:37<00:04,  9.82MB/s]:
#
#
# ███████████▋                   40% | 175.00/434.15 MB [00:17<00:26,  9.81MB/s]:
# █████████████████████▊         75% | 330.00/438.18 MB [00:31<00:11,  9.83MB/s]:
#
# ███████████████████████████▍    91% | 405.00/443.2 MB [00:38<00:03,  9.85MB/s]:
#
#
# ████████████                   41% | 180.00/434.15 MB [00:18<00:26,  9.74MB/s]:
# ██████████████████████▏        76% | 335.00/438.18 MB [00:31<00:10,  9.78MB/s]:
#
# ███████████████████████████▊    93% | 410.00/443.2 MB [00:38<00:03,  9.90MB/s]:
#
#
# ████████████▎                  43% | 185.00/434.15 MB [00:18<00:25,  9.77MB/s]:
# ██████████████████████▌        78% | 340.00/438.18 MB [00:32<00:10,  9.77MB/s]:
#
# ████████████████████████████    94% | 415.00/443.2 MB [00:39<00:02,  9.84MB/s]:
#
#
# ████████████▋                  44% | 190.00/434.15 MB [00:19<00:24,  9.79MB/s]:
# ██████████████████████▊        79% | 345.00/438.18 MB [00:32<00:09,  9.78MB/s]:
#
# ████████████████████████████▍   95% | 420.00/443.2 MB [00:39<00:02,  9.84MB/s]:
#
#
# █████████████                  45% | 195.00/434.15 MB [00:19<00:24,  9.77MB/s]:
# ███████████████████████▏       80% | 350.00/438.18 MB [00:33<00:09,  9.76MB/s]:
#
# ████████████████████████████▊   96% | 425.00/443.2 MB [00:40<00:01,  9.99MB/s]:
#
#
# █████████████▎                 46% | 200.00/434.15 MB [00:20<00:24,  9.74MB/s]:
# ███████████████████████▍       81% | 355.00/438.18 MB [00:33<00:08,  9.76MB/s]:
#
# █████████████████████████████   97% | 430.00/443.2 MB [00:40<00:01,  9.87MB/s]:
#
#
# █████████████▋                 47% | 205.00/434.15 MB [00:20<00:23,  9.70MB/s]:
# ███████████████████████▊       82% | 360.00/438.18 MB [00:34<00:07,  9.98MB/s]:
#
# █████████████████████████████▍  98% | 435.00/443.2 MB [00:41<00:00,  9.90MB/s]:
#
#
# ██████████████                 48% | 210.00/434.15 MB [00:21<00:23,  9.65MB/s]:
# ████████████████████████▏      83% | 365.00/438.18 MB [00:34<00:07,  9.85MB/s]:
#
# █████████████████████████████▊  99% | 440.00/443.2 MB [00:41<00:00,  9.93MB/s]:
#
#
# ██████████████▎                50% | 215.00/434.15 MB [00:21<00:22,  9.65MB/s]:
# █████████████████████████████▉ 100% | 443.19/443.2 MB [00:41<00:00,  9.92MB/s]:
#
# ███████████████████▌           68% | 295.00/436.92 MB [00:28<00:14,  9.95MB/s]:
#
#
# ██████████████▋                51% | 220.00/434.15 MB [00:22<00:21, 10.06MB/s]:
# ████████████████████████▊      86% | 375.00/438.18 MB [00:35<00:06, 10.24MB/s]:
#
# ███████████████████▉           69% | 300.00/436.92 MB [00:29<00:13, 10.40MB/s]:
#
#
# ███████████████                52% | 225.00/434.15 MB [00:22<00:20, 10.43MB/s]:
# █████████████████████████▏     87% | 380.00/438.18 MB [00:36<00:05, 10.63MB/s]:
#
# ████████████████████▏          70% | 305.00/436.92 MB [00:29<00:12, 10.73MB/s]:
#
#
# ███████████████▎               53% | 230.00/434.15 MB [00:23<00:19, 10.69MB/s]:
# █████████████████████████▍     88% | 385.00/438.18 MB [00:36<00:04, 10.91MB/s]:
#
# ████████████████████▌          71% | 310.00/436.92 MB [00:30<00:11, 10.96MB/s]:
#
#
# ███████████████▋               54% | 235.00/434.15 MB [00:23<00:18, 10.90MB/s]:
# █████████████████████████▊     89% | 390.00/438.18 MB [00:37<00:04, 11.09MB/s]:
#
# ████████████████████▉          72% | 315.00/436.92 MB [00:30<00:10, 11.13MB/s]:
# ██████████████████████████▏    90% | 395.00/438.18 MB [00:37<00:03, 11.36MB/s]:
#
#
# ████████████████               55% | 240.00/434.15 MB [00:23<00:17, 11.06MB/s]:
#
# █████████████████████▏         73% | 320.00/436.92 MB [00:31<00:10, 11.36MB/s]:
# ██████████████████████████▍    91% | 400.00/438.18 MB [00:37<00:03, 11.51MB/s]:
#
#
# ████████████████▎              56% | 245.00/434.15 MB [00:24<00:16, 11.23MB/s]:
#
# █████████████████████▌         74% | 325.00/436.92 MB [00:31<00:09, 11.53MB/s]:
# ██████████████████████████▊    92% | 405.00/438.18 MB [00:38<00:02, 11.61MB/s]:
#
#
# ████████████████▋              58% | 250.00/434.15 MB [00:24<00:16, 11.43MB/s]:
#
# █████████████████████▉         76% | 330.00/436.92 MB [00:31<00:09, 11.55MB/s]:
# ███████████████████████████▏   94% | 410.00/438.18 MB [00:38<00:02, 11.64MB/s]:
#
#
# █████████████████              59% | 255.00/434.15 MB [00:25<00:15, 11.42MB/s]:
#
# ██████████████████████▏        77% | 335.00/436.92 MB [00:32<00:08, 11.57MB/s]:
# ███████████████████████████▍   95% | 415.00/438.18 MB [00:39<00:01, 11.63MB/s]:
#
#
# ██████████████████████████████ 100% | 443.20/443.2 MB [00:45<00:00,  9.68MB/s]:
#
#
# ██████████████████████▌        78% | 340.00/436.92 MB [00:32<00:08, 11.56MB/s]:
# ███████████████████████████▊   96% | 420.00/438.18 MB [00:39<00:01, 11.60MB/s]:
#
#
# █████████████████▋             61% | 265.00/434.15 MB [00:26<00:14, 11.38MB/s]:
#
# ██████████████████████▉        79% | 345.00/436.92 MB [00:33<00:07, 11.55MB/s]:
# ████████████████████████████▏  97% | 425.00/438.18 MB [00:40<00:01, 11.68MB/s]:
#
#
# ██████████████████             62% | 270.00/434.15 MB [00:26<00:14, 11.39MB/s]:
#
# ███████████████████████▏       80% | 350.00/436.92 MB [00:33<00:07, 11.65MB/s]:
# ████████████████████████████▍  98% | 430.00/438.18 MB [00:40<00:00, 11.73MB/s]:
#
#
# ██████████████████▎            63% | 275.00/434.15 MB [00:26<00:13, 11.47MB/s]:
#
# ███████████████████████▌       81% | 355.00/436.92 MB [00:34<00:06, 11.76MB/s]:
# ████████████████████████████▊  99% | 435.00/438.18 MB [00:40<00:00, 11.81MB/s]:
#
#
# ██████████████████▋            64% | 280.00/434.15 MB [00:27<00:13, 11.63MB/s]:
#
# ███████████████████████▉       82% | 360.00/436.92 MB [00:34<00:06, 11.71MB/s]:
# █████████████████████████████ 100% | 438.18/438.18 MB [00:41<00:00, 11.71MB/s]:
#
#
# ███████████████████            66% | 285.00/434.15 MB [00:27<00:12, 11.57MB/s]:
#
# ████████████████████████▏      84% | 365.00/436.92 MB [00:34<00:06, 11.67MB/s]:
#
#
# ███████████████████▎           67% | 290.00/434.15 MB [00:28<00:12, 11.45MB/s]:
#
# ████████████████████████▌      85% | 370.00/436.92 MB [00:35<00:05, 11.63MB/s]:
#
#
# ███████████████████▋           68% | 295.00/434.15 MB [00:28<00:12, 11.45MB/s]:
#
# ████████████████████████▉      86% | 375.00/436.92 MB [00:35<00:05, 11.58MB/s]:
#
#
# ████████████████████           69% | 300.00/434.15 MB [00:29<00:11, 11.43MB/s]:
#
# █████████████████████████▏     87% | 380.00/436.92 MB [00:36<00:04, 11.69MB/s]:
#
#
# ████████████████████▎          70% | 305.00/434.15 MB [00:29<00:11, 11.52MB/s]:
#
# █████████████████████████▌     88% | 385.00/436.92 MB [00:36<00:04, 11.79MB/s]:
#
#
# ████████████████████▋          71% | 310.00/434.15 MB [00:29<00:10, 11.66MB/s]:
#
# █████████████████████████▉     89% | 390.00/436.92 MB [00:37<00:03, 11.74MB/s]:
#
#
# █████████████████████          73% | 315.00/434.15 MB [00:30<00:10, 11.61MB/s]:
#
# ██████████████████████████▏    90% | 395.00/436.92 MB [00:37<00:03, 11.70MB/s]:
#
#
# █████████████████████▍         74% | 320.00/434.15 MB [00:30<00:09, 11.47MB/s]:
#
# ██████████████████████████▌    92% | 400.00/436.92 MB [00:37<00:03, 11.66MB/s]:
#
#
# █████████████████████▋         75% | 325.00/434.15 MB [00:31<00:09, 11.47MB/s]:
#
# █████████████████████████████ 100% | 438.18/438.18 MB [00:45<00:00,  9.72MB/s]:
#
#
#
# ██████████████████████         76% | 330.00/434.15 MB [00:31<00:09, 11.44MB/s]:
#
# ███████████████████████████▏   94% | 410.00/436.92 MB [00:38<00:02, 11.72MB/s]:
#
#
# ██████████████████████▍        77% | 335.00/434.15 MB [00:32<00:08, 11.52MB/s]:
#
# ███████████████████████████▌   95% | 415.00/436.92 MB [00:39<00:01, 11.81MB/s]:
#
#
# ██████████████████████▋        78% | 340.00/434.15 MB [00:32<00:08, 11.66MB/s]:
#
# ███████████████████████████▉   96% | 420.00/436.92 MB [00:39<00:01, 11.75MB/s]:
#
#
# ███████████████████████        79% | 345.00/434.15 MB [00:33<00:07, 11.60MB/s]:
#
# ████████████████████████████▏  97% | 425.00/436.92 MB [00:40<00:01, 11.70MB/s]:
#
#
# ███████████████████████▍       81% | 350.00/434.15 MB [00:33<00:07, 11.47MB/s]:
#
# ████████████████████████████▌  98% | 430.00/436.92 MB [00:40<00:00, 11.66MB/s]:
#
#
# ███████████████████████▋       82% | 355.00/434.15 MB [00:33<00:06, 11.47MB/s]:
#
# ████████████████████████████▊ 100% | 435.00/436.92 MB [00:40<00:00, 11.59MB/s]:
#
# ████████████████████████████▉ 100% | 436.91/436.92 MB [00:41<00:00, 11.70MB/s]:
#
#
# ████████████████████████       83% | 360.00/434.15 MB [00:34<00:06, 11.42MB/s]:
#
#
# ████████████████████████▍      84% | 365.00/434.15 MB [00:34<00:05, 11.53MB/s]:
#
#
# ████████████████████████▋      85% | 370.00/434.15 MB [00:35<00:05, 11.67MB/s]:
#
#
# █████████████████████████      86% | 375.00/434.15 MB [00:35<00:05, 11.60MB/s]:
#
#
# █████████████████████████▍     88% | 380.00/434.15 MB [00:36<00:04, 11.49MB/s]:
#
#
# █████████████████████████▋     89% | 385.00/434.15 MB [00:36<00:04, 11.47MB/s]:
#
#
# ██████████████████████████     90% | 390.00/434.15 MB [00:36<00:03, 11.43MB/s]:
#
#
# ██████████████████████████▍    91% | 395.00/434.15 MB [00:37<00:03, 11.54MB/s]:
#
#
# █████████████████████████████ 100% | 436.92/436.92 MB [00:45<00:00,  9.68MB/s]:
#
#
#
# ███████████████████████████    93% | 405.00/434.15 MB [00:38<00:02, 11.59MB/s]:
#
#
# ███████████████████████████▍   94% | 410.00/434.15 MB [00:38<00:02, 11.49MB/s]:
#
#
# ███████████████████████████▋   96% | 415.00/434.15 MB [00:39<00:01, 11.48MB/s]:
#
#
# ████████████████████████████   97% | 420.00/434.15 MB [00:39<00:01, 11.44MB/s]:
#
#
# ████████████████████████████▍  98% | 425.00/434.15 MB [00:39<00:00, 11.54MB/s]:
#
#
# ████████████████████████████▋  99% | 430.00/434.15 MB [00:40<00:00, 11.69MB/s]:
#
#
# █████████████████████████████ 100% | 434.15/434.15 MB [00:44<00:00,  9.72MB/s]:
# File compression and upload completed: total size 3.71 GiB, 8 chunk(s) stored (average size 475.18 MiB)
# █████████████████████████████████ 100% | 7.33/7.33 MB [00:00<00:00, 12.64MB/s]:
# █████████████████████████████████ 100% | 7.33/7.33 MB [00:00<00:00, 13.05MB/s]:
# Dataset Upload
