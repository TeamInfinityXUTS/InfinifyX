# %% [markdown]
# # Training pipeline

# %% [markdown]
# ## ClearML Connect

# %%
# !pip install git+https://github.com/clearml/clearml
# !pip install clearml-agent
# Out:
# Collecting git+https://github.com/clearml/clearml
#   Cloning https://github.com/clearml/clearml to /tmp/pip-req-build-6gpew5k8
#   Running command git clone --filter=blob:none --quiet https://github.com/clearml/clearml /tmp/pip-req-build-6gpew5k8
#   Resolved https://github.com/clearml/clearml to commit dae19f212805ccace866add6a751888f77ccd647
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: attrs>=18.0 in /opt/conda/lib/python3.12/site-packages (from clearml==2.1.3) (23.2.0)
# Requirement already satisfied: furl>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from clearml==2.1.3) (2.1.4)
# Requirement already satisfied: jsonschema>=2.6.0 in /opt/conda/lib/python3.12/site-packages (from clearml==2.1.3) (4.23.0)
# Requirement already satisfied: numpy>=1.10 in /opt/conda/lib/python3.12/site-packages (from clearml==2.1.3) (2.4.3)
# Requirement already satisfied: pathlib2>=2.3.0 in /opt/conda/lib/python3.12/site-packages (from clearml==2.1.3) (2.3.7.post1)
# Requirement already satisfied: Pillow>=10.3.0 in /opt/conda/lib/python3.12/site-packages (from clearml==2.1.3) (11.3.0)
# Requirement already satisfied: psutil>=3.4.2 in /opt/conda/lib/python3.12/site-packages (from clearml==2.1.3) (5.9.8)
# Requirement already satisfied: pyparsing>=2.0.3 in /opt/conda/lib/python3.12/site-packages (from clearml==2.1.3) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/conda/lib/python3.12/site-packages (from clearml==2.1.3) (2.9.0.post0)
# Requirement already satisfied: pyjwt<2.11.0,>=2.4.0 in /opt/conda/lib/python3.12/site-packages (from clearml==2.1.3) (2.10.1)
# Requirement already satisfied: PyYAML>=3.12 in /opt/conda/lib/python3.12/site-packages (from clearml==2.1.3) (6.0.3)
# Requirement already satisfied: referencing<0.40 in /opt/conda/lib/python3.12/site-packages (from clearml==2.1.3) (0.37.0)
# Requirement already satisfied: requests>=2.32.0 in /opt/conda/lib/python3.12/site-packages (from clearml==2.1.3) (2.32.5)
# Requirement already satisfied: six>=1.16.0 in /opt/conda/lib/python3.12/site-packages (from clearml==2.1.3) (1.17.0)
# Requirement already satisfied: urllib3>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from clearml==2.1.3) (1.26.20)
# Requirement already satisfied: rpds-py>=0.7.0 in /opt/conda/lib/python3.12/site-packages (from referencing<0.40->clearml==2.1.3) (0.27.1)
# Requirement already satisfied: typing-extensions>=4.4.0 in /opt/conda/lib/python3.12/site-packages (from referencing<0.40->clearml==2.1.3) (4.15.0)
# Requirement already satisfied: orderedmultidict>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from furl>=2.0.0->clearml==2.1.3) (1.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=2.6.0->clearml==2.1.3) (2025.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests>=2.32.0->clearml==2.1.3) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests>=2.32.0->clearml==2.1.3) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests>=2.32.0->clearml==2.1.3) (2026.1.4)
# Requirement already satisfied: clearml-agent in /opt/conda/lib/python3.12/site-packages (2.0.7)
# Requirement already satisfied: psutil<7.1,>=3.4.2 in /opt/conda/lib/python3.12/site-packages (from clearml-agent) (5.9.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from clearml-agent) (1.26.20)
# Requirement already satisfied: virtualenv<21,>=16 in /opt/conda/lib/python3.12/site-packages (from clearml-agent) (20.38.0)
# Requirement already satisfied: requests<2.33,>=2.20.0 in /opt/conda/lib/python3.12/site-packages (from clearml-agent) (2.32.5)
# Requirement already satisfied: setuptools<82.0.0 in /opt/conda/lib/python3.12/site-packages (from clearml-agent) (81.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests<2.33,>=2.20.0->clearml-agent) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests<2.33,>=2.20.0->clearml-agent) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests<2.33,>=2.20.0->clearml-agent) (2026.1.4)
# Requirement already satisfied: distlib<1,>=0.3.7 in /opt/conda/lib/python3.12/site-packages (from virtualenv<21,>=16->clearml-agent) (0.4.0)
# Requirement already satisfied: filelock<4,>=3.24.2 in /opt/conda/lib/python3.12/site-packages (from virtualenv<21,>=16->clearml-agent) (3.24.3)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /opt/conda/lib/python3.12/site-packages (from virtualenv<21,>=16->clearml-agent) (4.9.2)

# %% [markdown]
# # Yolo training

# %%
# !pip install ultralytics --upgrade
# Out:
# Requirement already satisfied: ultralytics in /opt/conda/lib/python3.12/site-packages (8.4.27)
# Requirement already satisfied: numpy>=1.23.0 in /opt/conda/lib/python3.12/site-packages (from ultralytics) (2.4.3)
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/conda/lib/python3.12/site-packages (from ultralytics) (3.10.8)
# Requirement already satisfied: opencv-python>=4.6.0 in /opt/conda/lib/python3.12/site-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /opt/conda/lib/python3.12/site-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.12/site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.12/site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.12/site-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /opt/conda/lib/python3.12/site-packages (from ultralytics) (2.6.0)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/conda/lib/python3.12/site-packages (from ultralytics) (0.21.0)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.12/site-packages (from ultralytics) (5.9.8)
# Requirement already satisfied: polars>=0.20.0 in /opt/conda/lib/python3.12/site-packages (from ultralytics) (1.39.3)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /opt/conda/lib/python3.12/site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=3 in /opt/conda/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.39.3 in /opt/conda/lib/python3.12/site-packages (from polars>=0.20.0->ultralytics) (1.39.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2026.1.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (81.0.0)
# Requirement already satisfied: sympy!=1.13.2,>=1.13.1 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (2024.12.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy!=1.13.2,>=1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)

# %%
from datetime import datetime
print(datetime.now())
# Out:
# 2026-03-26 01:45:26.891513

# %%
from clearml import Task
Task.set_credentials(
     api_host="https://api.clear.ml",
     web_host="https://app.clear.ml/",
     files_host="https://files.clear.ml",
     key='NAR0DPIK0YBUPHWX0AJ625C54MN7MS',
     secret='eVfgulnTJac1WJfBECjenRN4fUg6mbCGpoAX6jUi4QQgK1j6-ng1Gu5kWWwHQzQqf_I'
)

# %%
from clearml import Task
Task.set_credentials(
     api_host="https://api.clear.ml",
     web_host="https://app.clear.ml/",
     files_host="https://files.clear.ml",
     key='R58U0GS1V7DPMV9POEA3L3E6WHH8EV',
     secret='XQWoX03bgFcB4eJa6Ux8Kt7zmkaVmVdjg-3xBMa1kFdAdpywfbwfAKb8UzS-Rc2WWXU'
)

# %%
# !clearml-agent daemon --queue Yolov8_training_v0.1
# Out:
# /opt/conda/lib/python3.12/site-packages/clearml_agent/external/requirements_parser/requirement.py:3: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import Requirement as Req
# Using environment access key CLEARML_API_ACCESS_KEY=NAR0DPIK0YBUPHWX0AJ625C54MN7MS
# Using environment secret key CLEARML_API_SECRET_KEY=********
# Current configuration (clearml_agent v2.0.7, location: None):
# ----------------------
# agent.worker_id =
# agent.worker_name = default
# agent.force_git_ssh_protocol = false
# agent.python_binary =
# agent.package_manager.type = pip
# agent.package_manager.pip_version.0 = <20.2 ; python_version < '3.10'
# agent.package_manager.pip_version.1 = <22.3 ; python_version >\= '3.10' and python_version <\= '3.11'
# agent.package_manager.pip_version.2 = >\=23,<24.3 ; python_version >\= '3.12'
# agent.package_manager.system_site_packages = false
# agent.package_manager.force_upgrade = false
# agent.package_manager.pip_legacy_resolver.0 = >\=20.3,<24.3
# agent.package_manager.conda_channels.0 = pytorch
# agent.package_manager.conda_channels.1 = conda-forge
# agent.package_manager.conda_channels.2 = nvidia
# agent.package_manager.conda_channels.3 = defaults
# agent.package_manager.priority_optional_packages.0 = pygobject
# agent.package_manager.torch_nightly = false
# agent.package_manager.poetry_files_from_repo_working_dir = false
# agent.package_manager.uv_files_from_repo_working_dir = false
# agent.venvs_dir = /home/sagemaker-user/.clearml/venvs-builds
# agent.venvs_cache.max_entries = 10
# agent.venvs_cache.free_space_threshold_gb = 2.0
# agent.venvs_cache.path = ~/.clearml/venvs-cache
# agent.vcs_cache.enabled = true
# agent.vcs_cache.path = /home/sagemaker-user/.clearml/vcs-cache
# agent.venv_update.enabled = false
# agent.pip_download_cache.enabled = true
# agent.pip_download_cache.path = /home/sagemaker-user/.clearml/pip-download-cache
# agent.translate_ssh = true
# agent.translate_ssl_replacement_scheme = https
# agent.reload_config = false
# agent.docker_pip_cache = /home/sagemaker-user/.clearml/pip-cache
# agent.docker_apt_cache = /home/sagemaker-user/.clearml/apt-cache
# agent.docker_force_pull = false
# agent.default_docker.image = nvidia/cuda:12.6.3-cudnn-runtime-ubuntu20.04
# agent.default_docker.update_back_task = true
# agent.default_docker.match_rules.0.image = python:3.6-bullseye
# agent.default_docker.match_rules.0.arguments = --ipc\=host
# agent.default_docker.match_rules.0.update_back_task = true
# agent.default_docker.match_rules.0.match.script.binary = python3.6$
# agent.default_docker.match_rules.1.image = python:3.7-bullseye
# agent.default_docker.match_rules.1.arguments = --ipc\=host
# agent.default_docker.match_rules.1.update_back_task = true
# agent.default_docker.match_rules.1.match.script.binary = python3.7$
# agent.default_docker.match_rules.2.image = python:3.8-bullseye
# agent.default_docker.match_rules.2.arguments = --ipc\=host
# agent.default_docker.match_rules.2.match.script.binary = python3.8$
# agent.default_docker.match_rules.3.image = python:3.9-bullseye
# agent.default_docker.match_rules.3.arguments = --ipc\=host
# agent.default_docker.match_rules.3.match.script.binary = python3.9$
# agent.default_docker.match_rules.4.image = python:3.10-bullseye
# agent.default_docker.match_rules.4.arguments = --ipc\=host
# agent.default_docker.match_rules.4.match.script.binary = python3.10$
# agent.default_docker.match_rules.5.image = python:3.11-bullseye
# agent.default_docker.match_rules.5.arguments = --ipc\=host
# agent.default_docker.match_rules.5.match.script.binary = python3.11$
# agent.default_docker.match_rules.6.image = python:3.12-bullseye
# agent.default_docker.match_rules.6.arguments = --ipc\=host
# agent.default_docker.match_rules.6.match.script.binary = python3.12$
# agent.default_docker.match_rules.7.image = python:3.13-bullseye
# agent.default_docker.match_rules.7.arguments = --ipc\=host
# agent.default_docker.match_rules.7.match.script.binary = python3.13$
# agent.enable_task_env = false
# agent.sanitize_config_printout = ****
# agent.hide_docker_command_env_vars.enabled = true
# agent.hide_docker_command_env_vars.parse_embedded_urls = true
# agent.abort_callback_max_timeout = 1800
# agent.docker_internal_mounts.sdk_cache = /clearml_agent_cache
# agent.docker_internal_mounts.apt_cache = /var/cache/apt/archives
# agent.docker_internal_mounts.ssh_folder = ~/.ssh
# agent.docker_internal_mounts.ssh_ro_folder = /.ssh
# agent.docker_internal_mounts.pip_cache = /root/.cache/pip
# agent.docker_internal_mounts.poetry_cache = /root/.cache/pypoetry
# agent.docker_internal_mounts.vcs_cache = /root/.clearml/vcs-cache
# agent.docker_internal_mounts.venvs_cache = /root/.clearml/venvs-cache
# agent.docker_internal_mounts.venv_build = ~/.clearml/venvs-builds
# agent.docker_internal_mounts.pip_download = /root/.clearml/pip-download-cache
# agent.apply_environment = true
# agent.apply_files = true
# agent.custom_build_script =
# agent.disable_task_docker_override = false
# agent.default_python = 3.12
# agent.cuda_version = 126
# agent.cudnn_version = 0
# api.version = 1.5
# api.verify_certificate = true
# api.default_version = 1.5
# api.http.max_req_size = 15728640
# api.http.retries.total = 240
# api.http.retries.connect = 240
# api.http.retries.read = 240
# api.http.retries.redirect = 240
# api.http.retries.status = 240
# api.http.retries.backoff_factor = 1.0
# api.http.retries.backoff_max = 120.0
# api.http.wait_on_maintenance_forever = true
# api.http.pool_maxsize = 512
# api.http.pool_connections = 512
# api.auth.token_expiration_threshold_sec = ****
# api.api_server = https://api.clear.ml
# api.files_server = https://files.clear.ml
# api.web_server = https://app.clear.ml/
# api.credentials.access_key = NAR0DPIK0YBUPHWX0AJ625C54MN7MS
# api.credentials.secret_key = ****
# sdk.storage.cache.default_base_dir = ~/.clearml/cache
# sdk.storage.cache.size.min_free_bytes = 10GB
# sdk.storage.direct_access.0.url = file://*
# sdk.metrics.file_history_size = 100
# sdk.metrics.matplotlib_untitled_history_size = 100
# sdk.metrics.images.format = JPEG
# sdk.metrics.images.quality = 87
# sdk.metrics.images.subsampling = 0
# sdk.metrics.tensorboard_single_series_per_graph = false
# sdk.network.metrics.file_upload_threads = 4
# sdk.network.metrics.file_upload_starvation_warning_sec = 120
# sdk.network.iteration.max_retries_on_server_error = 5
# sdk.network.iteration.retry_backoff_factor_sec = 10
# sdk.aws.s3.key =
# sdk.aws.s3.secret = ****
# sdk.aws.s3.region = ap-southeast-2
# sdk.aws.boto3.pool_connections = 512
# sdk.aws.boto3.max_multipart_concurrency = 16
# sdk.log.null_log_propagate = false
# sdk.log.task_log_buffer_capacity = 66
# sdk.log.disable_urllib3_info = true
# sdk.development.task_reuse_time_window_in_hours = 72.0
# sdk.development.vcs_repo_detect_async = true
# sdk.development.store_uncommitted_code_diff = true
# sdk.development.support_stopping = true
# sdk.development.default_output_uri =
# sdk.development.force_analyze_entire_repo = false
# sdk.development.suppress_update_message = false
# sdk.development.detect_with_pip_freeze = false
# sdk.development.worker.report_period_sec = 2
# sdk.development.worker.ping_period_sec = 30
# sdk.development.worker.log_stdout = true
# sdk.development.worker.report_global_mem_used = false
#
# Worker "default:gpuall" - Listening to queues:
# +----------------------------------+----------------------+-------+
# | id                               | name                 | tags  |
# +----------------------------------+----------------------+-------+
# | e5a392b5e3914599886e740ca0ced26a | Yolov8_training_v0.1 |       |
# +----------------------------------+----------------------+-------+
#
# Running CLEARML-AGENT daemon in background mode, writing stdout/stderr to /tmp/.clearml_agent_daemon_outvni5_ofo.txt
# ^C

# %%
# !python train_yolo.py
# Out:
# ClearML Task: created new task id=c558564150d9403c99b4e1efdec8bbd3
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774106017.394193    1418 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774106017.405441    1418 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ClearML results page: https://app.clear.ml/projects/60acc34acd9b4760b96731a36a4d51c4/experiments/c558564150d9403c99b4e1efdec8bbd3/output/log
# █████████████████████████████ 100% | 133.59/133.59 MB [00:08<00:00, 14.76MB/s]: /opt/conda/lib/python3.12/site-packages/tqdm/std.py:636: TqdmWarning:
#
# clamping frac to range [0, 1]
#
# ████████████████████████████ 100% | 133.59/133.59 MB [00:08<-00:00, 15.26MB/s]:
# ✅ Dataset path: /home/sagemaker-user/42174_Model/bdd100k_tiny_data
# ✅ dataset.yaml created!
# Ultralytics 8.4.24 🚀 Python-3.12.9 torch-2.6.0 CUDA:0 (Tesla T4, 14912MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/home/sagemaker-user/42174_Model/bdd100k_tiny_data/dataset.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=experiment_20260321_151419, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/YOLOv8_BDD100K, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/sagemaker-user/42174_Model/runs/detect/runs/YOLOv8_BDD100K/experiment_20260321_151419, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=10
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    753262  ultralytics.nn.modules.head.Detect           [10, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,012,798 parameters, 3,012,782 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1614.6±600.3 MB/s, size: 55.5 KB)
# train: Scanning /home/sagemaker-user/42174_Model/bdd100k_tiny_data/train/labels... 2000 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2000/2000 1.8Kit/s 1.1s0.0s
# train: New cache created: /home/sagemaker-user/42174_Model/bdd100k_tiny_data/train/labels.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 653.4±336.2 MB/s, size: 44.8 KB)
# val: Scanning /home/sagemaker-user/42174_Model/bdd100k_tiny_data/val/labels... 400 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 400/400 1.6Kit/s 0.3s<0.1s
# val: New cache created: /home/sagemaker-user/42174_Model/bdd100k_tiny_data/val/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000714, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to /home/sagemaker-user/42174_Model/runs/detect/runs/YOLOv8_BDD100K/experiment_20260321_151419/labels.jpg...
# 2026/03/21 15:14:35 INFO mlflow.bedrock: Enabled auto-tracing for Bedrock. Note that MLflow can only trace boto3 service clients that are created after this call. If you have already created one, please recreate the client by calling `boto3.client`.
# 2026/03/21 15:14:35 INFO mlflow.tracking.fluent: Autologging successfully enabled for boto3.
# /opt/conda/lib/python3.12/site-packages/mlflow/fastai/__init__.py:68: FutureWarning:
#
# fastai flavor is deprecated and will be removed in MLflow 3.0.
#
# 2026/03/21 15:14:35 WARNING mlflow.utils.autologging_utils: MLflow fastai autologging is known to be compatible with 2.4.1 <= fastai <= 2.7.19, but the installed version is 2.8.7. If you encounter errors during autologging, try upgrading / downgrading fastai to a compatible version, or try upgrading MLflow.
# 2026/03/21 15:14:35 INFO mlflow.tracking.fluent: Autologging successfully enabled for fastai.
# 2026/03/21 15:14:35 WARNING mlflow.utils.autologging_utils: MLflow keras autologging is known to be compatible with 3.0.2 <= keras <= 3.9.2, but the installed version is 3.12.0. If you encounter errors during autologging, try upgrading / downgrading keras to a compatible version, or try upgrading MLflow.
# 2026/03/21 15:14:35 INFO mlflow.tracking.fluent: Autologging successfully enabled for keras.
# 2026/03/21 15:14:35 WARNING mlflow.utils.autologging_utils: MLflow sklearn autologging is known to be compatible with 0.24.1 <= scikit-learn <= 1.6.1, but the installed version is 1.7.2. If you encounter errors during autologging, try upgrading / downgrading scikit-learn to a compatible version, or try upgrading MLflow.
# 2026/03/21 15:14:36 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 
7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.5it/s 2.4s0.2s
#                    all        400       7256       0.42      0.321      0.324      0.177
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      5.49G      1.359     0.7894     0.9525        266        640: 100% ━━━━━━━━━━━━ 125/125 6.7it/s 18.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.6it/s 2.0s0.2s
#                    all        400       7256      0.465      0.299      0.321      0.174
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50       5.5G       1.36     0.7879     0.9531        189        640: 100% ━━━━━━━━━━━━ 125/125 6.7it/s 18.6s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.6it/s 2.0s0.2s
#                    all        400       7256      0.451      0.304      0.319      0.175
#
# 50 epochs completed in 0.303 hours.
# Optimizer stripped from /home/sagemaker-user/42174_Model/runs/detect/runs/YOLOv8_BDD100K/experiment_20260321_151419/weights/last.pt, 6.2MB
# Optimizer stripped from /home/sagemaker-user/42174_Model/runs/detect/runs/YOLOv8_BDD100K/experiment_20260321_151419/weights/best.pt, 6.2MB
#
# Validating /home/sagemaker-user/42174_Model/runs/detect/runs/YOLOv8_BDD100K/experiment_20260321_151419/weights/best.pt...
# Ultralytics 8.4.24 🚀 Python-3.12.9 torch-2.6.0 CUDA:0 (Tesla T4, 14912MiB)
# Model summary (fused): 73 layers, 3,007,598 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.5it/s 2.9s0.2s
#                    all        400       7256      0.419      0.322      0.324      0.177
#                    car        399       4017      0.633      0.637      0.659      0.395
#                    bus         56         72      0.434      0.264      0.312      0.227
#                  truck        116        180      0.444      0.411       0.39      0.276
#                 person        134        510      0.551      0.449      0.474      0.219
#          traffic light        215       1042      0.496      0.417       0.37      0.117
#           traffic sign        331       1391      0.537      0.376      0.385      0.183
#                   bike         19         26      0.147     0.0769     0.0953     0.0508
#                  motor         13         17      0.528      0.265      0.227      0.124
#                  train          1          1          0          0          0          0
# Speed: 0.2ms preprocess, 1.1ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to /home/sagemaker-user/42174_Model/runs/detect/runs/YOLOv8_BDD100K/experiment_20260321_151419
# MLflow: results logged to runs/mlflow
# MLflow: disable with 'yolo settings mlflow=False'
#
# ✅ Training completed!
# 📂 Results saved in: runs/YOLOv8_BDD100K/experiment_20260321_151419
# 🏆 Best: runs/YOLOv8_BDD100K/experiment_20260321_151419/weights/best.pt
# 📦 Last: runs/YOLOv8_BDD100K/experiment_20260321_151419/weights/last.pt
# █████████████████████████████████ 100% | 5.94/5.94 MB [00:00<00:00, 11.72MB/s]:

# %%
# !python train_yolo.py
# Out:
# ClearML Task: overwriting (reusing) task id=fe391bfd23eb4585b74daffdabe3330d
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774121904.205198   13403 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774121904.210901   13403 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ClearML results page: https://app.clear.ml/projects/60acc34acd9b4760b96731a36a4d51c4/experiments/fe391bfd23eb4585b74daffdabe3330d/output/log
# ✅ Dataset path: /home/sagemaker-user/42174_Model/bdd100k_tiny_data1
# ✅ dataset.yaml created!
# Ultralytics 8.4.24 🚀 Python-3.12.9 torch-2.6.0 CUDA:0 (Tesla T4, 14912MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/home/sagemaker-user/42174_Model/bdd100k_tiny_data1/dataset.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=[], half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=960, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.0005, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=experiment_20260321_193849, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/YOLOv8_BDD100K, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/sagemaker-user/42174_Model/runs/detect/runs/YOLOv8_BDD100K/experiment_20260321_193849, save_frames=False, save_json=False, save_period=2, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=10
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    753262  ultralytics.nn.modules.head.Detect           [10, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,012,798 parameters, 3,012,782 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1660.7±545.0 MB/s, size: 55.5 KB)
# train: Scanning /home/sagemaker-user/42174_Model/bdd100k_tiny_data1/train/labels... 2000 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2000/2000 1.8Kit/s 1.1s0.0s
# train: New cache created: /home/sagemaker-user/42174_Model/bdd100k_tiny_data1/train/labels.cache
# val: Fast image access ✅ (ping: 2.0±4.5 ms, read: 744.6±343.6 MB/s, size: 44.8 KB)
# val: Scanning /home/sagemaker-user/42174_Model/bdd100k_tiny_data1/val/labels... 400 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 400/400 1.3Kit/s 0.3s<0.2s
# val: New cache created: /home/sagemaker-user/42174_Model/bdd100k_tiny_data1/val/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.0005' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000714, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to /home/sagemaker-user/42174_Model/runs/detect/runs/YOLOv8_BDD100K/experiment_20260321_193849/labels.jpg...
# 2026/03/21 19:39:03 INFO mlflow.bedrock: Enabled auto-tracing for Bedrock. Note that MLflow can only trace boto3 service clients that are created after this call. If you have already created one, please recreate the client by calling `boto3.client`.
# 2026/03/21 19:39:03 INFO mlflow.tracking.fluent: Autologging successfully enabled for boto3.
# /opt/conda/lib/python3.12/site-packages/mlflow/fastai/__init__.py:68: FutureWarning:
#
# fastai flavor is deprecated and will be removed in MLflow 3.0.
#
# 2026/03/21 19:39:03 WARNING mlflow.utils.autologging_utils: MLflow fastai autologging is known to be compatible with 2.4.1 <= fastai <= 2.7.19, but the installed version is 2.8.7. If you encounter errors during autologging, try upgrading / downgrading fastai to a compatible version, or try upgrading MLflow.
# 2026/03/21 19:39:03 INFO mlflow.tracking.fluent: Autologging successfully enabled for fastai.
# 2026/03/21 19:39:03 WARNING mlflow.utils.autologging_utils: MLflow keras autologging is known to be compatible with 3.0.2 <= keras <= 3.9.2, but the installed version is 3.12.0. If you encounter errors during autologging, try upgrading / downgrading keras to a compatible version, or try upgrading MLflow.
# 2026/03/21 19:39:03 INFO mlflow.tracking.fluent: Autologging successfully enabled for keras.
# 2026/03/21 19:39:03 WARNING mlflow.utils.autologging_utils: MLflow sklearn autologging is known to be compatible with 0.24.1 <= scikit-learn <= 1.6.1, but the installed version is 1.7.2. If you encounter errors during autologging, try upgrading / downgrading scikit-learn to a compatible version, or try upgrading MLflow.
# 2026/03/21 19:39:04 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2026/03/21 19:39:04 INFO mlflow.tracking.fluent: Autologging successfully enabled for tensorflow.
# MLflow: logging run_id(41b2ff9c37a14d6fa7f639d6a97565f7) to runs/mlflow
# MLflow: view at http://127.0.0.1:5000 with 'mlflow server --backend-store-uri runs/mlflow'
# MLflow: disable with 'yolo settings mlflow=False'
# Image sizes 960 train, 960 val
# Using 4 dataloader workers
# Logging results to /home/sagemaker-user/42174_Model/runs/detect/runs/YOLOv8_BDD100K/experiment_20260321_193849
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      3.15G      1.767      3.555      1.185        202        960: 24% ━━╸───────── 59/250 5.8it/s 12.5s<33.0s

# %%
# full dataset
# !python train_yolo.py
# Out:
# ClearML Task: created new task id=61e63f06a18d4c0dae6d724fefd544e1
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774241904.748182    3439 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774241904.753697    3439 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ClearML results page: https://app.clear.ml/projects/d8cfcd8731544c248f99e9b9ed8d40c0/experiments/61e63f06a18d4c0dae6d724fefd544e1/output/log
# ClearML Monitor: Could not detect iteration reporting, falling back to iterations as seconds-from-start
# ✅ Dataset path: /home/sagemaker-user/42174_Model/bdd100k_full_data
# ✅ dataset.yaml created!
# Ultralytics 8.4.24 🚀 Python-3.12.9 torch-2.6.0 CUDA:0 (Tesla T4, 14912MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/home/sagemaker-user/42174_Model/bdd100k_full_data/dataset.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=[], half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=960, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.0005, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=experiment_20260323_050256, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/YOLOv8_BDD100K, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/sagemaker-user/42174_Model/runs/detect/runs/YOLOv8_BDD100K/experiment_20260323_050256, save_frames=False, save_json=False, save_period=2, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=10
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    753262  ultralytics.nn.modules.head.Detect           [10, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,012,798 parameters, 3,012,782 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 64.7±15.5 MB/s, size: 55.7 KB)
# train: Scanning /home/sagemaker-user/42174_Model/bdd100k_full_data/train/labels... 69863 images, 137 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 70000/70000 1.2Kit/s 1:01<0.1sss
# train: /home/sagemaker-user/42174_Model/bdd100k_full_data/train/images/75055858-7d04a650.jpg: 1 duplicate labels removed
# train: New cache created: /home/sagemaker-user/42174_Model/bdd100k_full_data/train/labels.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 760.2±248.5 MB/s, size: 58.2 KB)
# val: Scanning /home/sagemaker-user/42174_Model/bdd100k_full_data/val/labels... 10000 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 10000/10000 1.2Kit/s 8.3s.1ss
# val: New cache created: /home/sagemaker-user/42174_Model/bdd100k_full_data/val/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.0005' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.01, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to /home/sagemaker-user/42174_Model/runs/detect/runs/YOLOv8_BDD100K/experiment_20260323_050256/labels.jpg...
# 2026/03/23 05:04:27 INFO mlflow.bedrock: Enabled auto-tracing for Bedrock. Note that MLflow can only trace boto3 service clients that are created after this call. If you have already created one, please recreate the client by calling `boto3.client`.
# 2026/03/23 05:04:27 INFO mlflow.tracking.fluent: Autologging successfully enabled for boto3.
# /opt/conda/lib/python3.12/site-packages/mlflow/fastai/__init__.py:68: FutureWarning:
#
# fastai flavor is deprecated and will be removed in MLflow 3.0.
#
# 2026/03/23 05:04:27 WARNING mlflow.utils.autologging_utils: MLflow fastai autologging is known to be compatible with 2.4.1 <= fastai <= 2.7.19, but the installed version is 2.8.7. If you encounter errors during autologging, try upgrading / downgrading fastai to a compatible version, or try upgrading MLflow.
# 2026/03/23 05:04:27 INFO mlflow.tracking.fluent: Autologging successfully enabled for fastai.
# 2026/03/23 05:04:27 WARNING mlflow.utils.autologging_utils: MLflow keras autologging is known to be compatible with 3.0.2 <= keras <= 3.9.2, but the installed version is 3.12.0. If you encounter errors during autologging, try upgrading / downgrading keras to a compatible version, or try upgrading MLflow.
# 2026/03/23 05:04:27 INFO mlflow.tracking.fluent: Autologging successfully enabled for keras.
# 2026/03/23 05:04:27 WARNING mlflow.utils.autologging_utils: MLflow sklearn autologging is known to be compatible with 0.24.1 <= scikit-learn <= 1.6.1, but the installed version is 1.7.2. If you encounter errors during autologging, try upgrading / downgrading scikit-learn to a compatible version, or try upgrading MLflow.
# 2026/03/23 05:04:28 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2026/03/23 05:04:28 INFO mlflow.tracking.fluent: Autologging successfully enabled for tensorflow.
# MLflow: logging run_id(4d84e2aca18b4fa2a1ea907c98daf1e6) to runs/mlflow
# MLflow: view at http://127.0.0.1:5000 with 'mlflow server --backend-store-uri runs/mlflow'
# MLflow: disable with 'yolo settings mlflow=False'
# Image sizes 960 train, 960 val
# Using 4 dataloader workers
# Logging results to /home/sagemaker-user/42174_Model/runs/detect/runs/YOLOv8_BDD100K/experiment_20260323_050256
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50       3.3G      1.533      1.408      1.086        340        960: 100% ━━━━━━━━━━━━ 8750/8750 4.3it/s 34:18<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 625/625
UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import Requirement as Req
# Using environment access key CLEARML_API_ACCESS_KEY=R58U0GS1V7DPMV9POEA3L3E6WHH8EV
# Using environment secret key CLEARML_API_SECRET_KEY=********
# Could not find a running clearml-agent instance with worker_name=default worker_id=default:gpuall
# Command completed

# %%
# !ls /home/sagemaker-user/42174_Model/bdd100k_full_data1/train/labels_yolo | head

# !cat /home/sagemaker-user/42174_Model/bdd100k_full_data1/train/labels_yolo/0000f77c-6257be58.txt
# Out:
# 0000f77c-6257be58.txt
# 0000f77c-62c2a288.txt
# 0000f77c-cb820c98.txt
# 0001542f-5ce3cf52.txt
# 0001542f-7c670be8.txt
# 0001542f-ec815219.txt
# 0004974f-05e1c285.txt
# 00054602-3bf57337.txt
# 00067cfb-5443fe39.txt
# 00067cfb-5adfaaa7.txt
# ls: write error: Broken pipe
# 8 0.891750 0.238931 0.024278 0.107904
# 8 0.917378 0.241328 0.026976 0.103108
# 9 0.887704 0.308811 0.053952 0.031172
# 9 0.039212 0.085467 0.078423 0.170249
# 2 0.157440 0.515581 0.244191 0.324133
# 2 0.553201 0.461419 0.312922 0.306927
# 9 0.040068 0.093209 0.079891 0.184170

# %%
# Resume training
from resume_train import resume_training

MODEL_PATH = "runs/detect/runs/YOLOv8_BDD100K/experiment_20260323_050256/weights/last.pt"
DATASET_YAML = "bdd100k_full_data/dataset.yaml"

resume_training(
    model_path=MODEL_PATH,
    dataset_yaml=DATASET_YAML,
    use_timestamp=False
)
# Out:
# Ultralytics 8.4.26 🚀 Python-3.12.9 torch-2.6.0 CUDA:0 (Tesla T4, 14912MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/home/sagemaker-user/42174_Model/bdd100k_full_data/dataset.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=[], half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=960, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.0005, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=runs/detect/runs/YOLOv8_BDD100K/experiment_20260323_050256/weights/last.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=experiment_20260323_050256, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/YOLOv8_BDD100K, rect=False, resume=runs/detect/runs/YOLOv8_BDD100K/experiment_20260323_050256/weights/last.pt, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/sagemaker-user/42174_Model/runs/detect/runs/YOLOv8_BDD100K/experiment_20260323_050256, save_frames=False, save_json=False, save_period=2, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.0, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# ClearML Task: created new task id=e68ee4daf9d14e70b459c1675d40cf63
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774298112.713283    2276 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774298112.723610    2276 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ClearML results page: https://app.clear.ml/projects/d65e0ea6d094406bbe406cc2c4a5e219/experiments/e68ee4daf9d14e70b459c1675d40cf63/output/log
# WARNING ⚠️ ClearML Initialized a new task. If you want to run remotely, please add clearml-init and connect your arguments before initializing YOLO.
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    753262  ultralytics.nn.modules.head.Detect           [10, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,012,798 parameters, 3,012,782 gradients, 8.2 GFLOPs
#
# Transferred 355/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 1.4±0.3 ms, read: 72.7±19.2 MB/s, size: 69.2 KB)
# train: Scanning /home/sagemaker-user/42174_Model/bdd100k_full_data/train/labels.cache... 69863 images, 137 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 70000/70000 4.4Git/s 0.0s
# train: /home/sagemaker-user/42174_Model/bdd100k_full_data/train/images/75055858-7d04a650.jpg: 1 duplicate labels removed
# val: Fast image access ✅ (ping: 1.3±0.4 ms, read: 56.6±22.2 MB/s, size: 55.2 KB)
# val: Scanning /home/sagemaker-user/42174_Model/bdd100k_full_data/val/labels.cache... 10000 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 10000/10000 355.4Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.0005' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.01, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to /home/sagemaker-user/42174_Model/runs/detect/runs/YOLOv8_BDD100K/experiment_20260323_050256/labels.jpg...
# Resuming training runs/detect/runs/YOLOv8_BDD100K/experiment_20260323_050256/weights/last.pt from epoch 23 to 50 total epochs
# 2026/03/23 20:35:47 INFO mlflow.bedrock: Enabled auto-tracing for Bedrock. Note that MLflow can only trace boto3 service clients that are created after this call. If you have already created one, please recreate the client by calling `boto3.client`.
# 2026/03/23 20:35:47 INFO mlflow.tracking.fluent: Autologging successfully enabled for boto3.
# /opt/conda/lib/python3.12/site-packages/mlflow/fastai/__init__.py:68: FutureWarning: fastai flavor is deprecated and will be removed in MLflow 3.0.
#   warnings.warn("fastai flavor is deprecated and will be removed in MLflow 3.0.", FutureWarning)
# 2026/03/23 20:35:47 WARNING mlflow.utils.autologging_utils: MLflow fastai autologging is known to be compatible with 2.4.1 <= fastai <= 2.7.19, but the installed version is 2.8.7. If you encounter errors during autologging, try upgrading / downgrading fastai to a compatible version, or try upgrading MLflow.
# 2026/03/23 20:35:47 INFO mlflow.tracking.fluent: Autologging successfully enabled for fastai.
# 2026/03/23 20:35:47 WARNING mlflow.utils.autologging_utils: MLflow keras autologging is known to be compatible with 3.0.2 <= keras <= 3.9.2, but the installed version is 3.12.0. If you encounter errors during autologging, try upgrading / downgrading keras to a compatible version, or try upgrading MLflow.
# 2026/03/23 20:35:47 INFO mlflow.tracking.fluent: Autologging successfully enabled for keras.
# 2026/03/23 20:35:47 WARNING mlflow.utils.autologging_utils: MLflow sklearn autologging is known to be compatible with 0.24.1 <= scikit-learn <= 1.6.1, but the installed version is 1.7.2. If you encounter errors during autologging, try upgrading / downgrading scikit-learn to a compatible version, or try upgrading MLflow.
# 2026/03/23 20:35:48 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2026/03/23 20:35:48 INFO mlflow.tracking.fluent: Autologging successfully enabled for tensorflow.
# MLflow: logging run_id(69abe67a8a9d467f8699a9688de57642) to runs/mlflow
# MLflow: view at http://127.0.0.1:5000 with 'mlflow server --backend-store-uri runs/mlflow'
# MLflow: disable with 'yolo settings mlflow=False'
# Image sizes 960 train, 960 val
# Using 4 dataloader workers
# Logging results to /home/sagemaker-user/42174_Model/runs/detect/runs/YOLOv8_BDD100K/experiment_20260323_050256
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      3.29G      1.382      0.849      1.018        282        960: 9% ━─────────── 830/8750 5.7it/s 2:39<23:14ClearML Monitor: Could not detect iteration reporting, falling back to iterations as seconds-from-start
#       23/50      3.29G      1.385     0.8547      1.019        340        960: 100% ━━━━━━━━━━━━ 8750/8750 5.3it/s 27:25<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 625/625 7.4it/s 1:24<0.1ss
#                    all      10000     184877       0.71       0.47      0.522      0.296
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50       3.7G      1.383      0.853      1.018        282        960: 100% ━━━━━━━━━━━━ 8750/8750 5.4it/s 27:12<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 625/625 7.7it/s 1:21<0.1ss
#                    all      10000     184877      0.711      0.471      0.522      0.296
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50       3.7G      1.382     0.8519      1.017        210        960: 100% ━━━━━━━━━━━━ 8750/8750 5.4it/s 27:14<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 625/625 7.5it/s 1:23<0.1ss
#                    all      10000     184877      0.711      0.472      0.523      0.297
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50       3.7G      1.381     0.8482      1.016        167        960: 100% ━━━━━━━━━━━━ 8750/8750 5.3it/s 27:20<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 625/625 7.6it/s 1:22<0.1ss
#                    all      10000     184877      0.714      0.471      0.523      0.297
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50       4.1G      1.378     0.8464      1.015        250        960: 100% ━━━━━━━━━━━━ 8750/8750 5.3it/s 27:20<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 625/625 7
 6.7ms
# Speed: 3.2ms preprocess, 6.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
# f7c95080-cda8ead8.jpg → Risk Vector: [     22.727          15     0.49185    0.068858]
#
# image 1/1 /home/sagemaker-user/42174_Model/bdd100k_full_data/test/eb991015-f00391de.jpg: 544x960 5 cars, 6.7ms
# Speed: 3.1ms preprocess, 6.7ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 960)
# eb991015-f00391de.jpg → Risk Vector: [     9.3436           5     0.72967     0.14592]
#
# image 1/1 /home/sagemaker-user/42174_Model/bdd100k_full_data/test/efa6f73b-8c261ec4.jpg: 544x960 3 cars, 1 bus, 2 trucks, 1 person, 2 traffic signs, 6.7ms
# Speed: 3.1ms preprocess, 6.7ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 960)
# efa6f73b-8c261ec4.jpg → Risk Vector: [     14.867           9     0.64452     0.11878]
#
# image 1/1 /home/sagemaker-user/42174_Model/bdd100k_full_data/test/f9b78c98-4348e4e1.jpg: 544x960 8 cars, 7 traffic signs, 6.7ms
# Speed: 3.1ms preprocess, 6.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 960)
# f9b78c98-4348e4e1.jpg → Risk Vector: [     33.129          15     0.58225    0.065771]
#
# image 1/1 /home/sagemaker-user/42174_Model/bdd100k_full_data/test/f7cb92ae-6c16dbce.jpg: 544x960 10 cars, 1 truck, 2 traffic signs, 1 motor, 6.7ms
# Speed: 3.1ms preprocess, 6.7ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 960)
# f7cb92ae-6c16dbce.jpg → Risk Vector: [     24.206          14     0.63843     0.10098]
#
# image 1/1 /home/sagemaker-user/42174_Model/bdd100k_full_data/test/da60d471-85834da3.jpg: 544x960 5 cars, 5 persons, 10 traffic lights, 5 traffic signs, 1 bike, 7.0ms
# Speed: 3.2ms preprocess, 7.0ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 960)
# da60d471-85834da3.jpg → Risk Vector: [     39.981          26     0.47568    0.021289]
#
# image 1/1 /home/sagemaker-user/42174_Model/bdd100k_full_data/test/ea9787b5-aa7da862.jpg: 544x960 13 cars, 9 traffic lights, 5 traffic signs, 6.7ms
# Speed: 3.1ms preprocess, 6.7ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 960)
# ea9787b5-aa7da862.jpg → Risk Vector: [     32.006          27     0.65732    0.040835]
#
# image 1/1 /home/sagemaker-user/42174_Model/bdd100k_full_data/test/ea766282-860edad9.jpg: 544x960 13 cars, 3 traffic lights, 7 traffic signs, 6.7ms
# Speed: 3.1ms preprocess, 6.7ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 960)
# ea766282-860edad9.jpg → Risk Vector: [     32.623          23     0.58943     0.03204]
#
# image 1/1 /home/sagemaker-user/42174_Model/bdd100k_full_data/test/f96cfa65-058daf4e.jpg: 544x960 10 cars, 1 truck, 1 traffic light, 4 traffic signs, 7.6ms
# Speed: 4.5ms preprocess, 7.6ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 960)
# f96cfa65-058daf4e.jpg → Risk Vector: [     36.345          16     0.56596    0.040682]
#
# image 1/1 /home/sagemaker-user/42174_Model/bdd100k_full_data/test/e71d759c-6ec019cf.jpg: 544x960 10 cars, 1 person, 7 traffic lights, 6 traffic signs, 7.6ms
# Speed: 4.5ms preprocess, 7.6ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 960)
# e71d759c-6ec019cf.jpg → Risk Vector: [     34.124          24     0.53427    0.024865]

# %% [markdown]
# ## Warning system

# %%
from warning_system import Warning_System

YOLO_MODEL = "runs/detect/runs/YOLOv8_BDD100K/experiment_20260323_050256/weights/best.pt"
RISK_MODEL = "risk_dataset7/risk_model.pkl"

IMAGE_PATH = "bdd100k_full_data/test/cabc30fc-e7726578.jpg"

system = Warning_System(YOLO_MODEL, RISK_MODEL)

system.run(IMAGE_PATH, save_path="result.jpg")
# Out:
# image 1/1 /home/sagemaker-user/42174_Model/bdd100k_full_data/test/cabc30fc-e7726578.jpg: 544x960 4 cars, 1 person, 2 traffic signs, 44.3ms
# Speed: 4.0ms preprocess, 44.3ms inference, 13.8ms postprocess per image at shape (1, 3, 544, 960)
# ==============================
# Risk level: Medium
# Probability: [ 0.00025148     0.72855      0.2712]
# Saved: result.jpg
# ==============================
# ('Medium', array([ 0.00025148,     0.72855,      0.2712]))

# %%
import matplotlib.pyplot as plt
import cv2

img = cv2.imread("result.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(8,6))
plt.imshow(img)
plt.axis("off")
plt.title("Result Image")
plt.show()
